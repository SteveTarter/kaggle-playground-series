# %% [markdown]
# ### PS-S06E03: CatBoost

# %% [markdown]
# This notebook tackles the [**Playground Series – Season 6, Episode 3: Predict Customer Churn**](https://www.kaggle.com/competitions/playground-series-s6e3), a competition focused on predicting if a customer is likely to cancel their subscription, based on features describing the customer's demographics and services used by them.

# %% [markdown]
# CatBoost is a strong baseline for tabular problems and often complements XGBoost/LightGBM in ensembles because it can behave differently on categorical and mixed-type features.
#
# In this notebook we:
# - Apply lightweight feature engineering per fold (to avoid leakage)
# - Train a **CatBoostClassifier** with stratified cross-validation
# - Collect **OOF probabilities** and averaged **test probabilities** for blending/stacking
# - Track fold and overall **ROC AUC**

# %% [markdown]
# ## Install Needed Packages

# %%
import os
import gc
import sys
import math
import random
import warnings

# Third-party
import numpy as np
import pandas as pd
import catboost as cb
import optuna
import torch
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import RFECV
from catboost import CatBoostClassifier, Pool, EFstrType, EFeaturesSelectionAlgorithm, EShapCalcType

import matplotlib.pyplot as plt
import seaborn as sns

from ps_s06e03_feature_engineering import FeatureFactory
from ps_s06e03_model_visualizer import ModelVisualizer
from ps_s06e03_experiment_setup import ExperimentSetup

warnings.filterwarnings('ignore')

import ipywidgets as widgets
widgets.IntProgress()
# Out:
# IntProgress(value=0)

# %%
helper = ExperimentSetup()

# Get the seed, and apply it to all the internals like pandas and numpy
seed = helper.set_seeds()

helper.configure_pandas()
helper.suppress_warnings()

# Target label column for S06E03
TARGET = 'Churn'

# GPU usage (set True only if your environment supports CatBoost GPU)
USE_GPU = False

# Optional: Recursive Feature Elimination
PERFORM_RFE = False

# Optional: Optuna tuning
PERFORM_OPTUNA_TUNING = False
# Out:
# Random seed set to: 10301
# Warnings suppressed.

# %% [markdown]
# ## Read and Examine the Training Dataset

# %%
training_df = helper.read_dataset('training')
# Out:
# TRAINING DATASET
# ================
#
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1            No             DSL            Yes          Yes               No
# 2           Yes     Fiber optic             No          Yes               No
# 3            No     Fiber optic             No           No               No
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0             Mailed check          60.100     1,653.850    No
# 1  Credit card (automatic)          69.500     3,778.200    No
# 2         Electronic check         100.400     5,841.350    No
# 3         Electronic check          69.700        70.700   Yes
# 4         Electronic check          70.450        70.450   Yes

# %% [markdown]
# ## Read and Examine the Test Dataset

# %%
test_df = helper.read_dataset('test')
# Out:
# TEST DATASET
# ============
#
#        id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  594194  Female              0     Yes         No      72          Yes
# 1  594195  Female              0     Yes         No      71          Yes
# 2  594196    Male              0      No         No      12          Yes
# 3  594197    Male              0     Yes        Yes      71          Yes
# 4  594198  Female              0      No         No      15          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                  Yes
# 3           Yes             DSL                  Yes                   No
# 4            No     Fiber optic                  Yes                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                  Yes                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
# 3                  Yes                  Yes                  Yes
# 4                   No                   No                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                  Yes        Two year              Yes
# 1  No internet service        Two year               No
# 2                   No  Month-to-month              Yes
# 3                  Yes        Two year               No
# 4                  Yes  Month-to-month               No
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0           Electronic check         115.550     8,061.500
# 1  Bank transfer (automatic)          19.800     1,336.500
# 2  Bank transfer (automatic)          55.550       633.550
# 3    Credit card (automatic)          84.100     6,457.150
# 4           Electronic check          90.350     1,233.650

# %% [markdown]
# ## Feature Engineering Strategy
#
# We apply a small set of feature engineering steps that are safe to run **inside each fold** (to avoid leakage) and compatible with CatBoost:
#
# - `drop_id`: removes `id` and the target column from the feature matrix
# - `standard_scaling`: standardizes numeric features
# - `interactions`: adds a small set of numeric interaction features
#
# We do **not** one-hot encode categoricals in this notebook. The heart disease dataset uses integer-coded categorical fields (e.g., chest pain type). We pass those columns to CatBoost as categorical features so the model can learn split rules directly.

# %%
# Define which feature engineering strategies to use
fe_strategies = [
        'drop_id',
        'encoding',
        'ratios',
        'interactions',
        'binning'
]

# %%
print('Performing initial feature engineering.')

# Encode target labels: Presence->1, Absence->0
y = training_df[TARGET].map({'No': 0, 'Yes': 1}).astype(np.int8)

# Initialize and apply the feature factory
feature_engineer = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)

# Fit_transform on training, transform on test
X = feature_engineer.fit_transform(training_df)
X_test = feature_engineer.transform(test_df)

cat_features = feature_engineer.get_cat_features(X)
print(f'Feature Count: {X.shape[1]}')
print(f'CatBoost categorical features ({len(cat_features)}): {cat_features}')
display(X.head())
# Out:
# Performing initial feature engineering.
# Feature Count: 31
# CatBoost categorical features (17): ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'tenure_group', 'Contract_Code']
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      29          Yes
# 1    Male              0     Yes        Yes      58          Yes
# 2    Male              0     Yes         No      58          Yes
# 3  Female              0      No         No       1          Yes
# 4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1            No             DSL            Yes          Yes               No
# 2           Yes     Fiber optic             No          Yes               No
# 3            No     Fiber optic             No           No               No
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0             Mailed check          60.100     1,653.850
# 1  Credit card (automatic)          69.500     3,778.200
# 2         Electronic check         100.400     5,841.350
# 3         Electronic check          69.700        70.700
# 4         Electronic check          70.450        70.450
#
#    Total_Addon_Services  Contract_Code  Avg_Cost_Per_Month_Tenure  \
# 0                     3              1                      2.003
# 1                     4              2                      1.178
# 2                     3              0                      1.702
# 3                     0              0                     34.850
# 4                     0              0                     35.225
#
#    Expected_Total  Charges_Gap  Cost_Per_Service  num_services  \
# 0       1,742.900      -89.050            15.025             3
# 1       4,031.000     -252.800            13.900             4
# 2       5,823.200       18.150            25.100             3
# 3          69.700        1.000            69.700             0
# 4          70.450        0.000            70.450             0
#
#    cost_per_service  charges_per_tenure  total_service_count  \
# 0            15.025               2.003                    5
# 1            13.900               1.178                    6
# 2            25.100               1.702                    6
# 3            69.700              34.850                    2
# 4            70.450              35.225                    2
#
#    tenure_month_to_month tenure_group
# 0                      0  Established
# 1                      0  Established
# 2                     58  Established
# 3                      1          New
# 4                      1          New

# %%
# Categorical columns for this competition (integer-coded)
cat_cols = feature_engineer.get_cat_features(X)

cat_cols = [c for c in cat_cols if c in X.columns]
print(f'Categorical Features: {cat_cols}')

# CatBoost accepts categoricals as either int codes or strings. We keep strings here.
for c in cat_cols:
    # Convert all identified categorical columns to string
    X[c] = X[c].astype(str)
    X_test[c] = X_test[c].astype(str)
# Out:
# Categorical Features: ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'tenure_group', 'Contract_Code']

# %% [markdown]
# ### Recursive Feature Elimination (RFE)
#
# Optionally run **RFECV** to remove features that do not contribute to ROC AUC.
#
# - This is relatively expensive for boosting models.
# - In practice, feature selection often helps less than careful regularization and early stopping.
# - Keep this off unless you are explicitly experimenting.

# %%
n_jobs = 1 if USE_GPU else -1

optimal_cols = X.columns

if PERFORM_RFE:
    print('Running Recursive Feature Elimination (RFECV)...')

    FS_RANDOM_SEED = seed
    FS_STEPS = 20  # higher = slower, potentially more stable (try 10/20/30)
    FS_EVAL_SPLIT = 0.2  # simple holdout inside selection
    
    # Ensure y is numeric 0/1 (adjust mapping if your y already is numeric)
    if y.dtype == object:
        y_fs = y.map({'Absence': 0, 'Presence': 1}).astype(np.int8)
    else:
        y_fs = y.astype(np.int8)

    # Recreate features using your FeatureFactory (same as training)
    fe_fs = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=FS_RANDOM_SEED)
    X_fs = fe_fs.fit_transform(training_df).drop(columns=[TARGET], errors="ignore")
    cat_features_fs = fe_fs.get_cat_features(X_fs)

    # Train/eval split for feature selection (stratified)
    from sklearn.model_selection import StratifiedShuffleSplit
    sss = StratifiedShuffleSplit(n_splits=1, test_size=FS_EVAL_SPLIT, random_state=FS_RANDOM_SEED)
    tr_idx, va_idx = next(sss.split(X_fs, y_fs))

    X_tr_fs, y_tr_fs = X_fs.iloc[tr_idx], y_fs.iloc[tr_idx]
    X_va_fs, y_va_fs = X_fs.iloc[va_idx], y_fs.iloc[va_idx]

    train_pool_fs = Pool(X_tr_fs, y_tr_fs, cat_features=cat_features_fs)
    eval_pool_fs  = Pool(X_va_fs, y_va_fs, cat_features=cat_features_fs)

    # Base model for selection.
    # You can swap in your tuned params once you have them; keep it modest for speed.
    fs_model = CatBoostClassifier(
        loss_function="Logloss",
        eval_metric="AUC",
        iterations=4000,
        learning_rate=0.05,
        depth=6,
        random_seed=FS_RANDOM_SEED,
        od_type="Iter",
        od_wait=200,
        verbose=200,
        allow_writing_files=False,
    )

    # Select features
    # - RecursiveByShapValues: generally strong, slower
    # - RecursiveByLossFunctionChange: faster, often good enough
    fs_result = fs_model.select_features(
        train_pool_fs,
        eval_set=eval_pool_fs,
        features_for_select=list(range(X_tr_fs.shape[1])),  # select from all features
        num_features_to_select=int(X_tr_fs.shape[1] * 0.80),  # keep 80% (tune: 0.6–0.9)
        steps=FS_STEPS,
        algorithm=EFeaturesSelectionAlgorithm.RecursiveByShapValues,
        shap_calc_type=EShapCalcType.Regular,
        train_final_model=True,
        logging_level="Verbose",
        plot=False
    )

    selected_idx = fs_result["selected_features"]
    optimal_cols = [X_fs.columns[i] for i in selected_idx]

    print(f"Selected {len(optimal_cols)} / {X_fs.shape[1]} features.")
    print("First 30 selected columns:")
    print(optimal_cols[:30])

else:
    optimal_cols = None
    print("Feature selection skipped.")
# Out:
# Feature selection skipped.

# %% [markdown]
# ### Optuna: Hyperparameter Tuning
#
# This section tunes CatBoost hyperparameters to maximize **ROC AUC** using stratified cross-validation.
#
# - We train with `loss_function='Logloss'` and evaluate with `eval_metric='AUC'`.
# - Each trial runs a 5-fold stratified CV loop with feature engineering inside the fold.
# - The objective returns mean validation AUC across folds (higher is better).

# %%
# Ensure optimal_cols is a standard list for filtering
cols_to_keep = list(optimal_cols) if optimal_cols is not None else None

print(f'Training shape: {X.shape}')
# print(f'Categorical Features: {cat_cols}')
print(f'cols_to_keep: {cols_to_keep}')

def objective(trial):

    params = {
        'loss_function': 'Logloss',
        'eval_metric': 'AUC',
        'iterations': 2500,
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05),
        'depth': trial.suggest_int('depth', 3, 6),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 50.0, log=True),
        'random_strength': trial.suggest_float('random_strength', 1.0, 10.0),
        'border_count': trial.suggest_int('border_count', 64, 128),
        'one_hot_max_size': trial.suggest_int('one_hot_max_size', 2, 20),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 200, log=True),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations', 1, 10),
        'bootstrap_type': 'Bernoulli',
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'grow_policy': 'SymmetricTree',
        'auto_class_weights': trial.suggest_categorical('auto_class_weights', [None, 'Balanced', 'SqrtBalanced']),
        'task_type': 'GPU' if USE_GPU else 'CPU',
        'gpu_ram_part': 0.65,
        'metric_period': 20,
        'allow_writing_files': False,
        'random_seed': seed,
        'verbose': 0,
    }

    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
    fold_auc = []

    for train_idx, val_idx in cv.split(training_df, y):
        X_train_fold = training_df.iloc[train_idx]
        y_train_fold = y.iloc[train_idx]

        X_val_fold = training_df.iloc[val_idx]
        y_val_fold = y.iloc[val_idx]

        fe_fold = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
        X_train_trans = fe_fold.fit_transform(X_train_fold)
        X_val_trans = fe_fold.transform(X_val_fold)

        if cols_to_keep is not None:
            final_cols = [c for c in cols_to_keep if c in X_train_trans.columns]
            if not final_cols:
                raise RuntimeError('No overlap between optimal_cols and fold feature columns.')
            X_train_trans = X_train_trans[final_cols]
            X_val_trans = X_val_trans[final_cols]

        # Get categorical feature names from the fold's feature engineer
        cat_features_fold = fe_fold.get_cat_features(X_train_trans)
        
        # If you filter columns, keep cat_features consistent
        if cols_to_keep is not None:
            cat_features_fold = [c for c in cat_features_fold if c in final_cols]
        
        train_pool = Pool(X_train_trans, y_train_fold, cat_features=cat_features_fold)
        val_pool   = Pool(X_val_trans, y_val_fold,   cat_features=cat_features_fold)

        model = CatBoostClassifier(**params)
        model.fit(
            train_pool,
            eval_set=val_pool,
            early_stopping_rounds=200,
            verbose=False
        )
        torch.cuda.synchronize()

        val_prob = model.predict_proba(val_pool)[:, 1]
        fold_auc.append(roc_auc_score(y_val_fold, val_prob))

        del model, train_pool, val_pool
        gc.collect()
        
    return float(np.mean(fold_auc))
# Out:
# Training shape: (594194, 31)
# cols_to_keep: None

# %%
if PERFORM_OPTUNA_TUNING:
    print('Starting Optuna Optimization (ROC AUC)...')

    pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=10)

    study = optuna.create_study(
        study_name='cb_predict_customer_churn_optuna',
        direction='maximize',
        pruner=pruner
    )

    study.optimize(
        objective,
        n_trials=50,
        n_jobs=1,
        gc_after_trial=True,
        show_progress_bar=True,
        timeout=18000
    )

    print('Best AUC:', study.best_value)
    print('Best Params:', study.best_params)

    best_params = study.best_params
else:
    # Provide reasonable defaults if you are skipping Optuna
    best_params = {
        'learning_rate': 0.03533040759652355,
        'depth': 6,
        'l2_leaf_reg': 13.766003057670106,
        'random_strength': 6.401978316354332,
        'border_count': 124,
        'one_hot_max_size': 19,
        'min_data_in_leaf': 16,
        'leaf_estimation_iterations': 6,
        'subsample': 0.7652360437462804,
        'auto_class_weights': None
    }
    
    print('Using default params:')
    print(best_params)
# Out:
# [I 2026-03-30 15:48:08,881] A new study created in memory with name: cb_predict_customer_churn_optuna
# Starting Optuna Optimization (ROC AUC)...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-03-30 15:50:32,797] Trial 0 finished with value: 0.9152837430799353 and parameters: {'learning_rate': 0.030547032627101733, 'depth': 3, 'l2_leaf_reg': 14.318467148441934, 'random_strength': 9.362503673896834, 'border_count': 84, 'one_hot_max_size': 12, 'min_data_in_leaf': 58, 'leaf_estimation_iterations': 2, 'subsample': 0.60593152479131, 'auto_class_weights': 'Balanced'}. Best is trial 0 with value: 0.9152837430799353.
# [I 2026-03-30 15:53:38,826] Trial 1 finished with value: 0.9157447301282744 and parameters: {'learning_rate': 0.04951717815454761, 'depth': 6, 'l2_leaf_reg': 22.363507342944708, 'random_strength': 3.419333945024697, 'border_count': 68, 'one_hot_max_size': 4, 'min_data_in_leaf': 23, 'leaf_estimation_iterations': 10, 'subsample': 0.8274501600721494, 'auto_class_weights': 'Balanced'}. Best is trial 1 with value: 0.9157447301282744.
# [I 2026-03-30 15:56:56,367] Trial 2 finished with value: 0.9160147218007035 and parameters: {'learning_rate': 0.04314681686143135, 'depth': 6, 'l2_leaf_reg': 44.63872628995132, 'random_strength': 5.407860915594413, 'border_count': 108, 'one_hot_max_size': 9, 'min_data_in_leaf': 89, 'leaf_estimation_iterations': 2, 'subsample': 0.6177979399947019, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 15:59:44,371] Trial 3 finished with value: 0.9156676992035522 and parameters: {'learning_rate': 0.04973720189175816, 'depth': 3, 'l2_leaf_reg': 7.81351324849747, 'random_strength': 1.2668609400434128, 'border_count': 84, 'one_hot_max_size': 11, 'min_data_in_leaf': 93, 'leaf_estimation_iterations': 6, 'subsample': 0.7026813964401732, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 16:02:30,355] Trial 4 finished with value: 0.9159886040155021 and parameters: {'learning_rate': 0.03299415725827318, 'depth': 4, 'l2_leaf_reg': 38.043964561207616, 'random_strength': 3.238683164188586, 'border_count': 125, 'one_hot_max_size': 16, 'min_data_in_leaf': 89, 'leaf_estimation_iterations': 3, 'subsample': 0.9794876672759989, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 16:05:42,804] Trial 5 finished with value: 0.9157837123294638 and parameters: {'learning_rate': 0.019717350989026817, 'depth': 5, 'l2_leaf_reg': 2.188920175066321, 'random_strength': 7.224782343498976, 'border_count': 111, 'one_hot_max_size': 20, 'min_data_in_leaf': 20, 'leaf_estimation_iterations': 5, 'subsample': 0.6824437026269539, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 16:08:53,868] Trial 6 finished with value: 0.9148767635250259 and parameters: {'learning_rate': 0.007819258556835804, 'depth': 6, 'l2_leaf_reg': 5.4900189821109455, 'random_strength': 7.061807694988435, 'border_count': 74, 'one_hot_max_size': 12, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 1, 'subsample': 0.7438580253616744, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 16:12:27,625] Trial 7 finished with value: 0.9159589978526134 and parameters: {'learning_rate': 0.04519591041948532, 'depth': 5, 'l2_leaf_reg': 6.493652422676431, 'random_strength': 9.339994906165934, 'border_count': 103, 'one_hot_max_size': 20, 'min_data_in_leaf': 14, 'leaf_estimation_iterations': 6, 'subsample': 0.8048758481482042, 'auto_class_weights': 'Balanced'}. Best is trial 2 with value: 0.9160147218007035.
# [I 2026-03-30 16:16:09,592] Trial 8 finished with value: 0.9160992854954184 and parameters: {'learning_rate': 0.03385976512910371, 'depth': 5, 'l2_leaf_reg': 19.8789098312516, 'random_strength': 5.925609576083725, 'border_count': 121, 'one_hot_max_size': 15, 'min_data_in_leaf': 24, 'leaf_estimation_iterations': 6, 'subsample': 0.7711268682155659, 'auto_class_weights': None}. Best is trial 8 with value: 0.9160992854954184.
# [I 2026-03-30 16:20:03,037] Trial 9 finished with value: 0.9159102753080932 and parameters: {'learning_rate': 0.03692481305028516, 'depth': 6, 'l2_leaf_reg': 4.956501788555065, 'random_strength': 3.107590252240029, 'border_count': 85, 'one_hot_max_size': 11, 'min_data_in_leaf': 24, 'leaf_estimation_iterations': 7, 'subsample': 0.8970529319280551, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 8 with value: 0.9160992854954184.
# [I 2026-03-30 16:24:52,802] Trial 10 finished with value: 0.9156736035103348 and parameters: {'learning_rate': 0.021579765081812557, 'depth': 4, 'l2_leaf_reg': 1.0322406318787363, 'random_strength': 5.720969826568013, 'border_count': 128, 'one_hot_max_size': 16, 'min_data_in_leaf': 200, 'leaf_estimation_iterations': 9, 'subsample': 0.8865404799529143, 'auto_class_weights': None}. Best is trial 8 with value: 0.9160992854954184.
# [I 2026-03-30 16:29:07,554] Trial 11 finished with value: 0.9160509553652039 and parameters: {'learning_rate': 0.03972076041741954, 'depth': 5, 'l2_leaf_reg': 44.58492975545845, 'random_strength': 5.191451337927788, 'border_count': 114, 'one_hot_max_size': 6, 'min_data_in_leaf': 48, 'leaf_estimation_iterations': 4, 'subsample': 0.6161587058750185, 'auto_class_weights': None}. Best is trial 8 with value: 0.9160992854954184.
# [I 2026-03-30 16:33:47,344] Trial 12 finished with value: 0.9161155752771537 and parameters: {'learning_rate': 0.03802793169601997, 'depth': 5, 'l2_leaf_reg': 21.080730962239258, 'random_strength': 5.281367573634923, 'border_count': 117, 'one_hot_max_size': 4, 'min_data_in_leaf': 37, 'leaf_estimation_iterations': 5, 'subsample': 0.7406311731633091, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 16:49:06,882] Trial 13 finished with value: 0.9156035416235483 and parameters: {'learning_rate': 0.02502020707890716, 'depth': 4, 'l2_leaf_reg': 16.207342509869253, 'random_strength': 7.171362427227098, 'border_count': 119, 'one_hot_max_size': 2, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 7, 'subsample': 0.7527471492716175, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 16:52:36,736] Trial 14 finished with value: 0.9160306946804362 and parameters: {'learning_rate': 0.03556659078126137, 'depth': 5, 'l2_leaf_reg': 23.347785971406594, 'random_strength': 4.234143276816553, 'border_count': 98, 'one_hot_max_size': 16, 'min_data_in_leaf': 32, 'leaf_estimation_iterations': 8, 'subsample': 0.7392795408032312, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 16:56:12,755] Trial 15 finished with value: 0.9156786527389545 and parameters: {'learning_rate': 0.016092719672314983, 'depth': 5, 'l2_leaf_reg': 10.982083627125306, 'random_strength': 8.05911361015379, 'border_count': 117, 'one_hot_max_size': 7, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 4, 'subsample': 0.856640294114403, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 16:59:48,467] Trial 16 finished with value: 0.9157598193556578 and parameters: {'learning_rate': 0.02741876833269164, 'depth': 4, 'l2_leaf_reg': 19.62517227724588, 'random_strength': 6.064112994108553, 'border_count': 122, 'one_hot_max_size': 14, 'min_data_in_leaf': 61, 'leaf_estimation_iterations': 5, 'subsample': 0.676366671027804, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:02:07,021] Trial 17 finished with value: 0.9160412585784478 and parameters: {'learning_rate': 0.04147783309525101, 'depth': 5, 'l2_leaf_reg': 27.888836138349287, 'random_strength': 1.8219490802601137, 'border_count': 94, 'one_hot_max_size': 8, 'min_data_in_leaf': 33, 'leaf_estimation_iterations': 7, 'subsample': 0.7774147903394871, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:12:57,376] Trial 18 finished with value: 0.9157356945830338 and parameters: {'learning_rate': 0.03018155867135477, 'depth': 4, 'l2_leaf_reg': 10.585579148737146, 'random_strength': 4.29203323680003, 'border_count': 102, 'one_hot_max_size': 2, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 4, 'subsample': 0.9866811296655869, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:16:04,819] Trial 19 finished with value: 0.9156245788944866 and parameters: {'learning_rate': 0.01195322163602112, 'depth': 6, 'l2_leaf_reg': 3.3549892486045843, 'random_strength': 8.311582543195021, 'border_count': 107, 'one_hot_max_size': 5, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 8, 'subsample': 0.9303457892705804, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:18:44,368] Trial 20 finished with value: 0.915973523231006 and parameters: {'learning_rate': 0.03666826924958102, 'depth': 5, 'l2_leaf_reg': 30.03217565525319, 'random_strength': 6.5121922861538915, 'border_count': 92, 'one_hot_max_size': 14, 'min_data_in_leaf': 157, 'leaf_estimation_iterations': 5, 'subsample': 0.7093698043112541, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:20:48,299] Trial 21 finished with value: 0.9160665763477546 and parameters: {'learning_rate': 0.03967626684420057, 'depth': 5, 'l2_leaf_reg': 47.890406852873866, 'random_strength': 4.979448604235502, 'border_count': 115, 'one_hot_max_size': 5, 'min_data_in_leaf': 50, 'leaf_estimation_iterations': 4, 'subsample': 0.6356139551908111, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:22:39,660] Trial 22 finished with value: 0.9160966626370364 and parameters: {'learning_rate': 0.04460039895004488, 'depth': 5, 'l2_leaf_reg': 31.68416788320951, 'random_strength': 4.646713343570202, 'border_count': 119, 'one_hot_max_size': 4, 'min_data_in_leaf': 47, 'leaf_estimation_iterations': 3, 'subsample': 0.6718365378046436, 'auto_class_weights': None}. Best is trial 12 with value: 0.9161155752771537.
# [I 2026-03-30 17:24:28,105] Trial 23 finished with value: 0.9161227647262068 and parameters: {'learning_rate': 0.04649150891687105, 'depth': 5, 'l2_leaf_reg': 13.372865186876775, 'random_strength': 4.502282595139979, 'border_count': 121, 'one_hot_max_size': 9, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 3, 'subsample': 0.6590247058420889, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:26:08,005] Trial 24 finished with value: 0.9161053583316532 and parameters: {'learning_rate': 0.0462680601254936, 'depth': 4, 'l2_leaf_reg': 11.94171184321645, 'random_strength': 3.8706317296929424, 'border_count': 127, 'one_hot_max_size': 9, 'min_data_in_leaf': 69, 'leaf_estimation_iterations': 3, 'subsample': 0.7845347965534804, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:27:30,466] Trial 25 finished with value: 0.9156930098225861 and parameters: {'learning_rate': 0.04658683549548224, 'depth': 3, 'l2_leaf_reg': 11.044068263928501, 'random_strength': 2.6436535981106823, 'border_count': 128, 'one_hot_max_size': 8, 'min_data_in_leaf': 69, 'leaf_estimation_iterations': 1, 'subsample': 0.6494676455317494, 'auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:29:21,951] Trial 26 finished with value: 0.9160619473727263 and parameters: {'learning_rate': 0.04798309720603677, 'depth': 4, 'l2_leaf_reg': 8.568800745686097, 'random_strength': 4.004865553708051, 'border_count': 123, 'one_hot_max_size': 9, 'min_data_in_leaf': 123, 'leaf_estimation_iterations': 3, 'subsample': 0.7152747821825661, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:31:18,041] Trial 27 finished with value: 0.9160249059779962 and parameters: {'learning_rate': 0.041224168401983695, 'depth': 4, 'l2_leaf_reg': 14.427649022347563, 'random_strength': 2.315079775932912, 'border_count': 112, 'one_hot_max_size': 7, 'min_data_in_leaf': 71, 'leaf_estimation_iterations': 2, 'subsample': 0.8008644037509498, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:33:08,786] Trial 28 finished with value: 0.916103682992763 and parameters: {'learning_rate': 0.0455445607518329, 'depth': 4, 'l2_leaf_reg': 3.653854275213029, 'random_strength': 3.537724656853135, 'border_count': 128, 'one_hot_max_size': 10, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 3, 'subsample': 0.8303917748746725, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:34:40,410] Trial 29 finished with value: 0.915570290897819 and parameters: {'learning_rate': 0.038275727212065784, 'depth': 3, 'l2_leaf_reg': 15.043101532133424, 'random_strength': 4.452879451039172, 'border_count': 108, 'one_hot_max_size': 12, 'min_data_in_leaf': 58, 'leaf_estimation_iterations': 1, 'subsample': 0.726400096814378, 'auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:37:56,725] Trial 30 finished with value: 0.9154910150748098 and parameters: {'learning_rate': 0.03201303056568505, 'depth': 3, 'l2_leaf_reg': 11.260334634144458, 'random_strength': 3.876624984654915, 'border_count': 124, 'one_hot_max_size': 3, 'min_data_in_leaf': 38, 'leaf_estimation_iterations': 2, 'subsample': 0.7681745641553983, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:39:46,347] Trial 31 finished with value: 0.9160925073913923 and parameters: {'learning_rate': 0.04363062885593577, 'depth': 4, 'l2_leaf_reg': 3.0010701665554134, 'random_strength': 3.5262565141295985, 'border_count': 128, 'one_hot_max_size': 10, 'min_data_in_leaf': 39, 'leaf_estimation_iterations': 3, 'subsample': 0.8374393220125556, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:41:29,341] Trial 32 finished with value: 0.9160683145693245 and parameters: {'learning_rate': 0.046997157471793734, 'depth': 4, 'l2_leaf_reg': 4.310617351668126, 'random_strength': 2.5033720278425906, 'border_count': 117, 'one_hot_max_size': 10, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 3, 'subsample': 0.830553424091992, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:43:11,626] Trial 33 finished with value: 0.915991399221346 and parameters: {'learning_rate': 0.042835270628302516, 'depth': 4, 'l2_leaf_reg': 1.9737160423207378, 'random_strength': 4.864257967762755, 'border_count': 125, 'one_hot_max_size': 9, 'min_data_in_leaf': 54, 'leaf_estimation_iterations': 2, 'subsample': 0.8548802588962668, 'auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:45:09,362] Trial 34 finished with value: 0.9160895664002509 and parameters: {'learning_rate': 0.049616073675734534, 'depth': 5, 'l2_leaf_reg': 8.973570884529742, 'random_strength': 3.4923259043212154, 'border_count': 121, 'one_hot_max_size': 13, 'min_data_in_leaf': 69, 'leaf_estimation_iterations': 4, 'subsample': 0.6000573712552915, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:46:59,980] Trial 35 finished with value: 0.9158203068203289 and parameters: {'learning_rate': 0.04548913507779938, 'depth': 4, 'l2_leaf_reg': 6.1886623155262095, 'random_strength': 5.366661292801826, 'border_count': 69, 'one_hot_max_size': 7, 'min_data_in_leaf': 100, 'leaf_estimation_iterations': 5, 'subsample': 0.7945817311414376, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:48:30,425] Trial 36 finished with value: 0.9157797569036676 and parameters: {'learning_rate': 0.04957228157770889, 'depth': 3, 'l2_leaf_reg': 18.99536282053855, 'random_strength': 2.929287741706734, 'border_count': 125, 'one_hot_max_size': 10, 'min_data_in_leaf': 44, 'leaf_estimation_iterations': 2, 'subsample': 0.6921106983804297, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:50:24,267] Trial 37 finished with value: 0.9159915472250034 and parameters: {'learning_rate': 0.04170618847158628, 'depth': 6, 'l2_leaf_reg': 3.888432871368874, 'random_strength': 1.1076145214118247, 'border_count': 111, 'one_hot_max_size': 18, 'min_data_in_leaf': 78, 'leaf_estimation_iterations': 3, 'subsample': 0.6474594696508746, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:52:22,638] Trial 38 finished with value: 0.9159928930235341 and parameters: {'learning_rate': 0.04673429377764486, 'depth': 5, 'l2_leaf_reg': 2.188261626632097, 'random_strength': 1.9803723785409553, 'border_count': 116, 'one_hot_max_size': 6, 'min_data_in_leaf': 28, 'leaf_estimation_iterations': 4, 'subsample': 0.8132980803098815, 'auto_class_weights': 'Balanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:53:59,567] Trial 39 finished with value: 0.9160250390642364 and parameters: {'learning_rate': 0.03938715136904631, 'depth': 4, 'l2_leaf_reg': 7.570802649683556, 'random_strength': 6.41072326326961, 'border_count': 128, 'one_hot_max_size': 12, 'min_data_in_leaf': 117, 'leaf_estimation_iterations': 1, 'subsample': 0.7855011036857191, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:55:55,117] Trial 40 finished with value: 0.9160318693460653 and parameters: {'learning_rate': 0.04325997081799567, 'depth': 5, 'l2_leaf_reg': 25.648283823031885, 'random_strength': 3.7665764182250125, 'border_count': 88, 'one_hot_max_size': 8, 'min_data_in_leaf': 40, 'leaf_estimation_iterations': 2, 'subsample': 0.8868848619835319, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 17:58:02,342] Trial 41 finished with value: 0.9160656473115173 and parameters: {'learning_rate': 0.03293103374739713, 'depth': 5, 'l2_leaf_reg': 17.78298856821634, 'random_strength': 5.676675134324888, 'border_count': 120, 'one_hot_max_size': 15, 'min_data_in_leaf': 22, 'leaf_estimation_iterations': 6, 'subsample': 0.7397660126711425, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 18:00:09,091] Trial 42 finished with value: 0.9161048093249328 and parameters: {'learning_rate': 0.035002351767238295, 'depth': 5, 'l2_leaf_reg': 12.898181464049456, 'random_strength': 5.955395116105471, 'border_count': 124, 'one_hot_max_size': 19, 'min_data_in_leaf': 17, 'leaf_estimation_iterations': 6, 'subsample': 0.7659069806755423, 'auto_class_weights': None}. Best is trial 23 with value: 0.9161227647262068.
# [I 2026-03-30 18:02:26,277] Trial 43 finished with value: 0.9161306135695655 and parameters: {'learning_rate': 0.03485124959818271, 'depth': 6, 'l2_leaf_reg': 12.959359562492697, 'random_strength': 4.676114862424672, 'border_count': 125, 'one_hot_max_size': 18, 'min_data_in_leaf': 18, 'leaf_estimation_iterations': 6, 'subsample': 0.7598252911349714, 'auto_class_weights': None}. Best is trial 43 with value: 0.9161306135695655.
# [I 2026-03-30 18:04:40,069] Trial 44 finished with value: 0.9161442502478016 and parameters: {'learning_rate': 0.03533040759652355, 'depth': 6, 'l2_leaf_reg': 13.766003057670106, 'random_strength': 6.401978316354332, 'border_count': 124, 'one_hot_max_size': 19, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 6, 'subsample': 0.7652360437462804, 'auto_class_weights': None}. Best is trial 44 with value: 0.9161442502478016.
# [I 2026-03-30 18:06:56,639] Trial 45 finished with value: 0.915916547562308 and parameters: {'learning_rate': 0.03199194516312619, 'depth': 6, 'l2_leaf_reg': 13.920414252689634, 'random_strength': 6.435737357237729, 'border_count': 80, 'one_hot_max_size': 17, 'min_data_in_leaf': 10, 'leaf_estimation_iterations': 5, 'subsample': 0.7548067071547091, 'auto_class_weights': None}. Best is trial 44 with value: 0.9161442502478016.
# [I 2026-03-30 18:09:17,944] Trial 46 finished with value: 0.916046037397461 and parameters: {'learning_rate': 0.02838609552651174, 'depth': 6, 'l2_leaf_reg': 22.39969213198922, 'random_strength': 5.261750620506632, 'border_count': 112, 'one_hot_max_size': 19, 'min_data_in_leaf': 12, 'leaf_estimation_iterations': 7, 'subsample': 0.7214805766607223, 'auto_class_weights': 'SqrtBalanced'}. Best is trial 44 with value: 0.9161442502478016.
# [I 2026-03-30 18:11:28,181] Trial 47 finished with value: 0.9160951383842505 and parameters: {'learning_rate': 0.03712678662513708, 'depth': 6, 'l2_leaf_reg': 35.00968147771151, 'random_strength': 4.755409689688954, 'border_count': 104, 'one_hot_max_size': 20, 'min_data_in_leaf': 19, 'leaf_estimation_iterations': 6, 'subsample': 0.8083469253994551, 'auto_class_weights': None}. Best is trial 44 with value: 0.9161442502478016.
# [I 2026-03-30 18:13:51,184] Trial 48 finished with value: 0.9160131228855297 and parameters: {'learning_rate': 0.024434435993264003, 'depth': 6, 'l2_leaf_reg': 13.035711218195152, 'random_strength': 7.766942837593996, 'border_count': 119, 'one_hot_max_size': 18, 'min_data_in_leaf': 13, 'leaf_estimation_iterations': 7, 'subsample': 0.6885472432317968, 'auto_class_weights': None}. Best is trial 44 with value: 0.9161442502478016.
# [I 2026-03-30 18:16:19,018] Trial 49 finished with value: 0.9161018717579642 and parameters: {'learning_rate': 0.03445947204786962, 'depth': 6, 'l2_leaf_reg': 8.886826662163655, 'random_strength': 6.796312165082804, 'border_count': 125, 'one_hot_max_size': 17, 'min_data_in_leaf': 15, 'leaf_estimation_iterations': 9, 'subsample': 0.7299893260811436, 'auto_class_weights': None}. Best is trial 44 with value: 0.9161442502478016.
# Best AUC: 0.9161442502478016
# Best Params: {'learning_rate': 0.03533040759652355, 'depth': 6, 'l2_leaf_reg': 13.766003057670106, 'random_strength': 6.401978316354332, 'border_count': 124, 'one_hot_max_size': 19, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 6, 'subsample': 0.7652360437462804, 'auto_class_weights': None}

# %% [markdown]
# ### Model Training: Stratified Cross-Validation
#
# Final training uses **5-fold StratifiedKFold**. Within each fold we:
#
# - Fit the feature engineering pipeline on the training split and transform validation/test (leakage prevention)
# - Train a `CatBoostClassifier` with early stopping on validation AUC
# - Store **OOF probabilities** and averaged **test probabilities** for ensembling
#
# The overall CV score is computed as ROC AUC on the full OOF vector.

# %%
# Cross-Validation Training Loop

cb_tuned_params = {
    **best_params,
    'iterations': 8000,
    'loss_function': 'Logloss',
    'eval_metric': 'AUC',
    'bootstrap_type': 'Bernoulli',
    'grow_policy': 'SymmetricTree',
    'allow_writing_files': False,
    'random_seed': seed,
    'verbose': 200,
    'metric_period': 20,
    'task_type': 'GPU' if USE_GPU else 'CPU',
}

print('Final CatBoost CV Training with OOF / Test probabilities')
print('========================================================')
print('Parameters used for training:')
print(cb_tuned_params)

cols_to_keep = list(optimal_cols) if optimal_cols is not None else None

n_folds = 5
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)

eval_results = []
models = []

oof_probs = np.zeros(len(y), dtype=np.float64)
test_probs = np.zeros(len(test_df), dtype=np.float64)

for fold, (train_idx, val_idx) in enumerate(skf.split(training_df, y)):
    print(f'Starting fold {fold+1}/{n_folds}...')

    X_train_fold = training_df.iloc[train_idx]
    y_train_fold = y.iloc[train_idx]

    X_val_fold = training_df.iloc[val_idx]
    y_val_fold = y.iloc[val_idx]

    fe_fold = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)

    X_train_trans = fe_fold.fit_transform(X_train_fold)
    X_val_trans = fe_fold.transform(X_val_fold)
    X_test_trans = fe_fold.transform(test_df)

    if cols_to_keep is not None:
        final_cols = [c for c in cols_to_keep if c in X_train_trans.columns]
        if not final_cols:
            raise RuntimeError('No overlap between optimal_cols and fold feature columns.')
        X_train_trans = X_train_trans[final_cols]
        X_val_trans   = X_val_trans[final_cols]
        X_test_trans  = X_test_trans[final_cols]

    cat_features_fold = fe_fold.get_cat_features(X_train_trans)
    if cols_to_keep is not None:
        cat_features_fold = [c for c in cat_features_fold if c in final_cols]
    
    train_pool = Pool(X_train_trans, y_train_fold, cat_features=cat_features_fold)
    val_pool   = Pool(X_val_trans, y_val_fold,   cat_features=cat_features_fold)
    test_pool  = Pool(X_test_trans,              cat_features=cat_features_fold)

    model = cb.CatBoostClassifier(**cb_tuned_params)

    model.fit(
        train_pool,
        eval_set=val_pool,
        early_stopping_rounds=200,
        verbose=200
    )

    eval_results.append(model.get_evals_result())
    models.append(model)

    val_prob = model.predict_proba(val_pool)[:, 1]
    oof_probs[val_idx] = val_prob

    fold_auc = roc_auc_score(y_val_fold, val_prob)
    print(f'Fold {fold+1} ROC AUC: {fold_auc:.6f}')

    test_prob_fold = model.predict_proba(test_pool)[:, 1]
    test_probs += test_prob_fold / n_folds

    del model, train_pool, val_pool
    gc.collect()
    
overall_auc = roc_auc_score(y, oof_probs)
print(f'Overall CV ROC AUC: {overall_auc:.6f}')
# Out:
# Final CatBoost CV Training with OOF / Test probabilities
# ========================================================
# Parameters used for training:
# {'learning_rate': 0.03533040759652355, 'depth': 6, 'l2_leaf_reg': 13.766003057670106, 'random_strength': 6.401978316354332, 'border_count': 124, 'one_hot_max_size': 19, 'min_data_in_leaf': 16, 'leaf_estimation_iterations': 6, 'subsample': 0.7652360437462804, 'auto_class_weights': None, 'iterations': 8000, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'allow_writing_files': False, 'random_seed': 10301, 'verbose': 200, 'metric_period': 20, 'task_type': 'GPU'}
# Starting fold 1/5...
# 0:	test: 0.8864716	best: 0.8864716 (0)	total: 14.9ms	remaining: 1m 59s
# 200:	test: 0.9132718	best: 0.9132718 (200)	total: 1.99s	remaining: 1m 17s
# 400:	test: 0.9141230	best: 0.9141230 (400)	total: 4.05s	remaining: 1m 16s
# 600:	test: 0.9148689	best: 0.9148689 (600)	total: 5.91s	remaining: 1m 12s
# 800:	test: 0.9152584	best: 0.9152584 (800)	total: 7.61s	remaining: 1m 8s
# 1000:	test: 0.9154852	best: 0.9154852 (1000)	total: 9.43s	remaining: 1m 5s
# 1200:	test: 0.9156003	best: 0.9156010 (1198)	total: 11.5s	remaining: 1m 5s
# 1400:	test: 0.9156690	best: 0.9156690 (1400)	total: 13.5s	remaining: 1m 3s
# 1600:	test: 0.9157148	best: 0.9157148 (1600)	total: 15.8s	remaining: 1m 3s
# 1800:	test: 0.9157510	best: 0.9157513 (1799)	total: 17.8s	remaining: 1m 1s
# 2000:	test: 0.9157765	best: 0.9157770 (1996)	total: 19.7s	remaining: 59s
# 2200:	test: 0.9157878	best: 0.9157900 (2194)	total: 21.7s	remaining: 57.1s
# 2400:	test: 0.9157822	best: 0.9157910 (2359)	total: 23.5s	remaining: 54.9s
# bestTest = 0.9157910347
# bestIteration = 2359
# Shrink model to first 2360 iterations.
# Fold 1 ROC AUC: 0.915791
# Starting fold 2/5...
# 0:	test: 0.8870670	best: 0.8870670 (0)	total: 12.8ms	remaining: 1m 42s
# 200:	test: 0.9135331	best: 0.9135331 (200)	total: 2.12s	remaining: 1m 22s
# 400:	test: 0.9144323	best: 0.9144323 (400)	total: 4.16s	remaining: 1m 18s
# 600:	test: 0.9152182	best: 0.9152182 (600)	total: 6.04s	remaining: 1m 14s
# 800:	test: 0.9155430	best: 0.9155436 (798)	total: 7.91s	remaining: 1m 11s
# 1000:	test: 0.9157776	best: 0.9157776 (1000)	total: 9.73s	remaining: 1m 8s
# 1200:	test: 0.9159348	best: 0.9159348 (1200)	total: 11.8s	remaining: 1m 6s
# 1400:	test: 0.9160306	best: 0.9160306 (1399)	total: 13.8s	remaining: 1m 5s
# 1600:	test: 0.9160962	best: 0.9160977 (1590)	total: 15.6s	remaining: 1m 2s
# 1800:	test: 0.9161311	best: 0.9161344 (1793)	total: 17.8s	remaining: 1m 1s
# 2000:	test: 0.9161578	best: 0.9161592 (1984)	total: 19.7s	remaining: 59.1s
# 2200:	test: 0.9161620	best: 0.9161711 (2125)	total: 21.8s	remaining: 57.5s
# bestTest = 0.9161710739
# bestIteration = 2125
# Shrink model to first 2126 iterations.
# Fold 2 ROC AUC: 0.916171
# Starting fold 3/5...
# 0:	test: 0.8863713	best: 0.8863713 (0)	total: 14.9ms	remaining: 1m 59s
# 200:	test: 0.9132284	best: 0.9132284 (200)	total: 2.17s	remaining: 1m 24s
# 400:	test: 0.9140456	best: 0.9140456 (400)	total: 4.15s	remaining: 1m 18s
# 600:	test: 0.9148233	best: 0.9148233 (600)	total: 6.1s	remaining: 1m 15s
# 800:	test: 0.9151609	best: 0.9151609 (800)	total: 8.33s	remaining: 1m 14s
# 1000:	test: 0.9153787	best: 0.9153787 (1000)	total: 10.6s	remaining: 1m 14s
# 1200:	test: 0.9155159	best: 0.9155159 (1200)	total: 12.7s	remaining: 1m 11s
# 1400:	test: 0.9156164	best: 0.9156164 (1400)	total: 15.1s	remaining: 1m 11s
# 1600:	test: 0.9156765	best: 0.9156765 (1600)	total: 17s	remaining: 1m 7s
# 1800:	test: 0.9157154	best: 0.9157158 (1799)	total: 20.2s	remaining: 1m 9s
# 2000:	test: 0.9157400	best: 0.9157433 (1987)	total: 22.7s	remaining: 1m 8s
# bestTest = 0.9157432616
# bestIteration = 1987
# Shrink model to first 1988 iterations.
# Fold 3 ROC AUC: 0.915743
# Starting fold 4/5...
# 0:	test: 0.8870644	best: 0.8870644 (0)	total: 23.3ms	remaining: 3m 6s
# 200:	test: 0.9130958	best: 0.9130958 (200)	total: 1.89s	remaining: 1m 13s
# 400:	test: 0.9138995	best: 0.9138995 (400)	total: 3.61s	remaining: 1m 8s
# 600:	test: 0.9147120	best: 0.9147120 (600)	total: 5.49s	remaining: 1m 7s
# 800:	test: 0.9151216	best: 0.9151217 (799)	total: 7.38s	remaining: 1m 6s
# 1000:	test: 0.9153420	best: 0.9153420 (1000)	total: 9.33s	remaining: 1m 5s
# 1200:	test: 0.9154937	best: 0.9154937 (1200)	total: 11.6s	remaining: 1m 5s
# 1400:	test: 0.9155956	best: 0.9155978 (1395)	total: 14.2s	remaining: 1m 6s
# 1600:	test: 0.9156679	best: 0.9156686 (1584)	total: 16.5s	remaining: 1m 5s
# 1800:	test: 0.9157173	best: 0.9157196 (1783)	total: 18.9s	remaining: 1m 4s
# 2000:	test: 0.9157579	best: 0.9157579 (2000)	total: 21.3s	remaining: 1m 3s
# 2200:	test: 0.9157965	best: 0.9157965 (2199)	total: 23.5s	remaining: 1m 1s
# 2400:	test: 0.9157960	best: 0.9158015 (2312)	total: 26s	remaining: 1m
# 2600:	test: 0.9157999	best: 0.9158053 (2470)	total: 28.3s	remaining: 58.8s
# 2800:	test: 0.9158040	best: 0.9158086 (2776)	total: 30.3s	remaining: 56.3s
# 3000:	test: 0.9158209	best: 0.9158235 (2988)	total: 32.3s	remaining: 53.8s
# 3200:	test: 0.9158174	best: 0.9158263 (3085)	total: 34.5s	remaining: 51.8s
# bestTest = 0.9158262908
# bestIteration = 3085
# Shrink model to first 3086 iterations.
# Fold 4 ROC AUC: 0.915826
# Starting fold 5/5...
# 0:	test: 0.8881129	best: 0.8881129 (0)	total: 13.7ms	remaining: 1m 49s
# 200:	test: 0.9144594	best: 0.9144594 (200)	total: 1.96s	remaining: 1m 16s
# 400:	test: 0.9153204	best: 0.9153204 (400)	total: 3.75s	remaining: 1m 11s
# 600:	test: 0.9161457	best: 0.9161457 (600)	total: 5.72s	remaining: 1m 10s
# 800:	test: 0.9165246	best: 0.9165246 (800)	total: 7.89s	remaining: 1m 10s
# 1000:	test: 0.9167408	best: 0.9167408 (1000)	total: 9.56s	remaining: 1m 6s
# 1200:	test: 0.9168788	best: 0.9168788 (1199)	total: 11.6s	remaining: 1m 5s
# 1400:	test: 0.9169745	best: 0.9169746 (1399)	total: 13.7s	remaining: 1m 4s
# 1600:	test: 0.9170460	best: 0.9170460 (1600)	total: 15.9s	remaining: 1m 3s
# 1800:	test: 0.9170836	best: 0.9170847 (1743)	total: 18.1s	remaining: 1m 2s
# 2000:	test: 0.9171086	best: 0.9171086 (2000)	total: 20.3s	remaining: 1m
# 2200:	test: 0.9171368	best: 0.9171368 (2200)	total: 22.6s	remaining: 59.5s
# 2400:	test: 0.9171458	best: 0.9171485 (2381)	total: 24.6s	remaining: 57.4s
# 2600:	test: 0.9171477	best: 0.9171570 (2506)	total: 27s	remaining: 56s
# bestTest = 0.9171569645
# bestIteration = 2506
# Shrink model to first 2507 iterations.
# Fold 5 ROC AUC: 0.917157
# Overall CV ROC AUC: 0.916131

# %% [markdown]
# ### Model Evaluation
#
# We evaluate using **ROC AUC**, matching the competition metric. AUC measures how well the model ranks positive cases above negative cases across all possible thresholds.
#
# OOF probabilities are used for an unbiased CV estimate.

# %% [markdown]
# ## Visualizing Model Performance
#
# We use a few diagnostic plots based on out-of-fold probabilities and per-fold training history.

# %% [markdown]
# ### Learning Curves (Train vs. Validation AUC)
# This plot shows the AUC over boosting iterations for the training and validation sets. A widening gap can indicate overfitting; a flat curve suggests diminishing returns.

# %%
mviz = ModelVisualizer(model_name='CatBoost')

mviz.plot_learning_curves(eval_results, metric='auc')

# %% [markdown]
# ### Feature Importance
# Average feature importance across folds. This is a sanity check (not a causal explanation).

# %%
mviz.plot_feature_importance(models, show_values=True)

# %% [markdown]
# ### ROC Curve (OOF)
# The ROC curve is plotted using out-of-fold probabilities. This is a quick visual check of separability and AUC.

# %%
mviz.plot_roc_curve(y_true=y, y_score=oof_probs, title='CatBoost OOF ROC Curve')

# %% [markdown]
# ### Confusion Matrix (OOF at 0.5 threshold)
# AUC is threshold-free, but a confusion matrix at a fixed threshold can help sanity-check error modes.

# %%
oof_pred_label = (oof_probs >= 0.5).astype(int)
mviz.plot_confusion_matrix(y_true=y, y_pred=oof_pred_label, classes=[0,1], normalize=True, title='CatBoost OOF Confusion Matrix (Normalized)')
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## Prepare Submission
#
# We write a submission file using the competition's sample submission schema. The submission value is the **predicted probability** of heart disease presence.

# %%
submission_df = helper.read_dataset('submission')

# Identify the prediction column from the sample submission
pred_col = [c for c in submission_df.columns if c != 'id'][0]

submission_df[pred_col] = test_probs

print('SAMPLE SUBMISSION')
display(submission_df.head())
# Out:
# SAMPLE SUBMISSION
#        id  Churn
# 0  594194  0.063
# 1  594195  0.001
# 2  594196  0.091
# 3  594197  0.003
# 4  594198  0.524

# %%
submission_df.to_csv('submission.csv', index=False)
print('Saved: submission.csv')
# Out:
# Saved: submission.csv

# %% [markdown]
# ## Save OOF and Test Probabilities
#
# Out-of-fold (OOF) probabilities and averaged test-set probabilities are saved for downstream ensembling (blending/stacking).
#
# Each file contains un-thresholded probabilities, which is essential for ROC AUC evaluation and weighted blending.

# %%
# Ensure directory exists
output_dir = 'predictions'
os.makedirs(output_dir, exist_ok=True)

# Save OOF probabilities and Test probabilities for blending/stacking
oof_df = pd.DataFrame({
    'id': training_df['id'].values,
    'prob_catboost': oof_probs,
    'target': y.values
})
oof_df.to_csv(f'{output_dir}/catboost_oof_probs.csv', index=False)

test_prob_df = pd.DataFrame({
    'id': test_df['id'].values,
    'prob_catboost': test_probs
})
test_prob_df.to_csv(f'{output_dir}/catboost_test_probs.csv', index=False)

print(f'Saved for ensembling:\n - {output_dir}/catboost_oof_probs.csv\n - {output_dir}/catboost_test_probs.csv')
# Out:
# Saved for ensembling:
#  - predictions/catboost_oof_probs.csv
#  - predictions/catboost_test_probs.csv

# %% [markdown]
# ### PS-S06E03: LightGBM

# %% [markdown]
# This notebook tackles the [**Playground Series – Season 6, Episode 3: Predict Customer Churn**](https://www.kaggle.com/competitions/playground-series-s6e3), a competition focused on predicting if a customer is likely to cancel their subscription, based on features describing the customer's demographics and services used by them.

# %% [markdown]
# ## Introduction

# %% [markdown]
# **LightGBM** distinguishes itself with a "leaf-wise" (best-first) tree growth strategy, contrasting with the traditional "level-wise" (depth-wise) approach used by XGBoost. This allows it to converge faster and often capture more complex, non-linear dependencies in physiological data. It handles missing values internally and is highly optimized for memory efficiency and training speed. While LightGBM has native support for categorical features, we will utilize our refined feature engineering pipeline to ensure robust inputs.
#
# The notebook is one of a number of notebooks that explore various models to address this challenge, with the ultimate goal of ensembling these diverse learners. The EDA for this dataset was performed in this notebook: [**PS-S06E03: EDA**](https://www.kaggle.com/code/stephentarter/ps-s06e03-eda).

# %% [markdown]
# ## Install Needed Packages

# %%
# %pip install --no-binary lightgbm --config-settings=cmake.define.USE_CUDA=ON lightgbm
# Out:
# Requirement already satisfied: lightgbm in /home/tarter/anaconda3/envs/tf-new-gpu/lib/python3.9/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17.0 in /home/tarter/anaconda3/envs/tf-new-gpu/lib/python3.9/site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in /home/tarter/anaconda3/envs/tf-new-gpu/lib/python3.9/site-packages (from lightgbm) (1.13.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import gc
import sys
import math
import random
import warnings
from pathlib import Path
from typing import Iterable
from IPython.display import display, Markdown, IFrame

# --- Third-party
import numpy as np
import pandas as pd
import lightgbm as lgb
import optuna
from optuna.exceptions import TrialPruned
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import mean_squared_error, roc_auc_score
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt
import seaborn as sns

from ps_s06e03_feature_engineering import FeatureFactory
from ps_s06e03_model_visualizer import ModelVisualizer
from ps_s06e03_experiment_setup import ExperimentSetup

# Notebook settings
warnings.filterwarnings('ignore')

# %matplotlib inline

import ipywidgets as widgets
widgets.IntProgress()
# Out:
# IntProgress(value=0)

# %%
helper = ExperimentSetup()

# Get the seed, and apply it to all the internals like pandas and numpy
seed = helper.set_seeds()

helper.configure_pandas()
helper.suppress_warnings()

# The target feature
TARGET = 'Churn'

# Show GPU be utilized in training
USE_GPU = False

# Optuna tuning should be performed in the pipeline
PERFORM_OPTUNA_TUNING = False
# Out:
# Random seed set to: 10301
# Warnings suppressed.

# %% [markdown]
# ## Read and Examine the Training Dataset

# %%
training_df = helper.read_dataset("training")
# Out:
# TRAINING DATASET
# ================
#
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1            No             DSL            Yes          Yes               No
# 2           Yes     Fiber optic             No          Yes               No
# 3            No     Fiber optic             No           No               No
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges Churn
# 0             Mailed check          60.100     1,653.850    No
# 1  Credit card (automatic)          69.500     3,778.200    No
# 2         Electronic check         100.400     5,841.350    No
# 3         Electronic check          69.700        70.700   Yes
# 4         Electronic check          70.450        70.450   Yes

# %% [markdown]
# ## Read and Examine the Test Dataset

# %%
test_df = helper.read_dataset("test")
# Out:
# TEST DATASET
# ============
#
#        id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  594194  Female              0     Yes         No      72          Yes
# 1  594195  Female              0     Yes         No      71          Yes
# 2  594196    Male              0      No         No      12          Yes
# 3  594197    Male              0     Yes        Yes      71          Yes
# 4  594198  Female              0      No         No      15          Yes
#
#   MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0           Yes     Fiber optic                  Yes                  Yes
# 1            No              No  No internet service  No internet service
# 2            No             DSL                  Yes                  Yes
# 3           Yes             DSL                  Yes                   No
# 4            No     Fiber optic                  Yes                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                  Yes                  Yes                  Yes
# 1  No internet service  No internet service  No internet service
# 2                   No                   No                   No
# 3                  Yes                  Yes                  Yes
# 4                   No                   No                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                  Yes        Two year              Yes
# 1  No internet service        Two year               No
# 2                   No  Month-to-month              Yes
# 3                  Yes        Two year               No
# 4                  Yes  Month-to-month               No
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0           Electronic check         115.550     8,061.500
# 1  Bank transfer (automatic)          19.800     1,336.500
# 2  Bank transfer (automatic)          55.550       633.550
# 3    Credit card (automatic)          84.100     6,457.150
# 4           Electronic check          90.350     1,233.650

# %% [markdown]
# ## Feature Engineering

# %%
# Define which strategies to use for the LightGBM model here:
fe_strategies = [
    'drop_id',
    'encoding',
    'ratios',
    'interactions',
    'binning'
]

# %%
print('Performing initial feature engineering.')

# Get the target before we start messing with features
y = training_df[TARGET].map({"No": 0, "Yes": 1}).astype("int8")

# Initialize and apply the feature factory
feature_engineer = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)

# Fit_transform on training, transform on test
X = feature_engineer.fit_transform(training_df)
X_test = feature_engineer.transform(test_df)

# Get categorical columns (original + engineered) from FeatureFactory
cat_cols = feature_engineer.get_cat_features(X)
cat_cols = [c for c in cat_cols if c in X.columns]

# LightGBM prefers 'category' dtype for native categorical handling
for c in cat_cols:
    X[c] = X[c].astype('category')
    X_test[c] = X_test[c].astype('category')
    
print(f'Old Feature Count: {training_df.shape[1] - 1}')
print(f'New Feature Count: {X.shape[1]}')
print(X.head())
# Out:
# Performing initial feature engineering.
# Old Feature Count: 20
# New Feature Count: 31
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0     Yes        Yes      29          Yes
# 1    Male              0     Yes        Yes      58          Yes
# 2    Male              0     Yes         No      58          Yes
# 3  Female              0      No         No       1          Yes
# 4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL            Yes           No              Yes
# 1            No             DSL            Yes          Yes               No
# 2           Yes     Fiber optic             No          Yes               No
# 3            No     Fiber optic             No           No               No
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0             Mailed check          60.100     1,653.850
# 1  Credit card (automatic)          69.500     3,778.200
# 2         Electronic check         100.400     5,841.350
# 3         Electronic check          69.700        70.700
# 4         Electronic check          70.450        70.450
#
#    Total_Addon_Services Contract_Code  Avg_Cost_Per_Month_Tenure  \
# 0                     3             1                      2.003
# 1                     4             2                      1.178
# 2                     3             0                      1.702
# 3                     0             0                     34.850
# 4                     0             0                     35.225
#
#    Expected_Total  Charges_Gap  Cost_Per_Service  num_services  \
# 0       1,742.900      -89.050            15.025             3
# 1       4,031.000     -252.800            13.900             4
# 2       5,823.200       18.150            25.100             3
# 3          69.700        1.000            69.700             0
# 4          70.450        0.000            70.450             0
#
#    cost_per_service  charges_per_tenure  total_service_count  \
# 0            15.025               2.003                    5
# 1            13.900               1.178                    6
# 2            25.100               1.702                    6
# 3            69.700              34.850                    2
# 4            70.450              35.225                    2
#
#    tenure_month_to_month tenure_group
# 0                      0  Established
# 1                      0  Established
# 2                     58  Established
# 3                      1          New
# 4                      1          New

# %% [markdown]
# ## Optuna Tuning

# %%
print("Precomputing fold-wise FE for Optuna (once)...")

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
fold_cache = []

for fold, (train_idx, val_idx) in enumerate(skf.split(training_df, y)):
    X_train_fold = training_df.iloc[train_idx].copy()
    X_val_fold   = training_df.iloc[val_idx].copy()
    y_train_fold = y.iloc[train_idx].copy()
    y_val_fold   = y.iloc[val_idx].copy()

    fe = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed + fold)
    X_train_trans = fe.fit_transform(X_train_fold)
    X_val_trans   = fe.transform(X_val_fold)

    cat_cols = X_train_trans.select_dtypes(include=["category", "object"]).columns.tolist()
    cat_cols = [c for c in cat_cols if c in X_val_trans.columns]

    fold_cache.append((X_train_trans, y_train_fold, X_val_trans, y_val_fold, cat_cols, val_idx))

print("Cached folds:", len(fold_cache))
# Out:
# Precomputing fold-wise FE for Optuna (once)...
# Cached folds: 5

# %%
n_jobs = 6

def objective(trial):
    params = {
        'n_estimators': 1200,
        'boosting_type': 'gbdt',
        'objective': 'binary',
        'metric': 'auc',
        'learning_rate': trial.suggest_float('learning_rate', 0.02, 0.08, log=True),
    
        'num_leaves': trial.suggest_int('num_leaves', 20, 64),
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'min_child_samples': trial.suggest_int('min_child_samples', 50, 200),

        'subsample': trial.suggest_float('subsample', 0.8, 1.0),
        'subsample_freq': trial.suggest_int('subsample_freq', 1, 3),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.8, 1.0),
    
        'reg_alpha': trial.suggest_float('reg_alpha', 1.0, 50.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1.0, 50.0, log=True),

        'feature_pre_filter': False,
        'force_col_wise': True,

        'random_state': seed,
        # 'device_type': 'gpu' if USE_GPU else 'cpu',
        'device_type': 'cpu',  # Forcing for Optuna training
        'n_jobs': n_jobs,
        'verbosity': -1,
    }

    # Set additional parameters if on GPU
    if params['device_type'] == 'gpu':
        params['gpu_platform_id'] =  0
        params['gpu_device_id'] = 0

    oof = np.zeros(len(y), dtype=float)

    for X_train_trans, y_train_fold, X_val_trans, y_val_fold, cat_cols, val_idx in fold_cache:
        # LightGBM requires categorical features to be 'category' dtype, not 'object'
        for col in cat_cols:
            if col in X_train_trans.columns:
                X_train_trans[col] = X_train_trans[col].astype('category')
                X_val_trans[col] = X_val_trans[col].astype('category')
                
        model = lgb.LGBMClassifier(**params)

        model.fit(
            X_train_trans, y_train_fold,
            eval_set=[(X_val_trans, y_val_fold)],
            categorical_feature=cat_cols,
            callbacks=[
                lgb.early_stopping(25, verbose=False)
            ]
        )
    
        oof[val_idx] = model.predict_proba(X_val_trans, num_iteration=model.best_iteration_)[:,1]

        del model
        gc.collect()
        
    return roc_auc_score(y, oof)

# %%
if PERFORM_OPTUNA_TUNING:
    print('Starting LightGBM Optuna Optimization...')
    
    # Use MedianPruner for efficiency
    pruner = optuna.pruners.MedianPruner(
        n_startup_trials=5,
        n_warmup_steps=1
    )
    
    study_lgbm = optuna.create_study(
        direction='maximize',
        study_name='lgbm_predict_customer_churn_optuna', 
        pruner=pruner
    )
    
    study_lgbm.optimize(
        objective,
        n_trials=50,
        show_progress_bar=True,
        timeout=18000,  # 5 hours
    )
    
    print('\nBest Trial:')
    print(f'  AUC: {study_lgbm.best_value:.5f}')
    print('  Params: ', study_lgbm.best_params)
    
    lgbm_best_params = study_lgbm.best_params
else:
    lgbm_best_params = {
        'learning_rate': 0.06194485684474406,
        'num_leaves': 27,
        'max_depth': 4,
        'min_child_samples': 111,
        'subsample': 0.9346769375036541,
        'subsample_freq': 1,
        'colsample_bytree': 0.884678520389216,
        'reg_alpha': 10.213097622281925,
        'reg_lambda': 10.319872544971782
    }
    
    print('\nUsing earlier calculated params:')
    print('  Params: ', lgbm_best_params)
# Out:
# [I 2026-03-31 12:32:45,917] A new study created in memory with name: lgbm_predict_customer_churn_optuna
# Starting LightGBM Optuna Optimization...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-03-31 12:35:23,133] Trial 0 finished with value: 0.9163399253126812 and parameters: {'learning_rate': 0.06271425278581304, 'num_leaves': 44, 'max_depth': 4, 'min_child_samples': 160, 'subsample': 0.81019421925044, 'subsample_freq': 2, 'colsample_bytree': 0.984786173063886, 'reg_alpha': 14.705853408026115, 'reg_lambda': 25.20008403939593}. Best is trial 0 with value: 0.9163399253126812.
# [I 2026-03-31 12:37:59,823] Trial 1 finished with value: 0.9163093537404969 and parameters: {'learning_rate': 0.03620535372102048, 'num_leaves': 27, 'max_depth': 4, 'min_child_samples': 57, 'subsample': 0.9290710963492418, 'subsample_freq': 1, 'colsample_bytree': 0.877030733232572, 'reg_alpha': 1.1936373136186849, 'reg_lambda': 1.238382607848354}. Best is trial 0 with value: 0.9163399253126812.
# [I 2026-03-31 12:39:45,814] Trial 2 finished with value: 0.9162978093552998 and parameters: {'learning_rate': 0.045363146301784264, 'num_leaves': 49, 'max_depth': 7, 'min_child_samples': 51, 'subsample': 0.8505928787081198, 'subsample_freq': 3, 'colsample_bytree': 0.8338695562680467, 'reg_alpha': 1.9614835895315372, 'reg_lambda': 2.2546027342385826}. Best is trial 0 with value: 0.9163399253126812.
# [I 2026-03-31 12:42:07,502] Trial 3 finished with value: 0.916348041954186 and parameters: {'learning_rate': 0.03842225122026498, 'num_leaves': 52, 'max_depth': 7, 'min_child_samples': 189, 'subsample': 0.8629070996789132, 'subsample_freq': 2, 'colsample_bytree': 0.9346723447936741, 'reg_alpha': 6.320455728919306, 'reg_lambda': 4.596286898420479}. Best is trial 3 with value: 0.916348041954186.
# [I 2026-03-31 12:45:08,072] Trial 4 finished with value: 0.9162068344741692 and parameters: {'learning_rate': 0.03761455595799431, 'num_leaves': 27, 'max_depth': 8, 'min_child_samples': 181, 'subsample': 0.8462067403006722, 'subsample_freq': 2, 'colsample_bytree': 0.9941179259505679, 'reg_alpha': 28.590578163628827, 'reg_lambda': 3.8904623302096617}. Best is trial 3 with value: 0.916348041954186.
# [I 2026-03-31 12:47:52,548] Trial 5 finished with value: 0.9162157758288212 and parameters: {'learning_rate': 0.054618213047887686, 'num_leaves': 64, 'max_depth': 3, 'min_child_samples': 176, 'subsample': 0.9640940570288974, 'subsample_freq': 3, 'colsample_bytree': 0.9871478133243873, 'reg_alpha': 10.092238117061536, 'reg_lambda': 2.666028695346366}. Best is trial 3 with value: 0.916348041954186.
# [I 2026-03-31 12:50:51,837] Trial 6 finished with value: 0.9164060861119888 and parameters: {'learning_rate': 0.04304543615674313, 'num_leaves': 39, 'max_depth': 5, 'min_child_samples': 195, 'subsample': 0.9997678528912092, 'subsample_freq': 2, 'colsample_bytree': 0.8647274550489512, 'reg_alpha': 3.2278796868316304, 'reg_lambda': 7.248448881522785}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 12:52:05,380] Trial 7 finished with value: 0.916337841928927 and parameters: {'learning_rate': 0.07735117817307784, 'num_leaves': 44, 'max_depth': 8, 'min_child_samples': 163, 'subsample': 0.9734822270885886, 'subsample_freq': 2, 'colsample_bytree': 0.8096487030702165, 'reg_alpha': 7.671631106423034, 'reg_lambda': 2.4459571595650753}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 12:54:43,341] Trial 8 finished with value: 0.9156016184774894 and parameters: {'learning_rate': 0.03251656203121754, 'num_leaves': 30, 'max_depth': 3, 'min_child_samples': 147, 'subsample': 0.8125897820196182, 'subsample_freq': 2, 'colsample_bytree': 0.9905433330065925, 'reg_alpha': 30.838550486158773, 'reg_lambda': 1.35150466572141}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 12:56:13,772] Trial 9 finished with value: 0.9162861661002946 and parameters: {'learning_rate': 0.06696630579452736, 'num_leaves': 54, 'max_depth': 8, 'min_child_samples': 141, 'subsample': 0.9203848696797027, 'subsample_freq': 2, 'colsample_bytree': 0.9098015426353459, 'reg_alpha': 14.634673817266908, 'reg_lambda': 15.021210768349007}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 12:59:26,964] Trial 10 finished with value: 0.9162224202013273 and parameters: {'learning_rate': 0.022764708330180003, 'num_leaves': 36, 'max_depth': 5, 'min_child_samples': 112, 'subsample': 0.9850418870206683, 'subsample_freq': 1, 'colsample_bytree': 0.8652441768344238, 'reg_alpha': 3.286202862082156, 'reg_lambda': 9.866477882183647}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 13:02:32,924] Trial 11 finished with value: 0.9162775613834607 and parameters: {'learning_rate': 0.027858179921232074, 'num_leaves': 57, 'max_depth': 6, 'min_child_samples': 195, 'subsample': 0.8833551188860015, 'subsample_freq': 3, 'colsample_bytree': 0.928147109654459, 'reg_alpha': 4.260342748083785, 'reg_lambda': 6.20127899800098}. Best is trial 6 with value: 0.9164060861119888.
# [I 2026-03-31 13:05:03,116] Trial 12 finished with value: 0.9164112104443836 and parameters: {'learning_rate': 0.045514653971861094, 'num_leaves': 37, 'max_depth': 5, 'min_child_samples': 200, 'subsample': 0.8893426353196585, 'subsample_freq': 1, 'colsample_bytree': 0.9531560264265415, 'reg_alpha': 3.8535148452001766, 'reg_lambda': 6.896552737780591}. Best is trial 12 with value: 0.9164112104443836.
# [I 2026-03-31 13:07:36,210] Trial 13 finished with value: 0.9164564833856745 and parameters: {'learning_rate': 0.0478676193625588, 'num_leaves': 20, 'max_depth': 5, 'min_child_samples': 109, 'subsample': 0.9336707910396832, 'subsample_freq': 1, 'colsample_bytree': 0.9503233750128686, 'reg_alpha': 2.5495236128535104, 'reg_lambda': 10.991136547426617}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:09:50,199] Trial 14 finished with value: 0.9163792257286769 and parameters: {'learning_rate': 0.051017523193877125, 'num_leaves': 20, 'max_depth': 6, 'min_child_samples': 102, 'subsample': 0.9330257484249079, 'subsample_freq': 1, 'colsample_bytree': 0.9574254995598631, 'reg_alpha': 1.05909095880288, 'reg_lambda': 42.652741470237714}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:12:15,821] Trial 15 finished with value: 0.9164234896817431 and parameters: {'learning_rate': 0.05179462086943676, 'num_leaves': 20, 'max_depth': 4, 'min_child_samples': 86, 'subsample': 0.8970323637730364, 'subsample_freq': 1, 'colsample_bytree': 0.9522238814378378, 'reg_alpha': 1.9066238649192744, 'reg_lambda': 15.093728957726608}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:14:45,192] Trial 16 finished with value: 0.9164505719255933 and parameters: {'learning_rate': 0.05462174649351351, 'num_leaves': 21, 'max_depth': 4, 'min_child_samples': 82, 'subsample': 0.9448798406470471, 'subsample_freq': 1, 'colsample_bytree': 0.9494284041773986, 'reg_alpha': 1.933221086359951, 'reg_lambda': 14.903363844317617}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:16:56,578] Trial 17 finished with value: 0.9164018324133926 and parameters: {'learning_rate': 0.05940613655801003, 'num_leaves': 32, 'max_depth': 4, 'min_child_samples': 81, 'subsample': 0.9543100213097523, 'subsample_freq': 1, 'colsample_bytree': 0.8979458714942862, 'reg_alpha': 1.9650977132675156, 'reg_lambda': 22.757895359986886}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:19:12,243] Trial 18 finished with value: 0.9163698850640131 and parameters: {'learning_rate': 0.0799766752185227, 'num_leaves': 25, 'max_depth': 3, 'min_child_samples': 121, 'subsample': 0.9431418259076629, 'subsample_freq': 1, 'colsample_bytree': 0.9234534113794488, 'reg_alpha': 2.1809299005164533, 'reg_lambda': 46.68403395644123}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:22:01,200] Trial 19 finished with value: 0.9163927440769456 and parameters: {'learning_rate': 0.03151879790055845, 'num_leaves': 24, 'max_depth': 6, 'min_child_samples': 74, 'subsample': 0.9125463488995691, 'subsample_freq': 1, 'colsample_bytree': 0.9627646837551368, 'reg_alpha': 1.430418139989123, 'reg_lambda': 13.415335706798318}. Best is trial 13 with value: 0.9164564833856745.
# [I 2026-03-31 13:23:50,866] Trial 20 finished with value: 0.9164652875059162 and parameters: {'learning_rate': 0.06779573629667998, 'num_leaves': 32, 'max_depth': 5, 'min_child_samples': 100, 'subsample': 0.9501862906367253, 'subsample_freq': 1, 'colsample_bytree': 0.8946561057976948, 'reg_alpha': 5.3915740082325, 'reg_lambda': 26.87081364942049}. Best is trial 20 with value: 0.9164652875059162.
# [I 2026-03-31 13:25:28,537] Trial 21 finished with value: 0.9164072741647824 and parameters: {'learning_rate': 0.06985704670356988, 'num_leaves': 32, 'max_depth': 5, 'min_child_samples': 97, 'subsample': 0.9539930467205433, 'subsample_freq': 1, 'colsample_bytree': 0.8944791365292662, 'reg_alpha': 5.34046685571413, 'reg_lambda': 24.324112171444714}. Best is trial 20 with value: 0.9164652875059162.
# [I 2026-03-31 13:27:52,534] Trial 22 finished with value: 0.9164419959071377 and parameters: {'learning_rate': 0.057581331132126094, 'num_leaves': 22, 'max_depth': 4, 'min_child_samples': 127, 'subsample': 0.9441736156417746, 'subsample_freq': 1, 'colsample_bytree': 0.9367426167088183, 'reg_alpha': 2.41261859226238, 'reg_lambda': 30.59259678504509}. Best is trial 20 with value: 0.9164652875059162.
# [I 2026-03-31 13:29:30,049] Trial 23 finished with value: 0.9164255057833833 and parameters: {'learning_rate': 0.06820677470026022, 'num_leaves': 30, 'max_depth': 5, 'min_child_samples': 66, 'subsample': 0.9073946979884532, 'subsample_freq': 1, 'colsample_bytree': 0.912313932207698, 'reg_alpha': 3.0045629310776327, 'reg_lambda': 18.063130931075293}. Best is trial 20 with value: 0.9164652875059162.
# [I 2026-03-31 13:31:32,663] Trial 24 finished with value: 0.9164100750161044 and parameters: {'learning_rate': 0.049598270204587395, 'num_leaves': 23, 'max_depth': 6, 'min_child_samples': 92, 'subsample': 0.9780318769490893, 'subsample_freq': 1, 'colsample_bytree': 0.9720339224821384, 'reg_alpha': 5.2165502700047215, 'reg_lambda': 11.066249008355697}. Best is trial 20 with value: 0.9164652875059162.
# [I 2026-03-31 13:33:51,758] Trial 25 finished with value: 0.9164931884245671 and parameters: {'learning_rate': 0.06194485684474406, 'num_leaves': 27, 'max_depth': 4, 'min_child_samples': 111, 'subsample': 0.9346769375036541, 'subsample_freq': 1, 'colsample_bytree': 0.884678520389216, 'reg_alpha': 10.213097622281925, 'reg_lambda': 10.319872544971782}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:35:36,746] Trial 26 finished with value: 0.9164496949531541 and parameters: {'learning_rate': 0.06422577355208992, 'num_leaves': 34, 'max_depth': 5, 'min_child_samples': 108, 'subsample': 0.9207969996036907, 'subsample_freq': 1, 'colsample_bytree': 0.8767416407069152, 'reg_alpha': 9.551661564948922, 'reg_lambda': 9.38290983240689}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:37:11,197] Trial 27 finished with value: 0.9163464372798308 and parameters: {'learning_rate': 0.07204326999131316, 'num_leaves': 27, 'max_depth': 7, 'min_child_samples': 124, 'subsample': 0.9638730583391361, 'subsample_freq': 1, 'colsample_bytree': 0.8409876262471847, 'reg_alpha': 20.051326233453924, 'reg_lambda': 32.18184586270543}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:39:35,076] Trial 28 finished with value: 0.9158884679212923 and parameters: {'learning_rate': 0.0601047091853031, 'num_leaves': 39, 'max_depth': 3, 'min_child_samples': 136, 'subsample': 0.8714510740421819, 'subsample_freq': 2, 'colsample_bytree': 0.8864073809944222, 'reg_alpha': 48.087828926995385, 'reg_lambda': 18.910094141911383}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:41:56,614] Trial 29 finished with value: 0.9163566746389525 and parameters: {'learning_rate': 0.04678079236000327, 'num_leaves': 29, 'max_depth': 4, 'min_child_samples': 111, 'subsample': 0.9306738920743978, 'subsample_freq': 1, 'colsample_bytree': 0.8531106374414177, 'reg_alpha': 13.301550262418276, 'reg_lambda': 34.18492652487436}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:44:48,997] Trial 30 finished with value: 0.9163315463115129 and parameters: {'learning_rate': 0.04083852069735103, 'num_leaves': 41, 'max_depth': 4, 'min_child_samples': 153, 'subsample': 0.996556592485, 'subsample_freq': 2, 'colsample_bytree': 0.9098227842373212, 'reg_alpha': 7.978938615038296, 'reg_lambda': 5.1782062255228585}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:46:51,237] Trial 31 finished with value: 0.9164400826684057 and parameters: {'learning_rate': 0.05511314904083291, 'num_leaves': 20, 'max_depth': 5, 'min_child_samples': 75, 'subsample': 0.9472089035226239, 'subsample_freq': 1, 'colsample_bytree': 0.972691342289671, 'reg_alpha': 1.4846889945710091, 'reg_lambda': 11.86996389217549}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:48:55,388] Trial 32 finished with value: 0.9164455414959797 and parameters: {'learning_rate': 0.06264866182210974, 'num_leaves': 25, 'max_depth': 4, 'min_child_samples': 91, 'subsample': 0.9367485245969929, 'subsample_freq': 1, 'colsample_bytree': 0.9380798322913374, 'reg_alpha': 2.608707022391696, 'reg_lambda': 8.191577931660218}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:50:50,257] Trial 33 finished with value: 0.9164570591550008 and parameters: {'learning_rate': 0.05366530110161635, 'num_leaves': 23, 'max_depth': 5, 'min_child_samples': 101, 'subsample': 0.9572383593148628, 'subsample_freq': 1, 'colsample_bytree': 0.9170338629904142, 'reg_alpha': 5.65773265026405, 'reg_lambda': 19.04261844152251}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:52:23,536] Trial 34 finished with value: 0.9164258510972668 and parameters: {'learning_rate': 0.0751171262161849, 'num_leaves': 26, 'max_depth': 6, 'min_child_samples': 117, 'subsample': 0.9607890487356113, 'subsample_freq': 1, 'colsample_bytree': 0.8830454546347246, 'reg_alpha': 10.940710620665746, 'reg_lambda': 20.027617560433338}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:54:31,030] Trial 35 finished with value: 0.9164529988295822 and parameters: {'learning_rate': 0.04857888825021261, 'num_leaves': 29, 'max_depth': 5, 'min_child_samples': 105, 'subsample': 0.9206066566216375, 'subsample_freq': 1, 'colsample_bytree': 0.9183510474043322, 'reg_alpha': 5.93091936329623, 'reg_lambda': 26.322525872162245}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:56:55,431] Trial 36 finished with value: 0.9164471293214003 and parameters: {'learning_rate': 0.042021585056652135, 'num_leaves': 47, 'max_depth': 5, 'min_child_samples': 133, 'subsample': 0.9758184411020243, 'subsample_freq': 1, 'colsample_bytree': 0.9018772231156815, 'reg_alpha': 4.522723078541319, 'reg_lambda': 3.7585313010621464}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 13:58:33,863] Trial 37 finished with value: 0.9164024976379007 and parameters: {'learning_rate': 0.06348350293271654, 'num_leaves': 23, 'max_depth': 7, 'min_child_samples': 99, 'subsample': 0.9062627554549306, 'subsample_freq': 3, 'colsample_bytree': 0.8578786134209182, 'reg_alpha': 6.814467516231946, 'reg_lambda': 17.143711089783217}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:00:53,285] Trial 38 finished with value: 0.9164008713504853 and parameters: {'learning_rate': 0.05603465276627585, 'num_leaves': 28, 'max_depth': 6, 'min_child_samples': 63, 'subsample': 0.9848894164878934, 'subsample_freq': 2, 'colsample_bytree': 0.8740365170349653, 'reg_alpha': 18.958211353872503, 'reg_lambda': 12.88404240164069}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:03:45,187] Trial 39 finished with value: 0.9164564285779405 and parameters: {'learning_rate': 0.04434444694208389, 'num_leaves': 33, 'max_depth': 5, 'min_child_samples': 117, 'subsample': 0.9677041450504543, 'subsample_freq': 2, 'colsample_bytree': 0.8202231122294571, 'reg_alpha': 8.098101495590745, 'reg_lambda': 38.71296570785796}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:06:08,671] Trial 40 finished with value: 0.9162684379044863 and parameters: {'learning_rate': 0.03517567427881188, 'num_leaves': 35, 'max_depth': 4, 'min_child_samples': 93, 'subsample': 0.8226723198930208, 'subsample_freq': 1, 'colsample_bytree': 0.8894045401102635, 'reg_alpha': 12.295583492288895, 'reg_lambda': 8.212331359890685}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:08:42,498] Trial 41 finished with value: 0.9164436633754272 and parameters: {'learning_rate': 0.05216329962218792, 'num_leaves': 33, 'max_depth': 5, 'min_child_samples': 129, 'subsample': 0.9698907008484766, 'subsample_freq': 2, 'colsample_bytree': 0.8171025439634579, 'reg_alpha': 8.285286693985672, 'reg_lambda': 36.779162068343155}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:11:33,659] Trial 42 finished with value: 0.9163837625721588 and parameters: {'learning_rate': 0.043491886918816, 'num_leaves': 31, 'max_depth': 5, 'min_child_samples': 118, 'subsample': 0.9557169540747118, 'subsample_freq': 3, 'colsample_bytree': 0.8253866721145372, 'reg_alpha': 17.646724132015887, 'reg_lambda': 49.90696302651765}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:14:26,207] Trial 43 finished with value: 0.9164311476199299 and parameters: {'learning_rate': 0.039303765707748343, 'num_leaves': 27, 'max_depth': 5, 'min_child_samples': 110, 'subsample': 0.9897689562643663, 'subsample_freq': 2, 'colsample_bytree': 0.805404373135718, 'reg_alpha': 9.895370027372143, 'reg_lambda': 24.675867307330133}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:16:48,273] Trial 44 finished with value: 0.916415851319486 and parameters: {'learning_rate': 0.047106017584987725, 'num_leaves': 38, 'max_depth': 6, 'min_child_samples': 115, 'subsample': 0.9257629852759821, 'subsample_freq': 2, 'colsample_bytree': 0.8409661579819478, 'reg_alpha': 6.508294598772881, 'reg_lambda': 40.5258973348446}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:19:19,708] Trial 45 finished with value: 0.9160224928368215 and parameters: {'learning_rate': 0.04377439010032281, 'num_leaves': 42, 'max_depth': 3, 'min_child_samples': 102, 'subsample': 0.9675566610338041, 'subsample_freq': 3, 'colsample_bytree': 0.9414104094944202, 'reg_alpha': 3.844395187053617, 'reg_lambda': 27.719049146346823}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:22:05,178] Trial 46 finished with value: 0.916124579906874 and parameters: {'learning_rate': 0.020498297701297942, 'num_leaves': 23, 'max_depth': 5, 'min_child_samples': 105, 'subsample': 0.9386840918855007, 'subsample_freq': 1, 'colsample_bytree': 0.9034180077009349, 'reg_alpha': 5.018045189783679, 'reg_lambda': 20.312438657245785}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:25:00,080] Trial 47 finished with value: 0.9162958048596213 and parameters: {'learning_rate': 0.037445793139317694, 'num_leaves': 60, 'max_depth': 4, 'min_child_samples': 164, 'subsample': 0.9525186566659711, 'subsample_freq': 2, 'colsample_bytree': 0.9255559913071342, 'reg_alpha': 8.368995431738396, 'reg_lambda': 9.836018645638559}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:26:13,817] Trial 48 finished with value: 0.9163380629616275 and parameters: {'learning_rate': 0.07284185371979206, 'num_leaves': 45, 'max_depth': 6, 'min_child_samples': 141, 'subsample': 0.9801639952784874, 'subsample_freq': 1, 'colsample_bytree': 0.8712940312364129, 'reg_alpha': 3.546818364368661, 'reg_lambda': 16.145473351985466}. Best is trial 25 with value: 0.9164931884245671.
# [I 2026-03-31 14:28:01,212] Trial 49 finished with value: 0.9164484323624915 and parameters: {'learning_rate': 0.05214537402764421, 'num_leaves': 25, 'max_depth': 5, 'min_child_samples': 85, 'subsample': 0.9293681971908135, 'subsample_freq': 1, 'colsample_bytree': 0.8539486829337599, 'reg_alpha': 2.899251510324923, 'reg_lambda': 1.9406730283958447}. Best is trial 25 with value: 0.9164931884245671.
#
# Best Trial:
#   AUC: 0.91649
#   Params:  {'learning_rate': 0.06194485684474406, 'num_leaves': 27, 'max_depth': 4, 'min_child_samples': 111, 'subsample': 0.9346769375036541, 'subsample_freq': 1, 'colsample_bytree': 0.884678520389216, 'reg_alpha': 10.213097622281925, 'reg_lambda': 10.319872544971782}

# %% [markdown]
# ## Model Training

# %%
# Build LGB parameters from best_params
lgb_tuned_params = {
    **lgbm_best_params,
    'n_estimators': 20000,
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'n_jobs': n_jobs,
    'random_state': seed,
    'device_type': 'gpu' if USE_GPU else 'cpu',
    'verbosity': -1,
}

# Set additional parameters if on GPU
if lgb_tuned_params['device_type'] == 'gpu':
    lgb_tuned_params['gpu_platform_id'] =  0
    lgb_tuned_params['gpu_device_id'] = 0

print('Final LightGBM CV Training with OOF / Test probabilities')
print('======================================================')
print('Parameters used for training:')
print(lgb_tuned_params)
print(' ')

# Initialize Standard K-Fold
n_folds = 5
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)

# Storage for plotting later
eval_results = []
models = []

# Arrays to store results
oof_probs = np.zeros(len(y), dtype=float)
test_probs = np.zeros(len(test_df), dtype=float)

for fold, (train_idx, val_idx) in enumerate(skf.split(training_df, y)):
    print(f'\nStarting processing of fold {fold+1}')

    X_train_fold = training_df.iloc[train_idx]
    X_val_fold = training_df.iloc[val_idx]
    y_train_fold = y.iloc[train_idx]
    y_val_fold = y.iloc[val_idx]

    fe = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
    X_train_trans = fe.fit_transform(X_train_fold)
    X_val_trans = fe.transform(X_val_fold)
    X_test_trans = fe.transform(test_df)
    
    cat_cols = X_train_trans.select_dtypes(include=["category", "object"]).columns.tolist()
    cat_cols = [c for c in cat_cols if c in X_val_trans.columns]

    # LightGBM requires categorical features to be 'category' dtype, not 'object'
    for col in cat_cols:
        if col in X_train_trans.columns:
            X_train_trans[col] = X_train_trans[col].astype('category')
            X_val_trans[col] = X_val_trans[col].astype('category')
            X_test_trans[col] = X_test_trans[col].astype('category')
            
    model = lgb.LGBMClassifier(**lgb_tuned_params)
    model.fit(
        X_train_trans, y_train_fold,
        eval_set=[(X_train_trans, y_train_fold), (X_val_trans, y_val_fold)],
        categorical_feature=cat_cols,
        callbacks=[
            lgb.early_stopping(200, verbose=False),
            lgb.log_evaluation(period=200)
        ]
    )
    
    # Store history
    eval_results.append(model.evals_result_)
    models.append(model)

    val_probs = model.predict_proba(X_val_trans, num_iteration=model.best_iteration_)[:,1]
    oof_probs[val_idx] = val_probs
    
    # Score this fold
    fold_auc = roc_auc_score(y_val_fold, val_probs)
    print(f'Fold {fold+1} AUC: {fold_auc:.5f} (best_iteration={model.best_iteration_})')
    
    batch_test_probs = model.predict_proba(X_test_trans, num_iteration=model.best_iteration_)[:,1]
    test_probs += batch_test_probs / skf.n_splits

    del model
    gc.collect()
    
# Final Metric Calculation
overall_auc = roc_auc_score(y, oof_probs)
print(f'\nOverall CV AUC: {overall_auc:.5f}')
# Out:
# Final LightGBM CV Training with OOF / Test probabilities
# ======================================================
# Parameters used for training:
# {'learning_rate': 0.06194485684474406, 'num_leaves': 27, 'max_depth': 4, 'min_child_samples': 111, 'subsample': 0.9346769375036541, 'subsample_freq': 1, 'colsample_bytree': 0.884678520389216, 'reg_alpha': 10.213097622281925, 'reg_lambda': 10.319872544971782, 'n_estimators': 20000, 'objective': 'binary', 'metric': 'auc', 'boosting_type': 'gbdt', 'n_jobs': 6, 'random_state': 10301, 'device_type': 'gpu', 'verbosity': -1, 'gpu_platform_id': 0, 'gpu_device_id': 0}
#
#
# Starting processing of fold 1
# [200]	training's auc: 0.915728	valid_1's auc: 0.914486
# [400]	training's auc: 0.917249	valid_1's auc: 0.915386
# [600]	training's auc: 0.918129	valid_1's auc: 0.915758
# [800]	training's auc: 0.918767	valid_1's auc: 0.915946
# [1000]	training's auc: 0.919301	valid_1's auc: 0.916015
# [1200]	training's auc: 0.919749	valid_1's auc: 0.916056
# [1400]	training's auc: 0.92013	valid_1's auc: 0.916085
# [1600]	training's auc: 0.920485	valid_1's auc: 0.91608
# Fold 1 AUC: 0.91609 (best_iteration=1445)
#
# Starting processing of fold 2
# [200]	training's auc: 0.915717	valid_1's auc: 0.914909
# [400]	training's auc: 0.91717	valid_1's auc: 0.91583
# [600]	training's auc: 0.918032	valid_1's auc: 0.916206
# [800]	training's auc: 0.918645	valid_1's auc: 0.916376
# [1000]	training's auc: 0.919153	valid_1's auc: 0.916492
# [1200]	training's auc: 0.919602	valid_1's auc: 0.91655
# [1400]	training's auc: 0.919996	valid_1's auc: 0.916569
# [1600]	training's auc: 0.92034	valid_1's auc: 0.916587
# Fold 2 AUC: 0.91659 (best_iteration=1583)
#
# Starting processing of fold 3
# [200]	training's auc: 0.915699	valid_1's auc: 0.914525
# [400]	training's auc: 0.917207	valid_1's auc: 0.915481
# [600]	training's auc: 0.918102	valid_1's auc: 0.915843
# [800]	training's auc: 0.918748	valid_1's auc: 0.916041
# [1000]	training's auc: 0.919273	valid_1's auc: 0.916147
# [1200]	training's auc: 0.919727	valid_1's auc: 0.916165
# Fold 3 AUC: 0.91617 (best_iteration=1156)
#
# Starting processing of fold 4
# [200]	training's auc: 0.915806	valid_1's auc: 0.914489
# [400]	training's auc: 0.917242	valid_1's auc: 0.915498
# [600]	training's auc: 0.918085	valid_1's auc: 0.915898
# [800]	training's auc: 0.918713	valid_1's auc: 0.916124
# [1000]	training's auc: 0.919214	valid_1's auc: 0.91623
# [1200]	training's auc: 0.919641	valid_1's auc: 0.916302
# [1400]	training's auc: 0.920038	valid_1's auc: 0.916322
# [1600]	training's auc: 0.920382	valid_1's auc: 0.916333
# Fold 4 AUC: 0.91634 (best_iteration=1514)
#
# Starting processing of fold 5
# [200]	training's auc: 0.915508	valid_1's auc: 0.915755
# [400]	training's auc: 0.916965	valid_1's auc: 0.916687
# [600]	training's auc: 0.917838	valid_1's auc: 0.917104
# [800]	training's auc: 0.918472	valid_1's auc: 0.917272
# [1000]	training's auc: 0.918988	valid_1's auc: 0.917375
# [1200]	training's auc: 0.919428	valid_1's auc: 0.917436
# [1400]	training's auc: 0.919828	valid_1's auc: 0.91746
# [1600]	training's auc: 0.920185	valid_1's auc: 0.917445
# Fold 5 AUC: 0.91747 (best_iteration=1413)
#
# Overall CV AUC: 0.91652

# %% [markdown]
# ## Visualize the Quality of Training
#
# It is standard practice to visualize Learning Curves (to spot overfitting/underfitting) and the ROC Curve (to check classification performance).
#
# ### Learning Curves (Train vs. Validation AUC)
#
# **Definition**
# This graph plots the model's performance (AUC) on the y-axis against the number of boosting rounds (iterations) on the x-axis. It displays two lines:
# *   **Blue (Train):** How well the model learned the data it has already seen.
# *   **Red (Validation):** How well the model generalizes to new data it hasn't seen.
#
# **Interpretation**
# This graph is fairly easy to interpret, and is a powerful indicator of how the model is likely to perform on new data.
# *   **Ideal:** Both lines go up steeply and plateau. The Blue line is slightly higher than the Red line, but the gap is stable.
# *   **Overfitting:** The Blue line keeps going up (approaching 1.0), but the Red line flattens out early or starts dropping. The "gap" between them widens significantly.
# *   **Underfitting:** Both lines flatten out very early at a low score. The model is too simple to learn the patterns.
#
# **Actions for Overfitting**
# If the Training score is 0.95 but the validation score is 0.72, the  are overfitting.
# 1.  **Restrict Depth:** Reduce `max_depth` (e.g., from 6 to 3 or 4). This forces the model to learn simpler, more general rules.
# 2.  **Add Randomness:** Lower `subsample` and `colsample_bytree` (e.g., to 0.6). This prevents the model from relying too heavily on specific rows or features.
# 3.  **Increase Regularization:** Increase `reg_alpha` (L1) or `reg_lambda` (L2). This penalizes the model for becoming too complex.
# 4.  **Increase `min_child_weight`:** This prevents the tree from creating leaves that only apply to a tiny handful of patients (noise).

# %%
mviz = ModelVisualizer(model_name='LightGBM')

mviz.plot_learning_curves(eval_results, metric='auc')

# %% [markdown]
# ### Feature Importance (Gain)
#
# This chart ranks features by how much they improved the model's accuracy (reduced the loss function) whenever they were used in a split.
#
# **Interpretation**
# *   **High Gain:** These are the "Signal" features. The model relies on them heavily.
# *   **Low/Zero Gain:** These features were rarely useful. The model mostly ignored them.
#
# **What if engineered features aren't at the top?**
# *   **Don't Panic:** It's okay if raw features like Glucose or BMI are still top. They are strong predictors!
# *   **Check Correlations:** If BMI is #1 and your engineered BMI\_Ratio is #50, they might be highly correlated, and the model just chose the simpler one. This is fine.
# *   **Re-evaluate:** If an engineered feature is at the very bottom (0 importance), it failed. The hypothesis behind it (e.g., "Age \* Height") likely has no biological relevance.
#
# **What to do with Low Performing Features**
# *   **Zero Importance:** **Drop them.** They add computational cost and noise without adding value.
# *   **Low Importance:**
#     *   **Try Dropping:** Sometimes removing "noise" features helps the model focus on the signal (increases score).
#
#     *   **Combine Them:** If SkinThickness is weak on its own, try creating an interaction like Insulin / SkinThickness. Sometimes two weak features make one strong feature.

# %%
mviz.plot_feature_importance(models, show_values=True)

# %%
# ROC on OOF
mviz.plot_roc_curve(y_true=y, y_score=oof_probs)

# %%
# Confusion matrix (threshold 0.5, adjust if needed)
y_hat = (oof_probs >= 0.5).astype(int)
mviz.plot_confusion_matrix(y_true=y, y_pred=y_hat, classes=[0, 1], normalize=True)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## Prepare Submission

# %%
submission_df = helper.read_dataset("submission")
submission_df[TARGET] = test_probs

print('SUBMISSION')
print('==========')

print(submission_df.head(10))
# Out:
# SUBMISSION
# ==========
#        id  Churn
# 0  594194  0.059
# 1  594195  0.001
# 2  594196  0.105
# 3  594197  0.003
# 4  594198  0.528
# 5  594199  0.164
# 6  594200  0.903
# 7  594201  0.002
# 8  594202  0.028
# 9  594203  0.321

# %%
submission_df.to_csv('submission.csv', index=False)
print('Saved: submission.csv')
# Out:
# Saved: submission.csv

# %% [markdown]
# ## Save OOF and Test Probabilities
#
# The OOF and test probabilities are saved so that they may be used for comparison of performance differences between the various models, or by a notebook exploring blending the probabilities of the models using some of the tools and techniques outline by Tilii in his excellent [For the (recovering) blind blending addicts](https://www.kaggle.com/competitions/playground-series-s5e12/discussion/651787).

# %%
# Ensure directory exists
output_dir = 'predictions'
os.makedirs(output_dir, exist_ok=True) 

# Save OOF probabilities and Test probabilities for blending/stacking
oof_df = pd.DataFrame({
    'id': training_df['id'].values,
    'prob_lgb': oof_probs,
    'target': y.values
})
oof_df.to_csv(f'{output_dir}/lgb_oof_probs.csv', index=False)

test_prob_df = pd.DataFrame({
    'id': test_df['id'].values,
    'prob_lgb': test_probs
})
test_prob_df.to_csv(f'{output_dir}/lgb_test_probs.csv', index=False)

print(f'Saved for Blending: {output_dir}/lgb_oof_probs.csv, {output_dir}/lgb_test_probs.csv')
# Out:
# Saved for Blending: predictions/lgb_oof_probs.csv, predictions/lgb_test_probs.csv

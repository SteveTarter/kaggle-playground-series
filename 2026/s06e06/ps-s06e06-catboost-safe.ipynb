# %% [markdown]
# # PS-S06E06: CatBoost

# %% [markdown]
# This notebook tackles the [**Playground Series – Season 6, Episode 6: Predicting Stellar Class**](https://www.kaggle.com/competitions/playground-series-s6e6), a competition focused on predicting a class label (`GALAXY`, `QSO`, `STAR`) for the `class` target, based on features describing the position, light intensity across SDSS photometric bands, redshift, spectral type, and galaxy population for each observed object.

# %% [markdown]
# CatBoost is a strong baseline for tabular problems and often complements XGBoost/LightGBM in ensembles because it handles categorical features natively and robustly — particularly useful here since `spectral_type` and `galaxy_population` are natural categoricals.
#
# In this notebook we:
# - Apply astronomy-domain feature engineering per fold (to avoid leakage)
# - Train a **CatBoostClassifier** using **Stratified 5-Fold Cross-Validation**
# - Optimize for **Balanced Accuracy**, the primary evaluation metric for this competition
# - Collect **Out-of-Fold (OOF) probabilities** and test-set predictions for downstream ensembling

# %% [markdown]
# ## Install Needed Packages

# %%
import os
import gc
import sys
import math
import time
import random
import warnings

# Third-party
import numpy as np
import pandas as pd
import catboost as cb
import optuna
from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit
from sklearn.metrics import balanced_accuracy_score
from catboost import CatBoostClassifier, Pool, EFstrType, EFeaturesSelectionAlgorithm, EShapCalcType

import matplotlib.pyplot as plt
import seaborn as sns

from ps_s06e06_feature_engineering import FeatureFactory
from ps_s06e06_model_visualizer import ModelVisualizer
from ps_s06e06_experiment_setup import ExperimentSetup

warnings.filterwarnings('ignore')

import ipywidgets as widgets
widgets.IntProgress()
# Out:
# IntProgress(value=0)

# %%
setup = ExperimentSetup(
    model_name='CatBoost',
    use_gpu=True,
    perform_rfe=True,
    perform_optuna_tuning=True
)

# Get the seed and apply it to all internals
seed = setup.set_seeds()

setup.configure_pandas()
setup.suppress_warnings()

# Target label column
TARGET = 'class'

# Class label mapping (must be consistent everywhere)
target_mapping = {'QSO': 0, 'STAR': 1, 'GALAXY': 2}
inverse_target_mapping = {v: k for k, v in target_mapping.items()}
# Out:
# Random seed set to: 10301
# Warnings suppressed.

# %% [markdown]
# ## Read and Examine the Training Dataset

# %%
training_df = setup.get_combined_training_data()
train_ids = training_df['id'].copy()
# Out:
# TRAINING DATASET
# ================
#
#    id   alpha  delta      u      g      r      i      z  redshift  \
# 0   0 147.734 16.959 25.472 21.896 20.358 19.257 18.621     0.409
# 1   1 127.989 32.347 20.779 19.087 17.587 17.226 16.786     0.158
# 2   2 179.793 35.345 21.035 21.079 21.172 20.583 20.557     2.824
# 3   3 225.818 48.569 23.305 21.051 19.018 18.366 17.915     0.536
# 4   4 141.836 19.343 21.703 19.472 18.234 17.899 17.616     0.556
#
#   spectral_type galaxy_population   class
# 0             M      Red_Sequence  GALAXY
# 1             M      Red_Sequence  GALAXY
# 2           O/B        Blue_Cloud     QSO
# 3             M      Red_Sequence  GALAXY
# 4             M      Red_Sequence  GALAXY

# %% [markdown]
# ## Read and Examine the Test Dataset

# %%
test_df = setup.read_dataset('test')
test_ids  = test_df['id'].copy()
# Out:
# TEST DATASET
# ============
#
#        id   alpha  delta      u      g      r      i      z  redshift  \
# 0  577347 120.720 23.924 23.668 21.952 21.086 20.180 19.202     0.429
# 1  577348 219.414 42.172 24.903 22.339 20.732 19.860 19.688     0.867
# 2  577349 173.569 -1.756 19.428 18.475 17.551 16.571 16.177     0.224
# 3  577350 184.904 -1.411 23.121 21.527 20.670 20.418 20.699     0.067
# 4  577351 222.488 15.381 25.094 22.644 21.123 19.440 19.094     0.977
#
#   spectral_type galaxy_population
# 0           G/K      Red_Sequence
# 1             M      Red_Sequence
# 2           G/K        Blue_Cloud
# 3           G/K      Red_Sequence
# 4             M      Red_Sequence

# %% [markdown]
# ## Feature Engineering Strategy
#
# We apply a set of feature engineering steps grounded in SDSS photometric and spectroscopic properties:
#
# - `encoding`: Casts `spectral_type` (ordered O/B→M) and `galaxy_population` (unordered) to CatBoost-native categorical dtype.
# - `colors`: Computes SDSS photometric color indices (`u-g`, `g-r`, `r-i`, `i-z`, and wider-baseline combos). These are the primary discriminators in color-color space.
# - `ratios`: SED shape features — mean/std magnitude across bands, spectral slope, and outer-to-central band ratio.
# - `redshift`: Redshift-derived features (`log1p`, squared, boolean flags) and color×redshift interaction terms. Redshift is the single strongest discriminator in this dataset.
# - `position`: Cartesian sky-coordinate projection and |δ|.
# - `interactions`: Higher-order cross products between the most discriminating features.
#
# **Categorical handling**: `spectral_type` and `galaxy_population` are passed directly to CatBoost as categoricals. CatBoost learns ordered statistics over them natively without one-hot encoding.

# %%
# Define which feature engineering strategies to use
fe_strategies = [
    'encoding',       # Cast spectral_type and galaxy_population to category dtype
    'colors',         # SDSS photometric color indices
    'ratios',         # SED shape features: mean/std magnitude, spectral slope
    'redshift',       # Redshift-derived features and color×redshift interactions
    'position',       # Sky-coordinate Cartesian projection and |delta|
    'interactions',   # Higher-order cross-feature products
    'flux',
    'numeric_expansion'
]

# %%
print('Performing initial feature engineering.')

# Initialize and apply the feature factory
feature_engineer = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)

# Encode target labels: QSO=0, STAR=1, GALAXY=2
y = training_df[TARGET].map(target_mapping).astype(int)

# Fit_transform on training, transform on test
X = feature_engineer.fit_transform(training_df)
X_test = feature_engineer.transform(test_df)

cat_features = feature_engineer.get_cat_features(X)
print(f'Feature Count: {X.shape[1]}')
print(f'CatBoost categorical features ({len(cat_features)}): {cat_features}')
print(f'Target sample: {y.head()}')
display(X.head())
# Out:
# Performing initial feature engineering.
# Feature Count: 61
# CatBoost categorical features (3): ['spectral_type', 'galaxy_population', 'sky_bin']
# Target sample: 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int64
#     alpha  delta      u      g      r      i      z  redshift spectral_type  \
# 0 147.734 16.959 25.472 21.896 20.358 19.257 18.621     0.409             M
# 1 127.989 32.347 20.779 19.087 17.587 17.226 16.786     0.158             M
# 2 179.793 35.345 21.035 21.079 21.172 20.583 20.557     2.824           O/B
# 3 225.818 48.569 23.305 21.051 19.018 18.366 17.915     0.536             M
# 4 141.836 19.343 21.703 19.472 18.234 17.899 17.616     0.556             M
#
#   galaxy_population  u_minus_g  g_minus_r  r_minus_i  i_minus_z  u_minus_r  \
# 0      Red_Sequence      3.577      1.538      1.101      0.636      5.114
# 1      Red_Sequence      1.691      1.500      0.361      0.440      3.191
# 2        Blue_Cloud     -0.044     -0.093      0.589      0.025     -0.137
# 3      Red_Sequence      2.254      2.033      0.652      0.451      4.287
# 4      Red_Sequence      2.231      1.237      0.335      0.283      3.469
#
#    u_minus_z  g_minus_z  g_minus_i  color_range  redshift_log1p  redshift_sq  \
# 0      6.851      3.275      2.638        6.851           0.343        0.167
# 1      3.992      2.301      1.861        3.992           0.147        0.025
# 2      0.478      0.522      0.496        0.478           1.341        7.974
# 3      5.390      3.136      2.685        5.390           0.429        0.287
# 4      4.087      1.855      1.572        4.087           0.442        0.309
#
#    is_near_zero_z  is_high_z  z_x_u_g  z_x_g_r  z_x_color_range  is_mid_z  \
# 0               0          0    1.463    0.629            2.802         1
# 1               0          0    0.267    0.237            0.631         1
# 2               0          1   -0.124   -0.262            1.349         0
# 3               0          0    1.209    1.090            2.890         0
# 4               0          0    1.240    0.688            2.271         0
#
#    pos_x  pos_y  pos_z  abs_delta  alpha_sin  alpha_cos  delta_sin  delta_cos  \
# 0 -0.809  0.511  0.292     16.959      0.534     -0.846      0.292      0.957
# 1 -0.520  0.666  0.535     32.347      0.788     -0.616      0.535      0.845
# 2 -0.816  0.003  0.578     35.345      0.004     -1.000      0.578      0.816
# 3 -0.461 -0.475  0.750     48.569     -0.717     -0.697      0.750      0.662
# 4 -0.742  0.583  0.331     19.343      0.618     -0.786      0.331      0.944
#
#    alpha_bin  delta_bin sky_bin  Log_alpha   alpha_sq  alpha_sqrt  Log_delta  \
# 0          9          6     9_6      5.002 21,825.410      12.155      2.888
# 1          8          9     8_9      4.860 16,381.102      11.313      3.507
# 2         11          9    11_9      5.197 32,325.396      13.409      3.593
# 3         15         12   15_12      5.424 50,993.902      15.027      3.903
# 4          9          6     9_6      4.962 20,117.489      11.909      3.013
#
#    delta_sq  delta_sqrt  Log_u    u_sq  u_sqrt  Log_g    g_sq  g_sqrt  Log_r  \
# 0   287.617       4.118  3.276 648.829   5.047  3.131 479.415   4.679  3.061
# 1 1,046.310       5.687  3.081 431.746   4.558  3.000 364.316   4.369  2.922
# 2 1,249.258       5.945  3.093 442.480   4.586  3.095 444.330   4.591  3.099
# 3 2,358.989       6.969  3.191 543.126   4.828  3.093 443.133   4.588  2.997
# 4   374.146       4.398  3.123 471.027   4.659  3.019 379.146   4.413  2.957
#
#      r_sq  r_sqrt  Log_i    i_sq  i_sqrt  Log_z    z_sq  z_sqrt  Log_redshift  \
# 0 414.445   4.512  3.009 370.836   4.388  2.977 346.744   4.315         0.343
# 1 309.310   4.194  2.903 296.737   4.150  2.878 281.784   4.097         0.147
# 2 448.247   4.601  3.072 423.645   4.537  3.071 422.605   4.534         1.341
# 3 361.675   4.361  2.964 337.297   4.286  2.940 320.946   4.233         0.429
# 4 332.495   4.270  2.939 320.390   4.231  2.924 310.330   4.197         0.442
#
#    redshift_sqrt
# 0          0.640
# 1          0.397
# 2          1.680
# 3          0.732
# 4          0.745

# %%
# Resolve categorical column list to those actually present after engineering
cat_cols = feature_engineer.get_cat_features(X)
cat_cols = [c for c in cat_cols if c in X.columns]
print(f'Categorical Features: {cat_cols}')

# CatBoost accepts categoricals as strings or integer codes. We use strings.
for c in cat_cols:
    X[c] = X[c].astype(str)
    X_test[c] = X_test[c].astype(str)
# Out:
# Categorical Features: ['spectral_type', 'galaxy_population', 'sky_bin']

# %% [markdown]
# ### Feature Selection (CatBoost Native)
#
# CatBoost's built-in `select_features` uses SHAP values to iteratively remove the weakest features. This is more appropriate than sklearn RFECV here because it respects the native categorical encoding and uses the same gradient-boosted objective as the final model.
#
# The selection runs on a stratified holdout split (not full CV) for speed, then the selected feature names are applied per-fold during training to prevent leakage.

# %%
n_jobs = 1 if setup.use_gpu() else -1
rfe_filename = 'selected_features_catboost.json'

optimal_cols = X.columns

if setup.perform_rfe():
    print('Running CatBoost native feature selection (RecursiveByShapValues)...')

    FS_STEPS = 20
    FS_EVAL_SPLIT = 0.2

    fe_fs = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
    X_fs = fe_fs.fit_transform(training_df)
    cat_features_fs = fe_fs.get_cat_features(X_fs)

    # Cast cats to string for CatBoost
    for c in cat_features_fs:
        if c in X_fs.columns:
            X_fs[c] = X_fs[c].astype(str)

    sss = StratifiedShuffleSplit(n_splits=1, test_size=FS_EVAL_SPLIT, random_state=seed)
    tr_idx, va_idx = next(sss.split(X_fs, y))

    X_tr_fs, y_tr_fs = X_fs.iloc[tr_idx], y.iloc[tr_idx]
    X_va_fs, y_va_fs = X_fs.iloc[va_idx], y.iloc[va_idx]

    train_pool_fs = Pool(X_tr_fs, y_tr_fs, cat_features=cat_features_fs)
    eval_pool_fs  = Pool(X_va_fs, y_va_fs, cat_features=cat_features_fs)

    fs_model = CatBoostClassifier(
        loss_function='MultiClass',
        eval_metric='TotalF1:average=Macro',
        classes_count=3,
        iterations=1000,
        learning_rate=0.05,
        depth=6,
        feature_border_type='UniformAndQuantiles',
        border_count=254,
        random_seed=seed,
        auto_class_weights='Balanced',
        task_type='GPU' if setup.use_gpu() else 'CPU',
        verbose=200,
        early_stopping_rounds=100,
        allow_writing_files=False,
    )

    fs_result = fs_model.select_features(
        train_pool_fs,
        eval_set=eval_pool_fs,
        features_for_select=list(range(X_tr_fs.shape[1])),
        num_features_to_select=int(X_tr_fs.shape[1] * 0.70),  # keep 70% (tune: 0.6–0.9)
        steps=FS_STEPS,
        algorithm=EFeaturesSelectionAlgorithm.RecursiveByShapValues,
        shap_calc_type=EShapCalcType.Regular,
        train_final_model=False,
        logging_level="Verbose",
        plot=False
    )

    print("\nEliminated Features:", fs_result['eliminated_features_names'])
    print("Selected Features count:", len(fs_result['selected_features_names']))

    loss_graph = fs_result['loss_graph']
    print("Loss values at each step:", loss_graph['loss_values'])

    selected_idx = fs_result["selected_features"]
    optimal_cols = [X_fs.columns[i] for i in selected_idx]
    print(f"\nSelected {len(optimal_cols)} / {X_fs.shape[1]} features.")

    setup.save_rfe(rfe_filename, pd.Index(optimal_cols))
else:
    optimal_cols = setup.load_rfe(rfe_filename, X)
# Out:
# Running CatBoost native feature selection (RecursiveByShapValues)...
# The number of features selection steps (20) is greater than the number of features to eliminate (19). The number of steps was reduced to 19.
# Step #1 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 20.5ms	remaining: 20.5s
# 200:	learn: 0.9568688	test: 0.9565555	best: 0.9565555 (200)	total: 2.83s	remaining: 11.2s
# 400:	learn: 0.9613686	test: 0.9598742	best: 0.9598742 (400)	total: 5.5s	remaining: 8.21s
# 600:	learn: 0.9629912	test: 0.9610181	best: 0.9610343 (589)	total: 8.1s	remaining: 5.38s
# 800:	learn: 0.9641418	test: 0.9618930	best: 0.9618930 (800)	total: 10.7s	remaining: 2.66s
# 999:	learn: 0.9652419	test: 0.9624585	best: 0.9625040 (996)	total: 13.4s	remaining: 0us
# bestTest = 0.9625039716
# bestIteration = 996
# Shrink model to first 997 iterations.
# Feature #53 eliminated
# Step #2 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 24.3ms	remaining: 24.3s
# 200:	learn: 0.9568167	test: 0.9567232	best: 0.9567702 (199)	total: 2.91s	remaining: 11.6s
# 400:	learn: 0.9613123	test: 0.9598952	best: 0.9599207 (399)	total: 5.62s	remaining: 8.39s
# 600:	learn: 0.9631585	test: 0.9610474	best: 0.9610814 (599)	total: 8.51s	remaining: 5.65s
# 800:	learn: 0.9641854	test: 0.9617544	best: 0.9617632 (796)	total: 11.1s	remaining: 2.76s
# 999:	learn: 0.9651392	test: 0.9624661	best: 0.9624661 (999)	total: 13.8s	remaining: 0us
# bestTest = 0.9624661121
# bestIteration = 999
# Feature #46 eliminated
# Step #3 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 17ms	remaining: 16.9s
# 200:	learn: 0.9569234	test: 0.9565236	best: 0.9565236 (200)	total: 2.81s	remaining: 11.2s
# 400:	learn: 0.9613400	test: 0.9597322	best: 0.9597837 (386)	total: 5.5s	remaining: 8.21s
# 600:	learn: 0.9630893	test: 0.9610475	best: 0.9610675 (564)	total: 8.28s	remaining: 5.5s
# 800:	learn: 0.9642206	test: 0.9617709	best: 0.9618362 (789)	total: 11.2s	remaining: 2.77s
# 999:	learn: 0.9651780	test: 0.9626578	best: 0.9626803 (998)	total: 14.3s	remaining: 0us
# bestTest = 0.9626802525
# bestIteration = 998
# Shrink model to first 999 iterations.
# Feature #21 eliminated
# Step #4 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 20.1ms	remaining: 20.1s
# 200:	learn: 0.9569234	test: 0.9565236	best: 0.9565236 (200)	total: 2.82s	remaining: 11.2s
# 400:	learn: 0.9613400	test: 0.9597322	best: 0.9597837 (386)	total: 5.47s	remaining: 8.17s
# 600:	learn: 0.9630893	test: 0.9610475	best: 0.9610675 (564)	total: 8.07s	remaining: 5.36s
# 800:	learn: 0.9642157	test: 0.9617780	best: 0.9618321 (794)	total: 10.7s	remaining: 2.67s
# 999:	learn: 0.9651350	test: 0.9626742	best: 0.9626742 (999)	total: 13.5s	remaining: 0us
# bestTest = 0.9626742201
# bestIteration = 999
# Feature #9 eliminated
# Feature #22 eliminated
# Step #5 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 24.3ms	remaining: 24.3s
# 200:	learn: 0.9569234	test: 0.9565236	best: 0.9565236 (200)	total: 2.8s	remaining: 11.1s
# 400:	learn: 0.9613400	test: 0.9597322	best: 0.9597837 (386)	total: 5.48s	remaining: 8.18s
# 600:	learn: 0.9630893	test: 0.9610475	best: 0.9610675 (564)	total: 8.15s	remaining: 5.41s
# 800:	learn: 0.9642157	test: 0.9617780	best: 0.9618321 (794)	total: 10.8s	remaining: 2.68s
# 999:	learn: 0.9651350	test: 0.9626742	best: 0.9626742 (999)	total: 13.8s	remaining: 0us
# bestTest = 0.9626742201
# bestIteration = 999
# Feature #36 eliminated
# Step #6 out of 19
# 0:	learn: 0.9237142	test: 0.9231452	best: 0.9231452 (0)	total: 18.4ms	remaining: 18.4s
# 200:	learn: 0.9567227	test: 0.9563145	best: 0.9563455 (199)	total: 2.78s	remaining: 11s
# 400:	learn: 0.9614217	test: 0.9596618	best: 0.9597218 (399)	total: 5.4s	remaining: 8.06s
# 600:	learn: 0.9632470	test: 0.9611579	best: 0.9611955 (583)	total: 8.06s	remaining: 5.35s
# 800:	learn: 0.9642315	test: 0.9618937	best: 0.9619146 (791)	total: 10.7s	remaining: 2.65s
# 999:	learn: 0.9652923	test: 0.9624633	best: 0.9624818 (993)	total: 13.3s	remaining: 0us
# bestTest = 0.9624817982
# bestIteration = 993
# Shrink model to first 994 iterations.
# Feature #54 eliminated
# Step #7 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 14.9ms	remaining: 14.9s
# 200:	learn: 0.9568075	test: 0.9564652	best: 0.9565003 (198)	total: 2.79s	remaining: 11.1s
# 400:	learn: 0.9612952	test: 0.9597147	best: 0.9597901 (397)	total: 5.39s	remaining: 8.06s
# 600:	learn: 0.9631472	test: 0.9611319	best: 0.9611319 (600)	total: 8.12s	remaining: 5.39s
# 800:	learn: 0.9642951	test: 0.9616867	best: 0.9617562 (776)	total: 10.8s	remaining: 2.67s
# 999:	learn: 0.9652675	test: 0.9622458	best: 0.9622458 (999)	total: 13.4s	remaining: 0us
# bestTest = 0.9622457719
# bestIteration = 999
# Feature #35 eliminated
# Step #8 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 15.4ms	remaining: 15.4s
# 200:	learn: 0.9568075	test: 0.9564652	best: 0.9565003 (198)	total: 2.9s	remaining: 11.5s
# 400:	learn: 0.9612952	test: 0.9597147	best: 0.9597901 (397)	total: 5.57s	remaining: 8.32s
# 600:	learn: 0.9631472	test: 0.9611319	best: 0.9611319 (600)	total: 8.29s	remaining: 5.5s
# 800:	learn: 0.9642951	test: 0.9616867	best: 0.9617562 (776)	total: 11.3s	remaining: 2.79s
# 999:	learn: 0.9652766	test: 0.9622634	best: 0.9622910 (994)	total: 13.9s	remaining: 0us
# bestTest = 0.9622910466
# bestIteration = 994
# Shrink model to first 995 iterations.
# Feature #8 eliminated
# Step #9 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 19.6ms	remaining: 19.6s
# 200:	learn: 0.9568075	test: 0.9564652	best: 0.9565003 (198)	total: 2.81s	remaining: 11.2s
# 400:	learn: 0.9612952	test: 0.9597147	best: 0.9597901 (397)	total: 5.46s	remaining: 8.15s
# 600:	learn: 0.9631684	test: 0.9611811	best: 0.9612212 (596)	total: 8.06s	remaining: 5.35s
# 800:	learn: 0.9642533	test: 0.9617616	best: 0.9618653 (791)	total: 10.6s	remaining: 2.64s
# 999:	learn: 0.9652776	test: 0.9620614	best: 0.9621182 (993)	total: 13.2s	remaining: 0us
# bestTest = 0.9621182287
# bestIteration = 993
# Shrink model to first 994 iterations.
# Feature #48 eliminated
# Step #10 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 19.5ms	remaining: 19.5s
# 200:	learn: 0.9567641	test: 0.9563747	best: 0.9563747 (200)	total: 2.82s	remaining: 11.2s
# 400:	learn: 0.9613089	test: 0.9599314	best: 0.9600390 (397)	total: 5.96s	remaining: 8.91s
# 600:	learn: 0.9632874	test: 0.9612319	best: 0.9612387 (597)	total: 8.76s	remaining: 5.82s
# 800:	learn: 0.9642093	test: 0.9616477	best: 0.9617093 (781)	total: 11.3s	remaining: 2.81s
# 999:	learn: 0.9651729	test: 0.9623537	best: 0.9623537 (999)	total: 14s	remaining: 0us
# bestTest = 0.9623537114
# bestIteration = 999
# Feature #33 eliminated
# Step #11 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 15.3ms	remaining: 15.3s
# 200:	learn: 0.9567641	test: 0.9563747	best: 0.9563747 (200)	total: 2.83s	remaining: 11.3s
# 400:	learn: 0.9613089	test: 0.9599314	best: 0.9600390 (397)	total: 5.47s	remaining: 8.17s
# 600:	learn: 0.9632874	test: 0.9612319	best: 0.9612387 (597)	total: 8.07s	remaining: 5.36s
# 800:	learn: 0.9642093	test: 0.9616477	best: 0.9617093 (781)	total: 10.5s	remaining: 2.62s
# 999:	learn: 0.9651729	test: 0.9623537	best: 0.9623537 (999)	total: 13.1s	remaining: 0us
# bestTest = 0.9623537114
# bestIteration = 999
# Feature #44 eliminated
# Step #12 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 14.8ms	remaining: 14.8s
# 200:	learn: 0.9567481	test: 0.9563272	best: 0.9563912 (199)	total: 2.81s	remaining: 11.2s
# 400:	learn: 0.9612339	test: 0.9597355	best: 0.9597411 (395)	total: 5.39s	remaining: 8.05s
# 600:	learn: 0.9630765	test: 0.9611103	best: 0.9611103 (600)	total: 7.99s	remaining: 5.3s
# 800:	learn: 0.9642687	test: 0.9617109	best: 0.9617154 (799)	total: 10.7s	remaining: 2.67s
# 999:	learn: 0.9652428	test: 0.9623325	best: 0.9623325 (999)	total: 13.3s	remaining: 0us
# bestTest = 0.9623325488
# bestIteration = 999
# Feature #18 eliminated
# Step #13 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 28.3ms	remaining: 28.3s
# 200:	learn: 0.9567481	test: 0.9563272	best: 0.9563912 (199)	total: 2.75s	remaining: 10.9s
# 400:	learn: 0.9612339	test: 0.9597355	best: 0.9597411 (395)	total: 5.37s	remaining: 8.02s
# 600:	learn: 0.9630765	test: 0.9611103	best: 0.9611103 (600)	total: 7.92s	remaining: 5.26s
# 800:	learn: 0.9642687	test: 0.9617109	best: 0.9617154 (799)	total: 10.5s	remaining: 2.62s
# 999:	learn: 0.9652428	test: 0.9623325	best: 0.9623325 (999)	total: 13.1s	remaining: 0us
# bestTest = 0.9623325488
# bestIteration = 999
# Feature #39 eliminated
# Step #14 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 26.8ms	remaining: 26.8s
# 200:	learn: 0.9567481	test: 0.9563272	best: 0.9563912 (199)	total: 2.77s	remaining: 11s
# 400:	learn: 0.9612339	test: 0.9597355	best: 0.9597411 (395)	total: 5.3s	remaining: 7.92s
# 600:	learn: 0.9630616	test: 0.9609712	best: 0.9610107 (578)	total: 7.9s	remaining: 5.25s
# 800:	learn: 0.9641668	test: 0.9615200	best: 0.9616156 (777)	total: 10.5s	remaining: 2.6s
# 999:	learn: 0.9651698	test: 0.9622070	best: 0.9622429 (927)	total: 13s	remaining: 0us
# bestTest = 0.9622429165
# bestIteration = 927
# Shrink model to first 928 iterations.
# Feature #57 eliminated
# Step #15 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 18.4ms	remaining: 18.3s
# 200:	learn: 0.9568070	test: 0.9565046	best: 0.9565165 (197)	total: 2.59s	remaining: 10.3s
# 400:	learn: 0.9613953	test: 0.9598677	best: 0.9598677 (400)	total: 5.11s	remaining: 7.63s
# 600:	learn: 0.9632708	test: 0.9612780	best: 0.9612892 (598)	total: 7.57s	remaining: 5.02s
# 800:	learn: 0.9642212	test: 0.9620159	best: 0.9620159 (800)	total: 10s	remaining: 2.49s
# 999:	learn: 0.9652196	test: 0.9625322	best: 0.9625583 (998)	total: 12.5s	remaining: 0us
# bestTest = 0.9625582771
# bestIteration = 998
# Shrink model to first 999 iterations.
# Feature #47 eliminated
# Step #16 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 20.7ms	remaining: 20.7s
# 200:	learn: 0.9567999	test: 0.9566659	best: 0.9566659 (200)	total: 2.68s	remaining: 10.7s
# 400:	learn: 0.9612428	test: 0.9597734	best: 0.9597843 (389)	total: 5.3s	remaining: 7.92s
# 600:	learn: 0.9631884	test: 0.9612936	best: 0.9612936 (600)	total: 7.82s	remaining: 5.19s
# 800:	learn: 0.9641946	test: 0.9617970	best: 0.9618731 (796)	total: 10.3s	remaining: 2.57s
# 999:	learn: 0.9651984	test: 0.9624187	best: 0.9624187 (999)	total: 12.9s	remaining: 0us
# bestTest = 0.9624187357
# bestIteration = 999
# Step #17 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 14.2ms	remaining: 14.2s
# 200:	learn: 0.9567999	test: 0.9566659	best: 0.9566659 (200)	total: 2.62s	remaining: 10.4s
# 400:	learn: 0.9612428	test: 0.9597734	best: 0.9597843 (389)	total: 5.13s	remaining: 7.66s
# 600:	learn: 0.9631884	test: 0.9612936	best: 0.9612936 (600)	total: 7.63s	remaining: 5.07s
# 800:	learn: 0.9641946	test: 0.9617970	best: 0.9618731 (796)	total: 10.1s	remaining: 2.51s
# 999:	learn: 0.9651984	test: 0.9624187	best: 0.9624187 (999)	total: 12.6s	remaining: 0us
# bestTest = 0.9624187357
# bestIteration = 999
# Feature #55 eliminated
# Step #18 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 21.3ms	remaining: 21.2s
# 200:	learn: 0.9570062	test: 0.9566671	best: 0.9566671 (200)	total: 2.66s	remaining: 10.6s
# 400:	learn: 0.9613929	test: 0.9601035	best: 0.9601749 (393)	total: 5.19s	remaining: 7.75s
# 600:	learn: 0.9632209	test: 0.9613830	best: 0.9613830 (600)	total: 7.72s	remaining: 5.13s
# 800:	learn: 0.9642268	test: 0.9619383	best: 0.9619829 (787)	total: 10.2s	remaining: 2.53s
# 999:	learn: 0.9651181	test: 0.9624023	best: 0.9624727 (980)	total: 12.7s	remaining: 0us
# bestTest = 0.9624727432
# bestIteration = 980
# Shrink model to first 981 iterations.
# Feature #52 eliminated
# Step #19 out of 19
# 0:	learn: 0.9237360	test: 0.9231705	best: 0.9231705 (0)	total: 21.3ms	remaining: 21.3s
# 200:	learn: 0.9567530	test: 0.9563623	best: 0.9563623 (200)	total: 2.63s	remaining: 10.5s
# 400:	learn: 0.9614087	test: 0.9599443	best: 0.9600192 (397)	total: 5.59s	remaining: 8.35s
# 600:	learn: 0.9632558	test: 0.9611672	best: 0.9611672 (600)	total: 8.1s	remaining: 5.38s
# 800:	learn: 0.9641956	test: 0.9618642	best: 0.9618724 (795)	total: 10.7s	remaining: 2.65s
# 999:	learn: 0.9651839	test: 0.9624498	best: 0.9624498 (999)	total: 13.1s	remaining: 0us
# bestTest = 0.96244982
# bestIteration = 999
# Feature #50 eliminated
#
# Eliminated Features: ['Log_i', 'u_sqrt', 'is_near_zero_z', 'galaxy_population', 'is_high_z', 'delta_bin', 'i_sq', 'alpha_bin', 'spectral_type', 'g_sq', 'delta_sin', 'Log_u', 'color_range', 'alpha_sq', 'z_sq', 'Log_g', 'i_sqrt', 'r_sqrt', 'Log_r']
# Selected Features count: 42
# Loss values at each step: [0.1050680574430461, 0.1050156342443814, 0.10486430781484013, 0.10482153068963872, 0.10482153068963872, 0.10482153068963872, 0.10511764994663318, 0.10518258347005756, 0.10523325121506498, 0.1052031025886714, 0.10508221458775492, 0.10508221669313589, 0.10504668763207228, 0.10504670268168204, 0.10568044126326132, 0.1049936120056229, 0.10506048338830647, 0.10522660797354566, 0.10499252075046275, 0.10505816917498659]
#
# Selected 42 / 61 features.
# Saved 42 features to selected_features_catboost.json

# %% [markdown]
# ### Optuna: Hyperparameter Tuning
#
# This section tunes CatBoost hyperparameters to maximize **Balanced Accuracy**.
#
# - **Objective**: Arithmetic mean of class-specific recall scores across QSO, STAR, and GALAXY.
# - **Weights**: `auto_class_weights='Balanced'` ensures the model does not ignore any stellar class.
# - **Validation**: Each trial runs a 5-fold stratified CV loop for robustness.

# %%
print("Precomputing fold-wise FE for Optuna (once)...")
skf_cache = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
fold_cache = []

for fold, (train_idx, val_idx) in enumerate(skf_cache.split(training_df, y)):
    X_train_fold = training_df.iloc[train_idx]
    y_train_fold = y.iloc[train_idx]
    X_val_fold   = training_df.iloc[val_idx]
    y_val_fold   = y.iloc[val_idx]

    fe = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
    X_train_trans = fe.fit_transform(X_train_fold)
    X_val_trans   = fe.transform(X_val_fold)

    if optimal_cols is not None:
        final_cols = [c for c in optimal_cols if c in X_train_trans.columns]
        X_train_trans = X_train_trans[final_cols]
        X_val_trans   = X_val_trans[final_cols]

    cat_features_fold = fe.get_cat_features(X_train_trans)
    if optimal_cols is not None:
        cat_features_fold = [c for c in cat_features_fold if c in final_cols]

    for c in cat_features_fold:
        X_train_trans[c] = X_train_trans[c].astype(str)
        X_val_trans[c]   = X_val_trans[c].astype(str)

    fold_cache.append((
        Pool(X_train_trans, y_train_fold, cat_features=cat_features_fold),
        Pool(X_val_trans,   y_val_fold,   cat_features=cat_features_fold),
        y_val_fold,
        val_idx
    ))

print(f"Cached {len(fold_cache)} folds.")
# Out:
# Precomputing fold-wise FE for Optuna (once)...
# Cached 5 folds.

# %%
cols_to_keep = list(optimal_cols) if optimal_cols is not None else None

print(f'Training shape: {X.shape}')
print(f'cols_to_keep: {cols_to_keep}')

# Only import if needed.
if setup.use_gpu():
    import torch
    
def objective(trial):
    trial_start = time.perf_counter()
    
    params = {
        'loss_function': 'MultiClass',
        'eval_metric': 'TotalF1:average=Macro',
        'classes_count': 3,
        'auto_class_weights': 'Balanced',
        'iterations': 4000,
        'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.06),
        'depth': trial.suggest_int('depth', 6, 8),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 10.0, log=True),
        'random_strength': trial.suggest_float('random_strength', 3.0, 8.0),
        'one_hot_max_size': 10,
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 200, log=True),
        'leaf_estimation_iterations': trial.suggest_int('leaf_estimation_iterations', 5, 15),
        'bootstrap_type': 'Bernoulli',
        'subsample': trial.suggest_float('subsample', 0.80, 1.0),
        'feature_border_type': 'UniformAndQuantiles',
        'border_count': 254,
        'task_type': 'GPU' if setup.use_gpu() else 'CPU',
        'gpu_ram_part': 0.65,
        'metric_period': 20,
        'allow_writing_files': False,
        'random_seed': seed,
        'verbose': 0,
    }
    
    grow_policy = trial.suggest_categorical('grow_policy', ['SymmetricTree', 'Lossguide'])
    params['grow_policy'] = grow_policy
    if grow_policy == 'Lossguide':
        params['max_leaves'] = trial.suggest_int('max_leaves', 24, 96)
        params['boosting_type'] = 'Plain'

    oof_preds = np.zeros(len(y), dtype=int)

    for fold, (train_pool, val_pool, y_val_fold, val_idx) in enumerate(fold_cache):
        fold_start = time.perf_counter()

        model = CatBoostClassifier(**params)
        model.fit(
            train_pool,
            eval_set=val_pool,
            early_stopping_rounds=300,
            verbose=False
        )

        fold_elapsed = time.perf_counter() - fold_start
        n_trees = model.tree_count_
        ms_per_tree = (fold_elapsed / n_trees) * 1000 if n_trees else float('nan')

        val_preds = model.predict(val_pool).flatten()
        oof_preds[val_idx] = val_preds
        fold_score = balanced_accuracy_score(y_val_fold, val_preds)

        print(f'  Fold {fold+1}: {fold_elapsed:6.1f}s | trees={n_trees:5d} '
              f'| {ms_per_tree:6.2f} ms/tree | bal_acc={fold_score:.5f} '
              f'| grow={grow_policy}, lei={params["leaf_estimation_iterations"]}, '
              f'depth={params["depth"]}')

        del model
        gc.collect()
        
        trial.report(fold_score, step=fold)
        if trial.should_prune():
            raise optuna.exceptions.TrialPruned()
    
    trial_elapsed = time.perf_counter() - trial_start
    overall = balanced_accuracy_score(y, oof_preds)
    print(f'Trial {trial.number}: {trial_elapsed/60:.1f} min total | OOF bal_acc={overall:.5f}\n')
    return overall
# Out:
# Training shape: (577347, 61)
# cols_to_keep: ['alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'redshift', 'u_minus_g', 'g_minus_r', 'r_minus_i', 'i_minus_z', 'u_minus_r', 'u_minus_z', 'g_minus_z', 'g_minus_i', 'redshift_log1p', 'redshift_sq', 'z_x_u_g', 'z_x_g_r', 'z_x_color_range', 'is_mid_z', 'pos_x', 'pos_y', 'pos_z', 'abs_delta', 'alpha_sin', 'alpha_cos', 'delta_cos', 'sky_bin', 'Log_alpha', 'alpha_sqrt', 'Log_delta', 'delta_sq', 'delta_sqrt', 'u_sq', 'g_sqrt', 'r_sq', 'Log_z', 'z_sqrt', 'Log_redshift', 'redshift_sqrt']

# %%
# Load the "best" parameters that were calculated in an earlier Optuna run
optuna_filename = 'optuna_params_catboost.json'
best_params = setup.load_optuna_params(optuna_filename)

if setup.perform_optuna_tuning() or len(best_params) == 0:
    print('Starting CatBoost Optuna Optimization...')

    pruner = optuna.pruners.MedianPruner(n_startup_trials=5, n_warmup_steps=3)

    study = optuna.create_study(
        storage='sqlite:///catboost_study.db',
        load_if_exists=True,
        study_name='cb_predict_stellar_class_optuna',
        direction='maximize',
        pruner=pruner,
        sampler=optuna.samplers.TPESampler(
            seed=seed,
            n_startup_trials=5,
            multivariate=True,
        )
    )

    # Seed the study with last best parameters.
    study.enqueue_trial(best_params)
    
    study.optimize(
        objective,
        n_trials=25,
        n_jobs=1,
        gc_after_trial=True,
        show_progress_bar=True,
        timeout=18000
    )

    print('Best Score:', study.best_value)
    print('Best Params:', study.best_params)

    best_params = study.best_params

    setup.save_optuna_params(optuna_filename, best_params)
else:
    print('\nUsing pretuned params (run Optuna for new tuned values):')
    print(best_params)
# Out:
# [I 2026-06-22 16:48:57,371] A new study created in memory with name: cb_predict_stellar_class_optuna
# Loaded 8 parameters from optuna_params_catboost.json
# Starting CatBoost Optuna Optimization...
#   0%|          | 0/25 [00:00<?, ?it/s]
#   Fold 1:   95.9s | trees= 2446 |  39.21 ms/tree | bal_acc=0.96495 | grow=SymmetricTree, lei=10, depth=6
#   Fold 2:   93.4s | trees= 2570 |  36.32 ms/tree | bal_acc=0.96537 | grow=SymmetricTree, lei=10, depth=6
#   Fold 3:  112.7s | trees= 3273 |  34.42 ms/tree | bal_acc=0.96588 | grow=SymmetricTree, lei=10, depth=6
#   Fold 4:   87.0s | trees= 2472 |  35.19 ms/tree | bal_acc=0.96511 | grow=SymmetricTree, lei=10, depth=6
#   Fold 5:  108.6s | trees= 3162 |  34.35 ms/tree | bal_acc=0.96500 | grow=SymmetricTree, lei=10, depth=6
# Trial 0: 8.3 min total | OOF bal_acc=0.96526
#
# [I 2026-06-22 16:57:17,041] Trial 0 finished with value: 0.9652616397014374 and parameters: {'learning_rate': 0.04404103864951304, 'depth': 6, 'l2_leaf_reg': 5.781049411382222, 'random_strength': 4.08407020757575, 'min_data_in_leaf': 187, 'leaf_estimation_iterations': 10, 'subsample': 0.9695070622307045, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   91.3s | trees= 2177 |  41.95 ms/tree | bal_acc=0.96504 | grow=SymmetricTree, lei=13, depth=6
#   Fold 2:   70.0s | trees= 1588 |  44.11 ms/tree | bal_acc=0.96518 | grow=SymmetricTree, lei=13, depth=6
#   Fold 3:   91.8s | trees= 2023 |  45.36 ms/tree | bal_acc=0.96562 | grow=SymmetricTree, lei=13, depth=6
#   Fold 4:   77.3s | trees= 1793 |  43.13 ms/tree | bal_acc=0.96478 | grow=SymmetricTree, lei=13, depth=6
#   Fold 5:   96.1s | trees= 2309 |  41.62 ms/tree | bal_acc=0.96488 | grow=SymmetricTree, lei=13, depth=6
# Trial 1: 7.1 min total | OOF bal_acc=0.96510
#
# [I 2026-06-22 17:04:25,395] Trial 1 finished with value: 0.965099858484772 and parameters: {'learning_rate': 0.052259403904799, 'depth': 6, 'l2_leaf_reg': 8.184951619730263, 'random_strength': 6.7618126841990565, 'min_data_in_leaf': 24, 'leaf_estimation_iterations': 13, 'subsample': 0.9994422948343273, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   50.1s | trees= 1563 |  32.04 ms/tree | bal_acc=0.96478 | grow=SymmetricTree, lei=5, depth=7
#   Fold 2:   53.6s | trees= 1687 |  31.76 ms/tree | bal_acc=0.96534 | grow=SymmetricTree, lei=5, depth=7
#   Fold 3:   51.0s | trees= 1586 |  32.13 ms/tree | bal_acc=0.96542 | grow=SymmetricTree, lei=5, depth=7
#   Fold 4:   64.4s | trees= 2079 |  30.98 ms/tree | bal_acc=0.96459 | grow=SymmetricTree, lei=5, depth=7
#   Fold 5:   87.3s | trees= 2931 |  29.77 ms/tree | bal_acc=0.96484 | grow=SymmetricTree, lei=5, depth=7
# Trial 2: 5.1 min total | OOF bal_acc=0.96499
#
# [I 2026-06-22 17:09:33,546] Trial 2 finished with value: 0.9649940518433623 and parameters: {'learning_rate': 0.044679105570701726, 'depth': 7, 'l2_leaf_reg': 3.2908078342574933, 'random_strength': 5.62048215637793, 'min_data_in_leaf': 81, 'leaf_estimation_iterations': 5, 'subsample': 0.9581396002727145, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:  102.6s | trees= 2337 |  43.90 ms/tree | bal_acc=0.96475 | grow=SymmetricTree, lei=14, depth=6
#   Fold 2:  103.4s | trees= 2377 |  43.50 ms/tree | bal_acc=0.96528 | grow=SymmetricTree, lei=14, depth=6
#   Fold 3:  127.9s | trees= 3023 |  42.30 ms/tree | bal_acc=0.96575 | grow=SymmetricTree, lei=14, depth=6
#   Fold 4:   85.3s | trees= 1880 |  45.35 ms/tree | bal_acc=0.96472 | grow=SymmetricTree, lei=14, depth=6
#   Fold 5:   94.2s | trees= 2120 |  44.42 ms/tree | bal_acc=0.96450 | grow=SymmetricTree, lei=14, depth=6
# Trial 3: 8.6 min total | OOF bal_acc=0.96500
#
# [I 2026-06-22 17:18:08,819] Trial 3 finished with value: 0.9649998244610195 and parameters: {'learning_rate': 0.04540414140008879, 'depth': 6, 'l2_leaf_reg': 4.832855528141586, 'random_strength': 3.1724961370358398, 'min_data_in_leaf': 55, 'leaf_estimation_iterations': 14, 'subsample': 0.8931080160599476, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   64.0s | trees= 1379 |  46.40 ms/tree | bal_acc=0.96473 | grow=Lossguide, lei=14, depth=7
#   Fold 2:   65.9s | trees= 1432 |  46.03 ms/tree | bal_acc=0.96525 | grow=Lossguide, lei=14, depth=7
#   Fold 3:   47.4s | trees=  938 |  50.50 ms/tree | bal_acc=0.96580 | grow=Lossguide, lei=14, depth=7
#   Fold 4:   53.1s | trees= 1099 |  48.27 ms/tree | bal_acc=0.96452 | grow=Lossguide, lei=14, depth=7
#   Fold 5:   48.8s | trees=  982 |  49.72 ms/tree | bal_acc=0.96435 | grow=Lossguide, lei=14, depth=7
# Trial 4: 4.7 min total | OOF bal_acc=0.96493
#
# [I 2026-06-22 17:22:51,922] Trial 4 finished with value: 0.9649279698974874 and parameters: {'learning_rate': 0.05917293457836964, 'depth': 7, 'l2_leaf_reg': 1.0119804453297743, 'random_strength': 3.2432499391206195, 'min_data_in_leaf': 54, 'leaf_estimation_iterations': 14, 'subsample': 0.9363408370821683, 'grow_policy': 'Lossguide', 'max_leaves': 43}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   93.0s | trees= 2900 |  32.08 ms/tree | bal_acc=0.96492 | grow=SymmetricTree, lei=9, depth=6
#   Fold 2:   78.2s | trees= 2398 |  32.60 ms/tree | bal_acc=0.96543 | grow=SymmetricTree, lei=9, depth=6
#   Fold 3:   75.2s | trees= 2285 |  32.92 ms/tree | bal_acc=0.96571 | grow=SymmetricTree, lei=9, depth=6
#   Fold 4:   64.1s | trees= 1894 |  33.84 ms/tree | bal_acc=0.96481 | grow=SymmetricTree, lei=9, depth=6
#   Fold 5:   61.7s | trees= 1823 |  33.84 ms/tree | bal_acc=0.96457 | grow=SymmetricTree, lei=9, depth=6
# Trial 5: 6.2 min total | OOF bal_acc=0.96509
#
# [I 2026-06-22 17:29:06,097] Trial 5 finished with value: 0.965091586246802 and parameters: {'learning_rate': 0.050430670338044006, 'depth': 6, 'l2_leaf_reg': 8.522829340162946, 'random_strength': 6.8320196400719455, 'min_data_in_leaf': 162, 'leaf_estimation_iterations': 9, 'subsample': 0.9044137137462853, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:  107.0s | trees= 2175 |  49.20 ms/tree | bal_acc=0.96474 | grow=SymmetricTree, lei=12, depth=7
#   Fold 2:  123.7s | trees= 2547 |  48.57 ms/tree | bal_acc=0.96539 | grow=SymmetricTree, lei=12, depth=7
#   Fold 3:  107.7s | trees= 2190 |  49.16 ms/tree | bal_acc=0.96564 | grow=SymmetricTree, lei=12, depth=7
#   Fold 4:  108.3s | trees= 2211 |  48.97 ms/tree | bal_acc=0.96482 | grow=SymmetricTree, lei=12, depth=7
#   Fold 5:   86.5s | trees= 1714 |  50.46 ms/tree | bal_acc=0.96441 | grow=SymmetricTree, lei=12, depth=7
# Trial 6: 8.9 min total | OOF bal_acc=0.96500
#
# [I 2026-06-22 17:38:01,200] Trial 6 finished with value: 0.9649972222434734 and parameters: {'learning_rate': 0.03781141167134428, 'depth': 7, 'l2_leaf_reg': 4.367221911641969, 'random_strength': 5.017109355574122, 'min_data_in_leaf': 125, 'leaf_estimation_iterations': 12, 'subsample': 0.951533057171733, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   58.2s | trees= 1405 |  41.42 ms/tree | bal_acc=0.96467 | grow=Lossguide, lei=11, depth=6
#   Fold 2:   51.9s | trees= 1209 |  42.92 ms/tree | bal_acc=0.96520 | grow=Lossguide, lei=11, depth=6
#   Fold 3:   75.4s | trees= 1892 |  39.85 ms/tree | bal_acc=0.96605 | grow=Lossguide, lei=11, depth=6
#   Fold 4:   81.1s | trees= 2081 |  38.96 ms/tree | bal_acc=0.96443 | grow=Lossguide, lei=11, depth=6
#   Fold 5:   48.8s | trees= 1117 |  43.64 ms/tree | bal_acc=0.96460 | grow=Lossguide, lei=11, depth=6
# Trial 7: 5.3 min total | OOF bal_acc=0.96499
#
# [I 2026-06-22 17:43:21,803] Trial 7 finished with value: 0.9649887471570512 and parameters: {'learning_rate': 0.03843697948311419, 'depth': 6, 'l2_leaf_reg': 5.8172976950399455, 'random_strength': 3.3251686795640465, 'min_data_in_leaf': 54, 'leaf_estimation_iterations': 11, 'subsample': 0.9973197781602325, 'grow_policy': 'Lossguide', 'max_leaves': 96}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   91.8s | trees= 3037 |  30.23 ms/tree | bal_acc=0.96483 | grow=SymmetricTree, lei=8, depth=6
#   Fold 2:   71.7s | trees= 2299 |  31.17 ms/tree | bal_acc=0.96551 | grow=SymmetricTree, lei=8, depth=6
#   Fold 3:   81.3s | trees= 2655 |  30.62 ms/tree | bal_acc=0.96558 | grow=SymmetricTree, lei=8, depth=6
#   Fold 4:   74.9s | trees= 2426 |  30.86 ms/tree | bal_acc=0.96499 | grow=SymmetricTree, lei=8, depth=6
#   Fold 5:   90.7s | trees= 3005 |  30.18 ms/tree | bal_acc=0.96464 | grow=SymmetricTree, lei=8, depth=6
# Trial 8: 6.9 min total | OOF bal_acc=0.96511
#
# [I 2026-06-22 17:50:14,313] Trial 8 finished with value: 0.9651100960411979 and parameters: {'learning_rate': 0.04499591790230746, 'depth': 6, 'l2_leaf_reg': 1.4255729998281845, 'random_strength': 3.2216043303507713, 'min_data_in_leaf': 189, 'leaf_estimation_iterations': 8, 'subsample': 0.9839544173244855, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   88.3s | trees= 1118 |  78.97 ms/tree | bal_acc=0.96430 | grow=SymmetricTree, lei=13, depth=8
#   Fold 2:   98.3s | trees= 1277 |  76.97 ms/tree | bal_acc=0.96516 | grow=SymmetricTree, lei=13, depth=8
#   Fold 3:  101.8s | trees= 1330 |  76.55 ms/tree | bal_acc=0.96565 | grow=SymmetricTree, lei=13, depth=8
#   Fold 4:   98.8s | trees= 1280 |  77.16 ms/tree | bal_acc=0.96508 | grow=SymmetricTree, lei=13, depth=8
#   Fold 5:   79.4s | trees=  976 |  81.40 ms/tree | bal_acc=0.96431 | grow=SymmetricTree, lei=13, depth=8
# Trial 9: 7.8 min total | OOF bal_acc=0.96490
#
# [I 2026-06-22 17:58:02,408] Trial 9 finished with value: 0.9648997005909692 and parameters: {'learning_rate': 0.0532954526222425, 'depth': 8, 'l2_leaf_reg': 9.514617736528951, 'random_strength': 3.442442605129728, 'min_data_in_leaf': 113, 'leaf_estimation_iterations': 13, 'subsample': 0.9483640973013882, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   89.1s | trees= 3177 |  28.04 ms/tree | bal_acc=0.96483 | grow=SymmetricTree, lei=7, depth=6
#   Fold 2:   81.2s | trees= 2870 |  28.28 ms/tree | bal_acc=0.96527 | grow=SymmetricTree, lei=7, depth=6
#   Fold 3:  102.4s | trees= 3955 |  25.90 ms/tree | bal_acc=0.96579 | grow=SymmetricTree, lei=7, depth=6
#   Fold 4:   85.4s | trees= 3027 |  28.20 ms/tree | bal_acc=0.96493 | grow=SymmetricTree, lei=7, depth=6
#   Fold 5:   94.7s | trees= 3397 |  27.86 ms/tree | bal_acc=0.96474 | grow=SymmetricTree, lei=7, depth=6
# Trial 10: 7.6 min total | OOF bal_acc=0.96511
#
# [I 2026-06-22 18:05:37,498] Trial 10 finished with value: 0.9651133633681538 and parameters: {'learning_rate': 0.030273654558822898, 'depth': 6, 'l2_leaf_reg': 5.184249588548203, 'random_strength': 3.4036825749100235, 'min_data_in_leaf': 196, 'leaf_estimation_iterations': 7, 'subsample': 0.9856215470435855, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   73.5s | trees= 2033 |  36.14 ms/tree | bal_acc=0.96469 | grow=SymmetricTree, lei=10, depth=6
#   Fold 2:   84.9s | trees= 2410 |  35.25 ms/tree | bal_acc=0.96546 | grow=SymmetricTree, lei=10, depth=6
#   Fold 3:  108.6s | trees= 3182 |  34.11 ms/tree | bal_acc=0.96595 | grow=SymmetricTree, lei=10, depth=6
#   Fold 4:   81.5s | trees= 2309 |  35.29 ms/tree | bal_acc=0.96488 | grow=SymmetricTree, lei=10, depth=6
#   Fold 5:   88.5s | trees= 2545 |  34.77 ms/tree | bal_acc=0.96486 | grow=SymmetricTree, lei=10, depth=6
# Trial 11: 7.3 min total | OOF bal_acc=0.96517
#
# [I 2026-06-22 18:12:56,498] Trial 11 finished with value: 0.965167466355617 and parameters: {'learning_rate': 0.043961453349967164, 'depth': 6, 'l2_leaf_reg': 9.267712568056934, 'random_strength': 3.794789445461024, 'min_data_in_leaf': 193, 'leaf_estimation_iterations': 10, 'subsample': 0.9954865323926205, 'grow_policy': 'SymmetricTree'}. Best is trial 0 with value: 0.9652616397014374.
#   Fold 1:   79.0s | trees= 2567 |  30.79 ms/tree | bal_acc=0.96481 | grow=SymmetricTree, lei=8, depth=6
#   Fold 2:   79.5s | trees= 2600 |  30.59 ms/tree | bal_acc=0.96563 | grow=SymmetricTree, lei=8, depth=6
#   Fold 3:   94.3s | trees= 3149 |  29.95 ms/tree | bal_acc=0.96610 | grow=SymmetricTree, lei=8, depth=6
#   Fold 4:   72.2s | trees= 2324 |  31.09 ms/tree | bal_acc=0.96521 | grow=SymmetricTree, lei=8, depth=6
#   Fold 5:   70.0s | trees= 2253 |  31.09 ms/tree | bal_acc=0.96487 | grow=SymmetricTree, lei=8, depth=6
# Trial 12: 6.6 min total | OOF bal_acc=0.96532
#
# [I 2026-06-22 18:19:33,747] Trial 12 finished with value: 0.9653229780909863 and parameters: {'learning_rate': 0.04991882743123098, 'depth': 6, 'l2_leaf_reg': 8.80110273143605, 'random_strength': 4.757097046475712, 'min_data_in_leaf': 146, 'leaf_estimation_iterations': 8, 'subsample': 0.987042822286356, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   47.2s | trees= 1687 |  27.99 ms/tree | bal_acc=0.96482 | grow=SymmetricTree, lei=6, depth=6
#   Fold 2:   48.4s | trees= 1730 |  27.97 ms/tree | bal_acc=0.96517 | grow=SymmetricTree, lei=6, depth=6
#   Fold 3:   59.6s | trees= 2212 |  26.94 ms/tree | bal_acc=0.96594 | grow=SymmetricTree, lei=6, depth=6
#   Fold 4:   71.0s | trees= 2696 |  26.34 ms/tree | bal_acc=0.96506 | grow=SymmetricTree, lei=6, depth=6
#   Fold 5:   44.1s | trees= 1560 |  28.28 ms/tree | bal_acc=0.96464 | grow=SymmetricTree, lei=6, depth=6
# Trial 13: 4.5 min total | OOF bal_acc=0.96513
#
# [I 2026-06-22 18:24:05,852] Trial 13 finished with value: 0.9651260750989549 and parameters: {'learning_rate': 0.054938667306172036, 'depth': 6, 'l2_leaf_reg': 6.111314137325162, 'random_strength': 4.441681357179128, 'min_data_in_leaf': 130, 'leaf_estimation_iterations': 6, 'subsample': 0.9683615250531736, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   86.8s | trees= 3812 |  22.77 ms/tree | bal_acc=0.96524 | grow=SymmetricTree, lei=5, depth=6
#   Fold 2:   86.9s | trees= 3854 |  22.54 ms/tree | bal_acc=0.96572 | grow=SymmetricTree, lei=5, depth=6
#   Fold 3:   86.8s | trees= 3831 |  22.65 ms/tree | bal_acc=0.96595 | grow=SymmetricTree, lei=5, depth=6
#   Fold 4:   72.1s | trees= 3024 |  23.84 ms/tree | bal_acc=0.96471 | grow=SymmetricTree, lei=5, depth=6
#   Fold 5:   59.6s | trees= 2446 |  24.38 ms/tree | bal_acc=0.96443 | grow=SymmetricTree, lei=5, depth=6
# Trial 14: 6.6 min total | OOF bal_acc=0.96521
#
# [I 2026-06-22 18:30:40,448] Trial 14 finished with value: 0.965211834242602 and parameters: {'learning_rate': 0.0369841789220559, 'depth': 6, 'l2_leaf_reg': 9.739930014942862, 'random_strength': 6.554101044847443, 'min_data_in_leaf': 119, 'leaf_estimation_iterations': 5, 'subsample': 0.9891940192454701, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   44.2s | trees= 1507 |  29.32 ms/tree | bal_acc=0.96504 | grow=Lossguide, lei=8, depth=6
#   Fold 2:   55.4s | trees= 1993 |  27.81 ms/tree | bal_acc=0.96563 | grow=Lossguide, lei=8, depth=6
#   Fold 3:   62.2s | trees= 2310 |  26.91 ms/tree | bal_acc=0.96614 | grow=Lossguide, lei=8, depth=6
#   Fold 4:   56.1s | trees= 2049 |  27.40 ms/tree | bal_acc=0.96497 | grow=Lossguide, lei=8, depth=6
#   Fold 5:   47.6s | trees= 1683 |  28.29 ms/tree | bal_acc=0.96471 | grow=Lossguide, lei=8, depth=6
# Trial 15: 4.5 min total | OOF bal_acc=0.96530
#
# [I 2026-06-22 18:35:11,502] Trial 15 finished with value: 0.9652997278024315 and parameters: {'learning_rate': 0.0503006414567081, 'depth': 6, 'l2_leaf_reg': 8.115245200216487, 'random_strength': 6.129747285947268, 'min_data_in_leaf': 115, 'leaf_estimation_iterations': 8, 'subsample': 0.9820694183508312, 'grow_policy': 'Lossguide', 'max_leaves': 28}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   45.1s | trees= 1498 |  30.13 ms/tree | bal_acc=0.96474 | grow=Lossguide, lei=9, depth=6
#   Fold 2:   48.0s | trees= 1608 |  29.84 ms/tree | bal_acc=0.96544 | grow=Lossguide, lei=9, depth=6
#   Fold 3:   51.4s | trees= 1748 |  29.39 ms/tree | bal_acc=0.96588 | grow=Lossguide, lei=9, depth=6
#   Fold 4:   56.9s | trees= 1977 |  28.80 ms/tree | bal_acc=0.96530 | grow=Lossguide, lei=9, depth=6
#   Fold 5:   39.5s | trees= 1265 |  31.26 ms/tree | bal_acc=0.96444 | grow=Lossguide, lei=9, depth=6
# Trial 16: 4.1 min total | OOF bal_acc=0.96516
#
# [I 2026-06-22 18:39:17,133] Trial 16 finished with value: 0.9651609726204576 and parameters: {'learning_rate': 0.056504100126630735, 'depth': 6, 'l2_leaf_reg': 8.356939387940821, 'random_strength': 5.747194783301103, 'min_data_in_leaf': 80, 'leaf_estimation_iterations': 9, 'subsample': 0.9792935717044196, 'grow_policy': 'Lossguide', 'max_leaves': 26}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   52.6s | trees= 2055 |  25.59 ms/tree | bal_acc=0.96460 | grow=Lossguide, lei=5, depth=6
#   Fold 2:   49.8s | trees= 1950 |  25.54 ms/tree | bal_acc=0.96525 | grow=Lossguide, lei=5, depth=6
#   Fold 3:   42.2s | trees= 1588 |  26.56 ms/tree | bal_acc=0.96620 | grow=Lossguide, lei=5, depth=6
#   Fold 4:   46.6s | trees= 1790 |  26.06 ms/tree | bal_acc=0.96454 | grow=Lossguide, lei=5, depth=6
#   Fold 5:   29.8s | trees= 1026 |  29.00 ms/tree | bal_acc=0.96482 | grow=Lossguide, lei=5, depth=6
# Trial 17: 3.8 min total | OOF bal_acc=0.96508
#
# [I 2026-06-22 18:43:03,826] Trial 17 finished with value: 0.9650798532320186 and parameters: {'learning_rate': 0.04164937140360954, 'depth': 6, 'l2_leaf_reg': 5.365158604048404, 'random_strength': 5.206145987709529, 'min_data_in_leaf': 141, 'leaf_estimation_iterations': 5, 'subsample': 0.9292943614442486, 'grow_policy': 'Lossguide', 'max_leaves': 61}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   71.4s | trees= 1748 |  40.84 ms/tree | bal_acc=0.96481 | grow=SymmetricTree, lei=12, depth=6
#   Fold 2:   84.8s | trees= 2133 |  39.75 ms/tree | bal_acc=0.96558 | grow=SymmetricTree, lei=12, depth=6
#   Fold 3:   86.0s | trees= 2170 |  39.63 ms/tree | bal_acc=0.96563 | grow=SymmetricTree, lei=12, depth=6
#   Fold 4:   76.6s | trees= 1903 |  40.26 ms/tree | bal_acc=0.96446 | grow=SymmetricTree, lei=12, depth=6
#   Fold 5:   82.5s | trees= 2077 |  39.70 ms/tree | bal_acc=0.96471 | grow=SymmetricTree, lei=12, depth=6
# Trial 18: 6.7 min total | OOF bal_acc=0.96504
#
# [I 2026-06-22 18:49:46,915] Trial 18 finished with value: 0.9650372109840303 and parameters: {'learning_rate': 0.057322342633402565, 'depth': 6, 'l2_leaf_reg': 2.3394321994514224, 'random_strength': 6.59487057913709, 'min_data_in_leaf': 89, 'leaf_estimation_iterations': 12, 'subsample': 0.9186019334644947, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   54.0s | trees= 2359 |  22.91 ms/tree | bal_acc=0.96487 | grow=Lossguide, lei=6, depth=6
#   Fold 2:   52.7s | trees= 2288 |  23.04 ms/tree | bal_acc=0.96514 | grow=Lossguide, lei=6, depth=6
#   Fold 3:   36.2s | trees= 1461 |  24.78 ms/tree | bal_acc=0.96568 | grow=Lossguide, lei=6, depth=6
#   Fold 4:   61.5s | trees= 2751 |  22.35 ms/tree | bal_acc=0.96480 | grow=Lossguide, lei=6, depth=6
#   Fold 5:   62.6s | trees= 2779 |  22.52 ms/tree | bal_acc=0.96497 | grow=Lossguide, lei=6, depth=6
# Trial 19: 4.5 min total | OOF bal_acc=0.96509
#
# [I 2026-06-22 18:54:19,924] Trial 19 finished with value: 0.9650920149114047 and parameters: {'learning_rate': 0.044151563072820914, 'depth': 6, 'l2_leaf_reg': 9.858778592503128, 'random_strength': 7.950504454644692, 'min_data_in_leaf': 31, 'leaf_estimation_iterations': 6, 'subsample': 0.9623429608519902, 'grow_policy': 'Lossguide', 'max_leaves': 27}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   53.7s | trees= 1183 |  45.37 ms/tree | bal_acc=0.96459 | grow=Lossguide, lei=13, depth=6
#   Fold 2:   44.9s | trees=  941 |  47.70 ms/tree | bal_acc=0.96476 | grow=Lossguide, lei=13, depth=6
#   Fold 3:   45.3s | trees=  932 |  48.59 ms/tree | bal_acc=0.96606 | grow=Lossguide, lei=13, depth=6
#   Fold 4:   77.6s | trees= 1843 |  42.08 ms/tree | bal_acc=0.96461 | grow=Lossguide, lei=13, depth=6
#   Fold 5:   68.1s | trees= 1575 |  43.23 ms/tree | bal_acc=0.96472 | grow=Lossguide, lei=13, depth=6
# Trial 20: 4.9 min total | OOF bal_acc=0.96495
#
# [I 2026-06-22 18:59:14,042] Trial 20 finished with value: 0.9649474769410933 and parameters: {'learning_rate': 0.055959806566746206, 'depth': 6, 'l2_leaf_reg': 3.7133505227301966, 'random_strength': 7.742408784096373, 'min_data_in_leaf': 160, 'leaf_estimation_iterations': 13, 'subsample': 0.9868932334277115, 'grow_policy': 'Lossguide', 'max_leaves': 74}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   53.9s | trees= 1437 |  37.50 ms/tree | bal_acc=0.96436 | grow=Lossguide, lei=10, depth=6
#   Fold 2:   44.9s | trees= 1132 |  39.69 ms/tree | bal_acc=0.96489 | grow=Lossguide, lei=10, depth=6
#   Fold 3:   56.6s | trees= 1515 |  37.35 ms/tree | bal_acc=0.96644 | grow=Lossguide, lei=10, depth=6
#   Fold 4:   78.4s | trees= 2232 |  35.13 ms/tree | bal_acc=0.96484 | grow=Lossguide, lei=10, depth=6
#   Fold 5:   37.6s | trees=  900 |  41.82 ms/tree | bal_acc=0.96447 | grow=Lossguide, lei=10, depth=6
# Trial 21: 4.6 min total | OOF bal_acc=0.96500
#
# [I 2026-06-22 19:03:50,402] Trial 21 finished with value: 0.9649978796843776 and parameters: {'learning_rate': 0.039857149343754915, 'depth': 6, 'l2_leaf_reg': 9.39015617711077, 'random_strength': 7.600378082073831, 'min_data_in_leaf': 141, 'leaf_estimation_iterations': 10, 'subsample': 0.9943674727879334, 'grow_policy': 'Lossguide', 'max_leaves': 50}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   52.2s | trees= 1617 |  32.26 ms/tree | bal_acc=0.96456 | grow=Lossguide, lei=8, depth=6
#   Fold 2:   47.6s | trees= 1448 |  32.91 ms/tree | bal_acc=0.96545 | grow=Lossguide, lei=8, depth=6
#   Fold 3:   57.0s | trees= 1813 |  31.46 ms/tree | bal_acc=0.96623 | grow=Lossguide, lei=8, depth=6
#   Fold 4:   41.7s | trees= 1230 |  33.88 ms/tree | bal_acc=0.96446 | grow=Lossguide, lei=8, depth=6
#   Fold 5:   53.1s | trees= 1667 |  31.88 ms/tree | bal_acc=0.96457 | grow=Lossguide, lei=8, depth=6
# Trial 22: 4.3 min total | OOF bal_acc=0.96505
#
# [I 2026-06-22 19:08:07,297] Trial 22 finished with value: 0.9650536904436838 and parameters: {'learning_rate': 0.047357759895242026, 'depth': 6, 'l2_leaf_reg': 5.576243838665688, 'random_strength': 5.808638440694083, 'min_data_in_leaf': 108, 'leaf_estimation_iterations': 8, 'subsample': 0.984722284553854, 'grow_policy': 'Lossguide', 'max_leaves': 43}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   55.9s | trees= 2073 |  26.98 ms/tree | bal_acc=0.96465 | grow=Lossguide, lei=8, depth=8
#   Fold 2:   58.4s | trees= 2200 |  26.55 ms/tree | bal_acc=0.96517 | grow=Lossguide, lei=8, depth=8
#   Fold 3:   49.2s | trees= 1809 |  27.21 ms/tree | bal_acc=0.96576 | grow=Lossguide, lei=8, depth=8
#   Fold 4:   48.9s | trees= 1780 |  27.47 ms/tree | bal_acc=0.96455 | grow=Lossguide, lei=8, depth=8
#   Fold 5:   56.8s | trees= 2147 |  26.46 ms/tree | bal_acc=0.96499 | grow=Lossguide, lei=8, depth=8
# Trial 23: 4.6 min total | OOF bal_acc=0.96502
#
# [I 2026-06-22 19:12:41,614] Trial 23 finished with value: 0.9650239733657865 and parameters: {'learning_rate': 0.047957983395520785, 'depth': 8, 'l2_leaf_reg': 9.068505154371469, 'random_strength': 5.799207339837442, 'min_data_in_leaf': 132, 'leaf_estimation_iterations': 8, 'subsample': 0.9796570319935662, 'grow_policy': 'Lossguide', 'max_leaves': 25}. Best is trial 12 with value: 0.9653229780909863.
#   Fold 1:   67.4s | trees= 2160 |  31.19 ms/tree | bal_acc=0.96462 | grow=SymmetricTree, lei=8, depth=6
#   Fold 2:   97.3s | trees= 3266 |  29.78 ms/tree | bal_acc=0.96566 | grow=SymmetricTree, lei=8, depth=6
#   Fold 3:   75.2s | trees= 2459 |  30.59 ms/tree | bal_acc=0.96564 | grow=SymmetricTree, lei=8, depth=6
#   Fold 4:   71.9s | trees= 2334 |  30.80 ms/tree | bal_acc=0.96450 | grow=SymmetricTree, lei=8, depth=6
#   Fold 5:   86.2s | trees= 2869 |  30.05 ms/tree | bal_acc=0.96487 | grow=SymmetricTree, lei=8, depth=6
# Trial 24: 6.7 min total | OOF bal_acc=0.96506
#
# [I 2026-06-22 19:19:21,716] Trial 24 finished with value: 0.9650579492212673 and parameters: {'learning_rate': 0.040233767469914104, 'depth': 6, 'l2_leaf_reg': 8.045164238056895, 'random_strength': 4.738662898179167, 'min_data_in_leaf': 195, 'leaf_estimation_iterations': 8, 'subsample': 0.9247912380511722, 'grow_policy': 'SymmetricTree'}. Best is trial 12 with value: 0.9653229780909863.
# Best Score: 0.9653229780909863
# Best Params: {'learning_rate': 0.04991882743123098, 'depth': 6, 'l2_leaf_reg': 8.80110273143605, 'random_strength': 4.757097046475712, 'min_data_in_leaf': 146, 'leaf_estimation_iterations': 8, 'subsample': 0.987042822286356, 'grow_policy': 'SymmetricTree'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 38
#      34     print('Best Params:', study.best_params)
#      35
#      36     best_params = study.best_params
#      37
# ---> 38     save_optuna_params(optuna_filename, best_params)
#      39 else:
#      40     print('\nUsing pretuned params (run Optuna for new tuned values):')
#      41     print(best_params)
#
# NameError: name 'save_optuna_params' is not defined

# %% [markdown]
# ### Model Training: Stratified Cross-Validation
#
# Final training uses **5-fold StratifiedKFold**. Within each fold we:
#
# - Fit the feature engineering pipeline on the training split and transform validation/test (leakage prevention)
# - Train a `CatBoostClassifier` with early stopping on validation score
# - Store **OOF probabilities** and averaged **test probabilities** for ensembling
#
# The overall CV score is Balanced Accuracy on the full OOF vector across all three stellar classes.

# %%
# TARGET MAPPING REFERENCE:
# 0: QSO
# 1: STAR
# 2: GALAXY

metric_period = 20

cb_tuned_params = {
    **best_params,
    'iterations': 16000,
    'loss_function': 'MultiClass',
    'eval_metric': 'TotalF1:average=Macro',
    'classes_count': 3,
    'auto_class_weights': 'Balanced',
    'bootstrap_type': 'Bernoulli',
    'feature_border_type': 'UniformAndQuantiles',
    'border_count': 254,
    'allow_writing_files': False,
    'random_seed': seed,
    'verbose': 200,
    'metric_period': metric_period,
    'task_type': 'GPU' if setup.use_gpu() else 'CPU',
}

    if cb_tuned_params.grow_policy == 'Lossguide':
        cb_tuned_params['boosting_type'] = 'Plain'

print('Final CatBoost CV Training with OOF / Test probabilities')
print('========================================================')
print('Parameters used for training:')
print(cb_tuned_params)

cols_to_keep = list(optimal_cols) if optimal_cols is not None else None

n_folds = 5
skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=seed)

eval_results = []
models = []

oof_probs = np.zeros((len(y), 3), dtype=np.float64)
test_probs = np.zeros((len(test_df), 3), dtype=np.float64)
oof_preds = np.zeros(len(y), dtype=np.int32)

for fold, (train_idx, val_idx) in enumerate(skf.split(training_df, y)):
    print(f'Starting fold {fold+1}/{n_folds}...')

    X_train_fold = training_df.iloc[train_idx]
    y_train_fold = y.iloc[train_idx]
    X_val_fold   = training_df.iloc[val_idx]
    y_val_fold   = y.iloc[val_idx]

    fe_fold = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
    X_train_trans = fe_fold.fit_transform(X_train_fold)
    X_val_trans   = fe_fold.transform(X_val_fold)
    X_test_trans  = fe_fold.transform(test_df)

    if cols_to_keep is not None:
        final_cols = [c for c in cols_to_keep if c in X_train_trans.columns]
        if not final_cols:
            raise RuntimeError('No overlap between optimal_cols and fold feature columns.')
        X_train_trans = X_train_trans[final_cols]
        X_val_trans   = X_val_trans[final_cols]
        X_test_trans  = X_test_trans[final_cols]

    cat_features_fold = fe_fold.get_cat_features(X_train_trans)
    if cols_to_keep is not None:
        cat_features_fold = [c for c in cat_features_fold if c in final_cols]

    # Cast to string for CatBoost
    for c in cat_features_fold:
        X_train_trans[c] = X_train_trans[c].astype(str)
        X_val_trans[c]   = X_val_trans[c].astype(str)
        X_test_trans[c]  = X_test_trans[c].astype(str)

    train_pool = Pool(X_train_trans, y_train_fold, cat_features=cat_features_fold)
    val_pool   = Pool(X_val_trans,   y_val_fold,   cat_features=cat_features_fold)
    test_pool  = Pool(X_test_trans,               cat_features=cat_features_fold)

    model = cb.CatBoostClassifier(**cb_tuned_params)
    model.fit(
        train_pool,
        eval_set=val_pool,
        early_stopping_rounds=300,
        verbose=200
    )

    eval_results.append(model.get_evals_result())
    models.append(model)

    val_prob = model.predict_proba(val_pool)
    val_pred = model.predict(val_pool).flatten()

    oof_probs[val_idx] = val_prob
    oof_preds[val_idx] = val_pred

    fold_score = balanced_accuracy_score(y_val_fold, val_pred)
    print(f'Fold {fold+1} Balanced Accuracy: {fold_score:.6f}')

    test_probs += model.predict_proba(test_pool) / n_folds

    del model, train_pool, val_pool
    gc.collect()

overall_score = balanced_accuracy_score(y, oof_preds)
print(f'Overall CV Balanced Accuracy: {overall_score:.6f}')
# Out:
# Final CatBoost CV Training with OOF / Test probabilities
# ========================================================
# Parameters used for training:
# {'learning_rate': 0.04991882743123098, 'depth': 6, 'l2_leaf_reg': 8.80110273143605, 'random_strength': 4.757097046475712, 'min_data_in_leaf': 146, 'leaf_estimation_iterations': 8, 'subsample': 0.987042822286356, 'grow_policy': 'SymmetricTree', 'iterations': 16000, 'loss_function': 'MultiClass', 'eval_metric': 'TotalF1:average=Macro', 'classes_count': 3, 'auto_class_weights': 'Balanced', 'bootstrap_type': 'Bernoulli', 'feature_border_type': 'UniformAndQuantiles', 'border_count': 254, 'allow_writing_files': False, 'random_seed': 10301, 'verbose': 200, 'metric_period': 20, 'task_type': 'GPU'}
# Starting fold 1/5...
# 0:	learn: 0.9214353	test: 0.9210469	best: 0.9210469 (0)	total: 29.1ms	remaining: 7m 46s
# 200:	learn: 0.9590691	test: 0.9583255	best: 0.9583255 (200)	total: 5.55s	remaining: 7m 16s
# 400:	learn: 0.9630197	test: 0.9609813	best: 0.9610458 (387)	total: 11.3s	remaining: 7m 18s
# 600:	learn: 0.9649708	test: 0.9622264	best: 0.9622443 (585)	total: 16.7s	remaining: 7m 8s
# 800:	learn: 0.9666027	test: 0.9626062	best: 0.9626841 (791)	total: 22.3s	remaining: 7m 2s
# 1000:	learn: 0.9678170	test: 0.9634091	best: 0.9634091 (1000)	total: 27.8s	remaining: 6m 57s
# 1200:	learn: 0.9688783	test: 0.9637778	best: 0.9637823 (1185)	total: 33.4s	remaining: 6m 51s
# 1400:	learn: 0.9698292	test: 0.9640197	best: 0.9640464 (1382)	total: 38.9s	remaining: 6m 45s
# 1600:	learn: 0.9708042	test: 0.9641629	best: 0.9641874 (1596)	total: 44.7s	remaining: 6m 41s
# 1800:	learn: 0.9716144	test: 0.9642872	best: 0.9643309 (1780)	total: 50.2s	remaining: 6m 35s
# 2000:	learn: 0.9724352	test: 0.9642930	best: 0.9644969 (1875)	total: 55.6s	remaining: 6m 29s
# 2200:	learn: 0.9731382	test: 0.9643955	best: 0.9645315 (2134)	total: 1m 1s	remaining: 6m 23s
# 2400:	learn: 0.9737558	test: 0.9646342	best: 0.9646572 (2398)	total: 1m 6s	remaining: 6m 17s
# 2600:	learn: 0.9744587	test: 0.9646598	best: 0.9648257 (2566)	total: 1m 12s	remaining: 6m 11s
# 2800:	learn: 0.9749807	test: 0.9645543	best: 0.9648257 (2566)	total: 1m 17s	remaining: 6m 5s
# bestTest = 0.9648256747
# bestIteration = 2566
# Shrink model to first 2567 iterations.
# Fold 1 Balanced Accuracy: 0.964809
# Starting fold 2/5...
# 0:	learn: 0.9219059	test: 0.9196042	best: 0.9196042 (0)	total: 31.2ms	remaining: 8m 19s
# 200:	learn: 0.9591713	test: 0.9579654	best: 0.9579654 (200)	total: 5.58s	remaining: 7m 19s
# 400:	learn: 0.9628673	test: 0.9610192	best: 0.9611498 (395)	total: 11s	remaining: 7m 7s
# 600:	learn: 0.9648179	test: 0.9625230	best: 0.9625549 (581)	total: 16.4s	remaining: 7m 1s
# 800:	learn: 0.9664060	test: 0.9634321	best: 0.9634322 (794)	total: 22.1s	remaining: 6m 59s
# 1000:	learn: 0.9677732	test: 0.9639147	best: 0.9639191 (998)	total: 27.6s	remaining: 6m 53s
# 1200:	learn: 0.9689215	test: 0.9645071	best: 0.9645176 (1181)	total: 33.1s	remaining: 6m 47s
# 1400:	learn: 0.9699726	test: 0.9647829	best: 0.9648377 (1387)	total: 38.6s	remaining: 6m 42s
# 1600:	learn: 0.9708108	test: 0.9648871	best: 0.9649479 (1558)	total: 44.1s	remaining: 6m 36s
# 1800:	learn: 0.9716863	test: 0.9649704	best: 0.9650053 (1660)	total: 49.6s	remaining: 6m 30s
# 2000:	learn: 0.9724141	test: 0.9650734	best: 0.9651775 (1888)	total: 55.1s	remaining: 6m 25s
# 2200:	learn: 0.9730964	test: 0.9651782	best: 0.9652909 (2146)	total: 1m	remaining: 6m 19s
# 2400:	learn: 0.9738604	test: 0.9653035	best: 0.9653079 (2399)	total: 1m 6s	remaining: 6m 13s
# 2600:	learn: 0.9745288	test: 0.9653334	best: 0.9653860 (2411)	total: 1m 11s	remaining: 6m 8s
# 2800:	learn: 0.9751121	test: 0.9654664	best: 0.9654805 (2799)	total: 1m 16s	remaining: 6m 2s
# 3000:	learn: 0.9757509	test: 0.9652620	best: 0.9655008 (2806)	total: 1m 22s	remaining: 5m 58s
# bestTest = 0.9655007511
# bestIteration = 2806
# Shrink model to first 2807 iterations.
# Fold 2 Balanced Accuracy: 0.965485
# Starting fold 3/5...
# 0:	learn: 0.9220055	test: 0.9231972	best: 0.9231972 (0)	total: 29.2ms	remaining: 7m 47s
# 200:	learn: 0.9595170	test: 0.9585061	best: 0.9585538 (199)	total: 5.58s	remaining: 7m 18s
# 400:	learn: 0.9633100	test: 0.9614364	best: 0.9615096 (395)	total: 11s	remaining: 7m 9s
# 600:	learn: 0.9651704	test: 0.9626750	best: 0.9627041 (598)	total: 16.5s	remaining: 7m 3s
# 800:	learn: 0.9666845	test: 0.9633490	best: 0.9633937 (790)	total: 22s	remaining: 6m 56s
# 1000:	learn: 0.9678807	test: 0.9640103	best: 0.9640199 (997)	total: 27.4s	remaining: 6m 50s
# 1200:	learn: 0.9689650	test: 0.9646535	best: 0.9646535 (1200)	total: 32.8s	remaining: 6m 44s
# 1400:	learn: 0.9698965	test: 0.9649478	best: 0.9650157 (1378)	total: 38.3s	remaining: 6m 39s
# 1600:	learn: 0.9708032	test: 0.9651203	best: 0.9651203 (1600)	total: 43.7s	remaining: 6m 33s
# 1800:	learn: 0.9715996	test: 0.9655492	best: 0.9655916 (1772)	total: 49.3s	remaining: 6m 28s
# 2000:	learn: 0.9721809	test: 0.9655437	best: 0.9655916 (1772)	total: 54.7s	remaining: 6m 22s
# 2200:	learn: 0.9729032	test: 0.9656483	best: 0.9656799 (2088)	total: 1m	remaining: 6m 17s
# 2400:	learn: 0.9734640	test: 0.9656824	best: 0.9657069 (2399)	total: 1m 5s	remaining: 6m 11s
# 2600:	learn: 0.9740258	test: 0.9656751	best: 0.9657720 (2589)	total: 1m 10s	remaining: 6m 5s
# 2800:	learn: 0.9746176	test: 0.9655141	best: 0.9657720 (2589)	total: 1m 16s	remaining: 6m
# bestTest = 0.9657719798
# bestIteration = 2589
# Shrink model to first 2590 iterations.
# Fold 3 Balanced Accuracy: 0.965762
# Starting fold 4/5...
# 0:	learn: 0.9218769	test: 0.9232840	best: 0.9232840 (0)	total: 28.5ms	remaining: 7m 36s
# 200:	learn: 0.9589392	test: 0.9575299	best: 0.9575299 (200)	total: 5.45s	remaining: 7m 8s
# 400:	learn: 0.9628069	test: 0.9606413	best: 0.9606546 (399)	total: 10.8s	remaining: 6m 59s
# 600:	learn: 0.9648544	test: 0.9621651	best: 0.9621695 (599)	total: 16.3s	remaining: 6m 56s
# 800:	learn: 0.9663833	test: 0.9631229	best: 0.9631229 (800)	total: 21.7s	remaining: 6m 52s
# 1000:	learn: 0.9676087	test: 0.9635135	best: 0.9635388 (995)	total: 27.3s	remaining: 6m 49s
# 1200:	learn: 0.9686118	test: 0.9639045	best: 0.9639467 (1195)	total: 32.8s	remaining: 6m 43s
# 1400:	learn: 0.9696451	test: 0.9644528	best: 0.9644528 (1400)	total: 38.3s	remaining: 6m 39s
# 1600:	learn: 0.9705399	test: 0.9646743	best: 0.9646788 (1599)	total: 43.8s	remaining: 6m 33s
# 1800:	learn: 0.9713245	test: 0.9648011	best: 0.9649972 (1709)	total: 49.2s	remaining: 6m 27s
# 2000:	learn: 0.9721589	test: 0.9650425	best: 0.9651294 (1977)	total: 54.7s	remaining: 6m 22s
# 2200:	learn: 0.9728661	test: 0.9650097	best: 0.9651845 (2124)	total: 1m	remaining: 6m 17s
# 2400:	learn: 0.9736546	test: 0.9650321	best: 0.9652122 (2323)	total: 1m 5s	remaining: 6m 11s
# 2600:	learn: 0.9743134	test: 0.9649423	best: 0.9652122 (2323)	total: 1m 11s	remaining: 6m 6s
# bestTest = 0.9652121667
# bestIteration = 2323
# Shrink model to first 2324 iterations.
# Fold 4 Balanced Accuracy: 0.965208
# Starting fold 5/5...
# 0:	learn: 0.9215642	test: 0.9206509	best: 0.9206509 (0)	total: 28.8ms	remaining: 7m 41s
# 200:	learn: 0.9594142	test: 0.9574102	best: 0.9574572 (197)	total: 5.5s	remaining: 7m 12s
# 400:	learn: 0.9631320	test: 0.9606723	best: 0.9606723 (400)	total: 11s	remaining: 7m 7s
# 600:	learn: 0.9650758	test: 0.9620828	best: 0.9621814 (564)	total: 16.5s	remaining: 7m 2s
# 800:	learn: 0.9666317	test: 0.9629919	best: 0.9629919 (800)	total: 21.9s	remaining: 6m 56s
# 1000:	learn: 0.9678254	test: 0.9634452	best: 0.9634751 (972)	total: 27.4s	remaining: 6m 50s
# 1200:	learn: 0.9687973	test: 0.9638319	best: 0.9638364 (1195)	total: 32.8s	remaining: 6m 44s
# 1400:	learn: 0.9697640	test: 0.9642015	best: 0.9642337 (1365)	total: 38.3s	remaining: 6m 39s
# 1600:	learn: 0.9706370	test: 0.9645206	best: 0.9645459 (1589)	total: 43.7s	remaining: 6m 33s
# 1800:	learn: 0.9715218	test: 0.9646575	best: 0.9647049 (1619)	total: 49.2s	remaining: 6m 27s
# 2000:	learn: 0.9722545	test: 0.9648293	best: 0.9648524 (1967)	total: 54.6s	remaining: 6m 21s
# 2200:	learn: 0.9730352	test: 0.9648146	best: 0.9648874 (2104)	total: 1m	remaining: 6m 17s
# 2400:	learn: 0.9737565	test: 0.9649581	best: 0.9649976 (2301)	total: 1m 5s	remaining: 6m 12s
# 2600:	learn: 0.9745143	test: 0.9649370	best: 0.9649976 (2301)	total: 1m 11s	remaining: 6m 8s
# bestTest = 0.9649976
# bestIteration = 2301
# Shrink model to first 2302 iterations.
# Fold 5 Balanced Accuracy: 0.964977
# Overall CV Balanced Accuracy: 0.965248

# %% [markdown]
# ## Visualizing Model Performance
#
# Diagnostic plots to evaluate how well the model distinguishes between the three stellar classes and to detect potential biases or overfitting.

# %% [markdown]
# ### Learning Curves (Train vs. Validation Log-Loss)
# This plot tracks the metric over boosting iterations. A widening gap between train and validation lines indicates overfitting. Early stopping terminates training once the validation score plateaus.

# %%
mviz = ModelVisualizer(model_name='CatBoost')

mviz.plot_learning_curves(eval_results, metric='TotalF1:average=Macro', metric_period=metric_period)

# %% [markdown]
# ### Feature Importance
# Average feature importance across folds.
# * **Validation check:** `redshift`, `redshift_sq`, `redshift_log1p`, and `is_high_z` should dominate — redshift is the single strongest discriminator in SDSS stellar classification.
# * **color check:** color indices (`g_minus_z`, `u_minus_r`, etc.) should rank in the mid-tier. Raw magnitudes outranking colors suggests the `colors` strategy is not active.
# * **Leakage check:** `id` must not appear. `alpha` and `delta` should rank near zero unless the `position` strategy is active.

# %%
mviz.plot_feature_importance(models, show_values=True)

# %% [markdown]
# ### Distribution Mismatch
# Overlays the distribution of true class labels against OOF predicted labels (QSO=0, STAR=1, GALAXY=2). A large divergence on one class suggests the model is systematically misclassifying that stellar type.

# %%
mviz.plot_distribution_mismatch(y_true=y, y_preds=oof_preds)

# %% [markdown]
# ### ROC Curves (One-vs-Rest)
# Each class is treated as the positive class in turn. AUC measures separation from the other two classes. All three curves should sit well above the diagonal; a sagging QSO curve is the most common weak point in stellar classification tasks.

# %%
mviz.plot_multiclass_roc_curve(y_true=y, y_score=oof_probs, title='CatBoost OOF ROC Curve')

# %% [markdown]
# ### Confusion Matrix (Out-of-Fold)
# Shows which stellar classes the model frequently confuses.
# * **QSO (0):** QSOs share photometric colors with both galaxies and stars at certain redshifts — off-diagonal entries here are the most common failure mode.
# * **STAR (1):** Stars are near-zero redshift and generally the easiest class to separate. High off-diagonal values here warrant investigation.
# * **GALAXY (2):** Galaxies span a wide redshift range and color space; moderate confusion with QSOs at high redshift is expected.

# %%
mviz.plot_confusion_matrix(
    y_true=y,
    y_pred=oof_preds,
    classes=['QSO (0)', 'STAR (1)', 'GALAXY (2)'],
    normalize=True,
    title='CatBoost OOF Confusion Matrix (Normalized)'
)
# Out:
# Normalized confusion matrix

# %% [markdown]
# ## Prepare Submission
#
# The competition requires the hard predicted class label (`GALAXY`, `QSO`, or `STAR`) for each row in the test set. We derive predictions by taking the argmax of the averaged test probabilities and mapping back to the original string labels.

# %%
submission_df = setup.read_dataset('submission')

numeric_preds = np.argmax(test_probs, axis=1)

# Map numeric predictions back to string class labels
pred_col = [c for c in submission_df.columns if c != 'id'][0]
submission_df[pred_col] = pd.Series(numeric_preds).map(inverse_target_mapping)

print('SAMPLE SUBMISSION')
display(submission_df.head(20))
# Out:
# SAMPLE SUBMISSION
#         id   class
# 0   577347  GALAXY
# 1   577348  GALAXY
# 2   577349  GALAXY
# 3   577350    STAR
# 4   577351  GALAXY
# 5   577352  GALAXY
# 6   577353  GALAXY
# 7   577354    STAR
# 8   577355  GALAXY
# 9   577356  GALAXY
# 10  577357    STAR
# 11  577358  GALAXY
# 12  577359     QSO
# 13  577360  GALAXY
# 14  577361  GALAXY
# 15  577362     QSO
# 16  577363     QSO
# 17  577364     QSO
# 18  577365     QSO
# 19  577366  GALAXY

# %%
submission_df.to_csv('submission.csv', index=False)
print('Saved: submission.csv')
# Out:
# Saved: submission.csv

# %% [markdown]
# ## Save OOF and Test Probabilities
#
# OOF and averaged test-set probabilities are saved for downstream ensembling (blending or stacking).
#
# For this three-class task we save the full probability distribution across `QSO`, `STAR`, and `GALAXY` rather than just the argmax labels. Raw probabilities are essential for:
#
# - **Weighted Blending**: Averaging confidence scores across XGBoost, LightGBM, and CatBoost models.
# - **Stacking**: Using these probabilities as meta-features for a secondary model.
# - **Calibration Analysis**: Verifying that predicted confidence aligns with actual class frequencies.

# %%
output_dir = 'predictions'
os.makedirs(output_dir, exist_ok=True)

# Column names match the class label mapping: QSO=0, STAR=1, GALAXY=2
prob_cols = ['prob_qso', 'prob_star', 'prob_galaxy']

# OOF probabilities
oof_prob_df = pd.DataFrame(oof_probs, columns=prob_cols)
oof_df = pd.concat([
    pd.DataFrame({'id': train_ids.values, 'target': y.values}),
    oof_prob_df
], axis=1)
oof_df.to_csv(f'{output_dir}/catboost_oof_probs.csv', index=False)

# Test probabilities
test_prob_df = pd.concat([
    pd.DataFrame({'id': test_ids.values}),
    pd.DataFrame(test_probs, columns=prob_cols)
], axis=1)
test_prob_df.to_csv(f'{output_dir}/catboost_test_probs.csv', index=False)

print(f'Saved for ensembling:\n - {output_dir}/catboost_oof_probs.csv\n - {output_dir}/catboost_test_probs.csv')
# Out:
# Saved for ensembling:
#  - predictions/catboost_oof_probs.csv
#  - predictions/catboost_test_probs.csv

# %% [markdown]
# # PS-S06E01: XGBoost

# %% [markdown]
# This notebook tackles the [**Playground Series – Season 6, Episode 1: Diabetes Prediction Challenge**](https://www.kaggle.com/competitions/playground-series-s6e1), a competition focused on predicting the exam score for a student, based on features describing the student, the exam, and the facility.

# %% [markdown]
# ## Introduction

# %% [markdown]
# **XGBoost** is highly effective at capturing non-linear relationships between physiological markers (like BMI and Blood Pressure) and the target. It handles missing values internally (if any exist) and includes regularization (L1/L2) to prevent overfitting on smaller datasets.
# We will need to encode our categorical variables (One-Hot or Label Encoding) before feeding them into XGBoost, as it treats inputs as numerical matrices.
# The notebook is one of a number of notebooks that explore various models to address this challenge.  The EDA for this dataset was performed in this notebook: [**PS-S06E01: EDA**](https://www.kaggle.com/code/stephentarter/ps-s06e01-eda).

# %%
import os
import sys
import math
import random
import warnings
from pathlib import Path
from typing import Iterable
from IPython.display import display, Markdown, IFrame

# --- Third-party
import numpy as np
import pandas as pd
import xgboost as xgb
import optuna
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, roc_curve
from sklearn.preprocessing import OrdinalEncoder
from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt
import seaborn as sns

from ps_s06e01_feature_engineering import FeatureFactory
from ps_s06e01_model_visualizer import ModelVisualizer
from ps_s06e01_experiment_setup import ExperimentSetup

# --- Notebook settings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
helper = ExperimentSetup()

# Get the seed, and apply it to all the internals like pandas and numpy
seed = helper.set_seeds()

helper.configure_pandas()
helper.suppress_warnings()

# The target feature
TARGET = 'exam_score'

# Show GPU be utilized in training
USE_GPU = False

# Recursive Feature Elimination should be performed in the pipeline.
PERFORM_RFE = False

# Optuna tuning should be performed in the pipeline
PERFORM_OPTUNA_TUNING = False
# Out:
# Random seed set to: 10301
# Warnings suppressed.

# %% [markdown]
# ## Read and Examine the Training Dataset

# %%
training_df = helper.read_training_dataset()
# Out:
# TRAINING DATASET
# ================
#
#    id  age  gender   course  study_hours  class_attendance internet_access  \
# 0   0   21  female     b.sc        7.910            98.800              no
# 1   1   18   other  diploma        4.950            94.800             yes
# 2   2   20  female     b.sc        4.680            92.600             yes
# 3   3   19    male     b.sc        2.000            49.500             yes
# 4   4   23    male      bca        7.650            86.900             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty  \
# 0        4.900       average  online videos             low            easy
# 1        4.700          poor     self-study          medium        moderate
# 2        5.800          poor       coaching            high        moderate
# 3        8.300       average    group study            high        moderate
# 4        9.600          good     self-study            high            easy
#
#    exam_score
# 0      78.300
# 1      46.700
# 2      99.000
# 3      63.900
# 4     100.000

# %%
test_df = helper.read_test_dataset()
# Out:
# TEST DATASET
# ============
#
#        id  age  gender   course  study_hours  class_attendance  \
# 0  630000   24   other       ba        6.850            65.200
# 1  630001   18    male  diploma        6.610            45.000
# 2  630002   24  female   b.tech        6.600            98.500
# 3  630003   24    male  diploma        3.030            66.300
# 4  630004   20  female   b.tech        2.030            42.400
#
#   internet_access  sleep_hours sleep_quality study_method facility_rating  \
# 0             yes        5.200          poor  group study            high
# 1              no        9.300          poor     coaching             low
# 2             yes        6.200          good  group study          medium
# 3             yes        5.700       average        mixed          medium
# 4             yes        9.200       average     coaching             low
#
#   exam_difficulty
# 0            easy
# 1            easy
# 2        moderate
# 3        moderate
# 4        moderate

# %% [markdown]
# ## Feature Engineering

# %%
# Define which strategies to use for the XGBoost model here:
fe_strategies = [
    'drop_id',
]
#    Other strategies
#
#   'ordinal_encoding',
#   'binning',
#   'interactions',
#   'clustering',

# %%
print('Performing initial feature engineering.')

# Get the target before we start messing with features
y = training_df[TARGET]

# Initialize and apply the feature factory
feature_engineer = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)

# Fit_transform on training, transform on test
X_full = feature_engineer.fit_transform(training_df)
X_test = feature_engineer.transform(test_df)

X = X_full.drop(TARGET, axis=1, errors='ignore')

print(f'Old Feature Count: {training_df.shape[1] - 1}')
print(f'New Feature Count: {X.shape[1]}')
print(X.head())
# Out:
# Performing initial feature engineering.
# Old Feature Count: 12
# New Feature Count: 11
#    age  gender   course  study_hours  class_attendance internet_access  \
# 0   21  female     b.sc        7.910            98.800              no
# 1   18   other  diploma        4.950            94.800             yes
# 2   20  female     b.sc        4.680            92.600             yes
# 3   19    male     b.sc        2.000            49.500             yes
# 4   23    male      bca        7.650            86.900             yes
#
#    sleep_hours sleep_quality   study_method facility_rating exam_difficulty
# 0        4.900       average  online videos             low            easy
# 1        4.700          poor     self-study          medium        moderate
# 2        5.800          poor       coaching            high        moderate
# 3        8.300       average    group study            high        moderate
# 4        9.600          good     self-study            high            easy

# %% [markdown]
# ## Optional Recursive Feature Elimination and Optuna Training
#
# If the `PERFORM_RFE` variable in cell 3 is set to True, Recursive Feature Elimination (RFE) is performed.  This works by training the model, identifying the weakest feature, deleting it, and then re-training. It repeats this process until it finds the exact subset of features that gives the highest Cross-Validation score.  This step is performed on a temporary feature engineered dataset to determine the optimal set of features, which are used to filter the in-fold feature engineered dataset.  If the variable is set to False, all features are used in training.
#
# If the `PERFORM_OPTUNA_TUNING` variable in cell 3 is set to True, an Optuna trial is performed to determine the best set of hyperscaling parameters.  If training isn't requested, a set of hyperparameters derived from an earlier run is used instead.

# %%
n_jobs = 1 if USE_GPU else -1

# Convert object columns to 'category' dtype
X_rfe = X.copy()

# Identify string/object columns
cat_cols = X_rfe.select_dtypes(include=['object', 'category']).columns.tolist()

if cat_cols:
    # Use OrdinalEncoder to turn "Female" -> 0, "Male" -> 1
    oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
    X_rfe[cat_cols] = oe.fit_transform(X_rfe[cat_cols])
    
    # Ensure they are cast to integer type for XGBoost
    # We cast to 'category' type so XGBoost knows to treat them as discrete
    for col in cat_cols:
        X_rfe[col] = X_rfe[col].astype('category')
        
if PERFORM_RFE:    
    # Suppress the specific XGBoost warning to clean up the output
    warnings.filterwarnings('ignore', message='.*Falling back to prediction using DMatrix.*')
    
    # Use a "stfe" set of parameters
    rfe_params = {
        'n_estimators': 1000,
        'learning_rate': 0.05,
        'max_depth': 6,          # Standard starting depth
        'colsample_bytree': 0.8, # Allow it to see most features
        'reg_alpha': 0.1,        # Light regularization only
        'device': 'cuda',
        'tree_method': 'hist',
        'enable_categorical': True
    }
    
    # 'gpu_hist' is removed. Now we use 'hist' + device='cuda'
    if USE_GPU:
        rfe_params['device'] = 'cuda'
    else:
        rfe_params['device'] = 'cpu'
    
    # Setup Model with Best Params
    # We use the exact same params that found the signal in the noise
    clf = xgb.XGBClassifier(**rfe_params)

    # Initialize RFECV
    # step=1: remove 1 feature at a time (most precise)
    # min_features_to_select=10: Don't go below 10 features
    rfecv = RFECV(
        estimator=clf,
        step=1,
        cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=seed),
        scoring='roc_auc',
        min_features_to_select=15,
        n_jobs=n_jobs,
        verbose=0
    )
    
    print('Running Recursive Feature Elimination (this will take a few minutes)...')
    rfecv.fit(X_rfe, y)
    
    # Results
    print(f'Optimal number of features: {rfecv.n_features_}')
    
    # Plot Performance vs Number of Features
    # Note: usage of cv_results_ depends on sklearn version, this is for recent versions
    n_scores = len(rfecv.cv_results_['mean_test_score'])
    plt.figure(figsize=(10, 6))
    plt.xlabel('Number of features selected')
    plt.ylabel('Cross validation score (AUC)')
    plt.plot(
        range(10, 10 + n_scores),
        rfecv.cv_results_['mean_test_score']
    )
    plt.show()

    # Save the selected features for the next step
    optimal_cols = X_rfe.columns[rfecv.support_]
else:
    print('Using all columns as optimal features.')
    optimal_cols = X_rfe.columns
    
print('\nOptimal Features:')
print(optimal_cols.tolist())
# Out:
# Using all columns as optimal features.
#
# Optimal Features:
# ['age', 'gender', 'course', 'study_hours', 'class_attendance', 'internet_access', 'sleep_hours', 'sleep_quality', 'study_method', 'facility_rating', 'exam_difficulty']

# %%
def objective(trial):
    
    # Suggest Parameters
    param = {
        # Core Booster Params
        'n_estimators': 5000,               # High cap, rely on early_stopping
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'min_child_weight': trial.suggest_float('min_child_weight', 1.0, 50.0, log=True),
        'subsample': trial.suggest_float('subsample', 0.5, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 0.95),
        
        # Regularization
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-3, 10.0, log=True),  # L1
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-3, 10.0, log=True), # L2
        'gamma': trial.suggest_float('gamma', 0.1, 5.0),
        
        # Tree Structure
        'grow_policy': trial.suggest_categorical('grow_policy', ['depthwise', 'lossguide']),
        
        # Boilerplate for Regression
        'objective': 'reg:squarederror',    # <--- Standard for RMSE
        'eval_metric': 'rmse',              # <--- Metric to optimize
        'tree_method': 'gpu_hist' if USE_GPU else 'hist',
        'enable_categorical': True,
        'early_stopping_rounds': 50,
        'random_state': seed,
        'n_jobs': n_jobs
    }

    # Ensure optimal_cols is a standard list for filtering
    cols_to_keep = list(optimal_cols) if not isinstance(optimal_cols, list) else optimal_cols
    
    # Initialize Standard K-Fold (Shuffle is critical for regression)
    kf = KFold(n_splits=5, shuffle=True, random_state=seed)
    
    cv_scores = []

    # Standard CV Loop
    for fold, (train_idx, val_idx) in enumerate(kf.split(training_df, y)):
        
        # Create Folds
        X_train_fold = training_df.iloc[train_idx]
        y_train_fold = y.iloc[train_idx]
        
        X_val_fold = training_df.iloc[val_idx]
        y_val_fold = y.iloc[val_idx]
        
        # Feature Engineering (Per fold to prevent leakage)
        fe_fold = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
        
        X_train_trans = fe_fold.fit_transform(X_train_fold)
        X_val_trans = fe_fold.transform(X_val_fold)

        # Restrict to optimal column set
        if cols_to_keep is not None:
            final_cols = [c for c in cols_to_keep if c in X_train_trans.columns]
            if not final_cols:
                raise RuntimeError("No overlap between optimal_cols and fold feature columns.")
            X_train_trans = X_train_trans[final_cols]
            X_val_trans   = X_val_trans[final_cols]
        
        # Identify categorical columns for XGBoost
        # XGBoost requires 'category' dtype for enable_categorical=True
        cat_cols = X_train_trans.select_dtypes(include=['object', 'category']).columns.tolist()
        if cat_cols:
            for c in cat_cols:
                X_train_trans[c] = X_train_trans[c].astype('category')
                X_val_trans[c]   = X_val_trans[c].astype('category')
            
        # Create model (Regressor)
        model = xgb.XGBRegressor(**param)

        # Train the model
        model.fit(
            X_train_trans, y_train_fold,
            eval_set=[(X_val_trans, y_val_fold)],
            verbose=False
        )
        
        # Predict
        val_preds = model.predict(X_val_trans)
        
        # CLIP predictions to valid range (0-100)
        # This is a critical optimization for RMSE on bounded targets
        val_preds = np.clip(val_preds, 0, 100)
        
        # Score this fold
        fold_rmse = np.sqrt(mean_squared_error(y_val_fold, val_preds))
        cv_scores.append(fold_rmse)

    # Return the average RMSE across all folds
    return np.mean(cv_scores)

# %%
if PERFORM_OPTUNA_TUNING:
    print("Starting XGBoost Optuna Optimization...")
    
    # Use MedianPruner for efficiency
    pruner = optuna.pruners.MedianPruner(
        n_startup_trials=5,
        n_warmup_steps=10
    )
    
    study_xgb = optuna.create_study(
        direction='minimize',
        study_name='xgb_student_test_scores_optuna', 
        pruner=pruner)
    
    study_xgb.optimize(
        objective,
        n_trials=50,
        show_progress_bar=True,
        timeout=18000,  # 5 hours
    )
    
    print("\nBest Trial:")
    print(f"  RMSE: {study_xgb.best_value:.5f}")
    print("  Params: ", study_xgb.best_params)
    
    xgb_best_params = study_xgb.best_params
else:
    # Placeholder for manually tuned params if you skip optuna
    xgb_best_params = {
        'learning_rate': 0.013990215499161093,
        'max_depth': 6,
        'min_child_weight': 1.4425033535788745,
        'subsample': 0.8894820282793995,
        'colsample_bytree': 0.7473735194517545,
        'reg_alpha': 0.0023956873156932845,
        'reg_lambda': 0.001976726479539849,
        'gamma': 2.5221307703428075,
        'grow_policy': 'depthwise'
    }
# Out:
# [I 2026-01-10 15:06:35,201] A new study created in memory with name: xgb_student_test_scores_optuna
# Starting XGBoost Optuna Optimization...
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2026-01-10 15:08:22,880] Trial 0 finished with value: 8.811822776752281 and parameters: {'learning_rate': 0.0050173337598805965, 'max_depth': 3, 'min_child_weight': 13.573504284678522, 'subsample': 0.8763409514305498, 'colsample_bytree': 0.9442811254474996, 'reg_alpha': 6.591877906602019, 'reg_lambda': 2.7435418188878495, 'gamma': 3.8278980966895326, 'grow_policy': 'lossguide'}. Best is trial 0 with value: 8.811822776752281.
# [I 2026-01-10 15:09:37,417] Trial 1 finished with value: 8.755246004478625 and parameters: {'learning_rate': 0.05191565215786827, 'max_depth': 6, 'min_child_weight': 1.247063910794356, 'subsample': 0.7028516221145977, 'colsample_bytree': 0.7539696931838274, 'reg_alpha': 0.07300841285973611, 'reg_lambda': 0.0038025916083748537, 'gamma': 2.2927690697720804, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 8.755246004478625.
# [I 2026-01-10 15:11:23,856] Trial 2 finished with value: 8.768156350605839 and parameters: {'learning_rate': 0.038033559382731744, 'max_depth': 3, 'min_child_weight': 9.631240947051543, 'subsample': 0.64022494464798, 'colsample_bytree': 0.6946450822587837, 'reg_alpha': 0.1616752410308358, 'reg_lambda': 1.4193935024494648, 'gamma': 0.49187555296037655, 'grow_policy': 'depthwise'}. Best is trial 1 with value: 8.755246004478625.
# [I 2026-01-10 15:15:30,539] Trial 3 finished with value: 8.757601609052745 and parameters: {'learning_rate': 0.030482363278627377, 'max_depth': 10, 'min_child_weight': 43.16834644620638, 'subsample': 0.8117130409934066, 'colsample_bytree': 0.599869414969481, 'reg_alpha': 0.021002350035575844, 'reg_lambda': 0.7959878811992703, 'gamma': 0.9393026693629385, 'grow_policy': 'lossguide'}. Best is trial 1 with value: 8.755246004478625.
# [I 2026-01-10 15:16:56,423] Trial 4 finished with value: 8.753158847679567 and parameters: {'learning_rate': 0.03676228843205876, 'max_depth': 5, 'min_child_weight': 42.70150118587545, 'subsample': 0.8567949204304255, 'colsample_bytree': 0.5909218123535538, 'reg_alpha': 0.004709046541777835, 'reg_lambda': 0.009753515397697777, 'gamma': 1.3937358125337644, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:17:48,367] Trial 5 finished with value: 8.780745419728735 and parameters: {'learning_rate': 0.08641537109338293, 'max_depth': 8, 'min_child_weight': 1.3640965821105138, 'subsample': 0.5045816391109342, 'colsample_bytree': 0.9006394976873886, 'reg_alpha': 6.180512563846315, 'reg_lambda': 0.034579395044202675, 'gamma': 3.3407563207813165, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:18:13,827] Trial 6 finished with value: 8.77066883973919 and parameters: {'learning_rate': 0.07688238475378484, 'max_depth': 9, 'min_child_weight': 11.880261627752665, 'subsample': 0.7796918254819237, 'colsample_bytree': 0.6231537255070696, 'reg_alpha': 0.10580202734618867, 'reg_lambda': 0.07291294427058037, 'gamma': 4.025307588977675, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:20:03,599] Trial 7 finished with value: 8.782885668833313 and parameters: {'learning_rate': 0.017366165256070022, 'max_depth': 3, 'min_child_weight': 4.597263735662359, 'subsample': 0.8691154869655784, 'colsample_bytree': 0.634611386355082, 'reg_alpha': 0.5043306224914339, 'reg_lambda': 0.007499000033326204, 'gamma': 3.0638860660116207, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:23:12,249] Trial 8 finished with value: 8.75376516872997 and parameters: {'learning_rate': 0.018805729712511383, 'max_depth': 7, 'min_child_weight': 25.467999013142443, 'subsample': 0.5555376639760148, 'colsample_bytree': 0.7220327185618922, 'reg_alpha': 0.0013141730507641933, 'reg_lambda': 1.3905626934999575, 'gamma': 1.1037953374179017, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:25:33,702] Trial 9 finished with value: 8.755390778933599 and parameters: {'learning_rate': 0.022753778544901803, 'max_depth': 5, 'min_child_weight': 8.5721737472085, 'subsample': 0.5732347290714366, 'colsample_bytree': 0.667710162920797, 'reg_alpha': 0.3051690852929561, 'reg_lambda': 0.007194194147244426, 'gamma': 1.4893321115717357, 'grow_policy': 'lossguide'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:27:52,195] Trial 10 finished with value: 8.768224950324452 and parameters: {'learning_rate': 0.009580292223302212, 'max_depth': 5, 'min_child_weight': 3.2182729006088295, 'subsample': 0.7475133896802897, 'colsample_bytree': 0.5008051048851553, 'reg_alpha': 0.0010418190500347325, 'reg_lambda': 0.0011887131257068131, 'gamma': 4.723145082437723, 'grow_policy': 'depthwise'}. Best is trial 4 with value: 8.753158847679567.
# [I 2026-01-10 15:29:25,903] Trial 11 finished with value: 8.750033997824222 and parameters: {'learning_rate': 0.0167758640098292, 'max_depth': 7, 'min_child_weight': 45.89931901682712, 'subsample': 0.6309939943181331, 'colsample_bytree': 0.7934979418635254, 'reg_alpha': 0.0012217333101746375, 'reg_lambda': 8.342682887677537, 'gamma': 1.85517206812473, 'grow_policy': 'depthwise'}. Best is trial 11 with value: 8.750033997824222.
# [I 2026-01-10 15:31:41,225] Trial 12 finished with value: 8.75580159158341 and parameters: {'learning_rate': 0.011486367991882901, 'max_depth': 5, 'min_child_weight': 49.049073019023176, 'subsample': 0.6516857040221118, 'colsample_bytree': 0.8143811036171823, 'reg_alpha': 0.008279311868675837, 'reg_lambda': 9.489039989928688, 'gamma': 2.0371183085108173, 'grow_policy': 'depthwise'}. Best is trial 11 with value: 8.750033997824222.
# [I 2026-01-10 15:32:19,885] Trial 13 finished with value: 8.757539316523394 and parameters: {'learning_rate': 0.04746368827567684, 'max_depth': 7, 'min_child_weight': 25.453309944546678, 'subsample': 0.6641969166312414, 'colsample_bytree': 0.8137718045790465, 'reg_alpha': 0.00455731282593757, 'reg_lambda': 0.19695547603414612, 'gamma': 0.1391257461112978, 'grow_policy': 'depthwise'}. Best is trial 11 with value: 8.750033997824222.
# [I 2026-01-10 15:34:50,687] Trial 14 finished with value: 8.757281873058275 and parameters: {'learning_rate': 0.011680357460662084, 'max_depth': 6, 'min_child_weight': 23.186661456809002, 'subsample': 0.5929855577140201, 'colsample_bytree': 0.537908392580649, 'reg_alpha': 0.0041083139990017396, 'reg_lambda': 0.29927650599411265, 'gamma': 1.7833259562997694, 'grow_policy': 'depthwise'}. Best is trial 11 with value: 8.750033997824222.
# [I 2026-01-10 15:35:45,522] Trial 15 finished with value: 8.751867900312396 and parameters: {'learning_rate': 0.030474911350707352, 'max_depth': 8, 'min_child_weight': 34.18744355247756, 'subsample': 0.8308192154114277, 'colsample_bytree': 0.7864037657583388, 'reg_alpha': 0.023791592072435537, 'reg_lambda': 0.034290635058117636, 'gamma': 2.772115946448845, 'grow_policy': 'depthwise'}. Best is trial 11 with value: 8.750033997824222.
# [I 2026-01-10 15:38:52,472] Trial 16 finished with value: 8.748064815337305 and parameters: {'learning_rate': 0.007301312876044446, 'max_depth': 8, 'min_child_weight': 18.010932794358673, 'subsample': 0.7322684644642315, 'colsample_bytree': 0.7828609293611254, 'reg_alpha': 0.033813970306271666, 'reg_lambda': 0.03497691946603, 'gamma': 2.7650330288224207, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:42:50,199] Trial 17 finished with value: 8.750974555879 and parameters: {'learning_rate': 0.00509748145174647, 'max_depth': 9, 'min_child_weight': 17.029609485193625, 'subsample': 0.717947304435024, 'colsample_bytree': 0.8587459837513107, 'reg_alpha': 0.9866969991979112, 'reg_lambda': 8.388212070764679, 'gamma': 2.515359751745838, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:45:12,609] Trial 18 finished with value: 8.749444863538528 and parameters: {'learning_rate': 0.007347677651481327, 'max_depth': 8, 'min_child_weight': 5.831438670340523, 'subsample': 0.755545369951565, 'colsample_bytree': 0.8621610578394332, 'reg_alpha': 0.015767469996068793, 'reg_lambda': 0.031547551344879965, 'gamma': 3.6028828641936292, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:47:53,249] Trial 19 finished with value: 8.758209818451952 and parameters: {'learning_rate': 0.0075245826373964856, 'max_depth': 10, 'min_child_weight': 5.172955916698372, 'subsample': 0.7597717395936097, 'colsample_bytree': 0.8666001795868854, 'reg_alpha': 0.02438061527362586, 'reg_lambda': 0.0376277172175064, 'gamma': 4.518939639992767, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:50:29,856] Trial 20 finished with value: 8.75002840269706 and parameters: {'learning_rate': 0.007051843268282531, 'max_depth': 8, 'min_child_weight': 2.5989165004930177, 'subsample': 0.7910717309980645, 'colsample_bytree': 0.9487057790686949, 'reg_alpha': 0.044732206412711834, 'reg_lambda': 0.13249773359519584, 'gamma': 3.626521918087625, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:52:52,417] Trial 21 finished with value: 8.750815203662238 and parameters: {'learning_rate': 0.007685693430946668, 'max_depth': 8, 'min_child_weight': 2.3604309157017487, 'subsample': 0.8035697952757648, 'colsample_bytree': 0.9454163018072463, 'reg_alpha': 0.04969688999049664, 'reg_lambda': 0.1264175415598242, 'gamma': 3.529889018042125, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:55:35,109] Trial 22 finished with value: 8.752010030053933 and parameters: {'learning_rate': 0.006817915820578499, 'max_depth': 9, 'min_child_weight': 2.191020305544957, 'subsample': 0.7340547491107288, 'colsample_bytree': 0.8945497475181287, 'reg_alpha': 0.010955438549780143, 'reg_lambda': 0.018061980455930438, 'gamma': 4.207913181844827, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:57:05,695] Trial 23 finished with value: 8.750663420130788 and parameters: {'learning_rate': 0.012488537639978868, 'max_depth': 8, 'min_child_weight': 6.032916741195625, 'subsample': 0.7829224564600679, 'colsample_bytree': 0.8492434713770056, 'reg_alpha': 0.04589843794703349, 'reg_lambda': 0.3796061006353037, 'gamma': 3.0087581200202265, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 15:59:53,807] Trial 24 finished with value: 8.752372036677013 and parameters: {'learning_rate': 0.006230299511020882, 'max_depth': 9, 'min_child_weight': 3.617282863073847, 'subsample': 0.6845317261893321, 'colsample_bytree': 0.904310771929624, 'reg_alpha': 0.20514917492252105, 'reg_lambda': 0.09511238358226423, 'gamma': 3.646308727916235, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 16:02:06,227] Trial 25 finished with value: 8.749390236600124 and parameters: {'learning_rate': 0.00819941677584094, 'max_depth': 8, 'min_child_weight': 1.9537634384435043, 'subsample': 0.7645621037303486, 'colsample_bytree': 0.8387213068509914, 'reg_alpha': 0.012399395239615077, 'reg_lambda': 0.052902377532866786, 'gamma': 3.2894057064468916, 'grow_policy': 'depthwise'}. Best is trial 16 with value: 8.748064815337305.
# [I 2026-01-10 16:04:17,435] Trial 26 finished with value: 8.746839925322035 and parameters: {'learning_rate': 0.0091436405043776, 'max_depth': 7, 'min_child_weight': 1.6741297732745395, 'subsample': 0.8326962310884621, 'colsample_bytree': 0.7453795743780236, 'reg_alpha': 0.010568143867135844, 'reg_lambda': 0.01651835225832733, 'gamma': 3.1224859096233306, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 8.746839925322035.
# [I 2026-01-10 16:06:22,377] Trial 27 finished with value: 8.747754085034728 and parameters: {'learning_rate': 0.00960774215433974, 'max_depth': 6, 'min_child_weight': 1.0154042446956812, 'subsample': 0.8976794568418214, 'colsample_bytree': 0.7551101296180186, 'reg_alpha': 0.007628790949661164, 'reg_lambda': 0.0023054190801542634, 'gamma': 3.1553876127782954, 'grow_policy': 'depthwise'}. Best is trial 26 with value: 8.746839925322035.
# [I 2026-01-10 16:08:07,700] Trial 28 finished with value: 8.746314068714168 and parameters: {'learning_rate': 0.013990215499161093, 'max_depth': 6, 'min_child_weight': 1.4425033535788745, 'subsample': 0.8894820282793995, 'colsample_bytree': 0.7473735194517545, 'reg_alpha': 0.0023956873156932845, 'reg_lambda': 0.001976726479539849, 'gamma': 2.5221307703428075, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:09:29,134] Trial 29 finished with value: 8.76265829004039 and parameters: {'learning_rate': 0.014206795106419836, 'max_depth': 4, 'min_child_weight': 1.0064293048992503, 'subsample': 0.8760187266268477, 'colsample_bytree': 0.7490277825351516, 'reg_alpha': 0.002744001426594106, 'reg_lambda': 0.0010167548072919112, 'gamma': 2.2591807516448936, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:11:31,385] Trial 30 finished with value: 8.749837488096635 and parameters: {'learning_rate': 0.010016943870293284, 'max_depth': 6, 'min_child_weight': 1.5545639666366355, 'subsample': 0.8994238718320244, 'colsample_bytree': 0.6967409032477486, 'reg_alpha': 0.0019904211062421982, 'reg_lambda': 0.002650037078547676, 'gamma': 2.5825205237712807, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:14:09,927] Trial 31 finished with value: 8.750573031836225 and parameters: {'learning_rate': 0.005292525334471199, 'max_depth': 7, 'min_child_weight': 1.7299265300149396, 'subsample': 0.8391379514063833, 'colsample_bytree': 0.7638525997863425, 'reg_alpha': 0.006654976298941231, 'reg_lambda': 0.002639698606694913, 'gamma': 2.798118989511801, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:16:07,386] Trial 32 finished with value: 8.747816106027667 and parameters: {'learning_rate': 0.009753742338580831, 'max_depth': 6, 'min_child_weight': 1.0919120236703543, 'subsample': 0.8921020936735217, 'colsample_bytree': 0.7275151758140248, 'reg_alpha': 0.0023016360482877303, 'reg_lambda': 0.01460561592292819, 'gamma': 3.0720200266045308, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:18:06,588] Trial 33 finished with value: 8.750346430494513 and parameters: {'learning_rate': 0.009737964124251684, 'max_depth': 6, 'min_child_weight': 1.0299898034253048, 'subsample': 0.8994354269538486, 'colsample_bytree': 0.7259226439415282, 'reg_alpha': 0.002368891723427379, 'reg_lambda': 0.004738827910271394, 'gamma': 3.144432410927416, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:19:46,451] Trial 34 finished with value: 8.765148578017886 and parameters: {'learning_rate': 0.0144737483657777, 'max_depth': 4, 'min_child_weight': 1.3003764669628586, 'subsample': 0.8460070023583193, 'colsample_bytree': 0.6785630580067702, 'reg_alpha': 0.002649024546661213, 'reg_lambda': 0.015277208494286466, 'gamma': 3.965698882990193, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:20:49,441] Trial 35 finished with value: 8.749170944315214 and parameters: {'learning_rate': 0.021765133598834824, 'max_depth': 6, 'min_child_weight': 1.1999031090514187, 'subsample': 0.8230425632937562, 'colsample_bytree': 0.7469395925251061, 'reg_alpha': 0.007238587714024315, 'reg_lambda': 0.001931767702685823, 'gamma': 2.330501973751208, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:23:00,547] Trial 36 finished with value: 8.747911968475808 and parameters: {'learning_rate': 0.009009360546576015, 'max_depth': 7, 'min_child_weight': 1.616161077021769, 'subsample': 0.8779638631619087, 'colsample_bytree': 0.7208843536074075, 'reg_alpha': 0.004075865376375662, 'reg_lambda': 0.004431291492189686, 'gamma': 2.9309149162721546, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:24:44,314] Trial 37 finished with value: 8.76675543046829 and parameters: {'learning_rate': 0.013497683540495594, 'max_depth': 4, 'min_child_weight': 1.2652294823437293, 'subsample': 0.8631803258361812, 'colsample_bytree': 0.6627421357294985, 'reg_alpha': 0.0018484870760454898, 'reg_lambda': 0.013648872800197472, 'gamma': 4.321543056931864, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:26:26,307] Trial 38 finished with value: 8.758282124546117 and parameters: {'learning_rate': 0.010339836125505339, 'max_depth': 5, 'min_child_weight': 2.864622192198564, 'subsample': 0.8848387696247725, 'colsample_bytree': 0.7019759726110297, 'reg_alpha': 0.006690900336614329, 'reg_lambda': 0.0019014880363128085, 'gamma': 2.071997297806437, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:28:32,000] Trial 39 finished with value: 8.756749422289966 and parameters: {'learning_rate': 0.0059725365350876, 'max_depth': 6, 'min_child_weight': 1.9117623010337474, 'subsample': 0.8467770653239433, 'colsample_bytree': 0.7652430811148623, 'reg_alpha': 0.09651839286684705, 'reg_lambda': 0.006163293673144592, 'gamma': 3.3229630403194035, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:32:01,738] Trial 40 finished with value: 8.747709897065791 and parameters: {'learning_rate': 0.01581193460534495, 'max_depth': 6, 'min_child_weight': 1.509457496789599, 'subsample': 0.899622305124173, 'colsample_bytree': 0.6481113837267535, 'reg_alpha': 1.232208008423158, 'reg_lambda': 0.00970687589430595, 'gamma': 3.8202519946627413, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:35:12,032] Trial 41 finished with value: 8.748941110755977 and parameters: {'learning_rate': 0.01644061803329757, 'max_depth': 6, 'min_child_weight': 1.442054836588053, 'subsample': 0.8992461983863859, 'colsample_bytree': 0.6427240702768412, 'reg_alpha': 6.052510769224283, 'reg_lambda': 0.011632271159999848, 'gamma': 3.8800857065458008, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:37:51,495] Trial 42 finished with value: 8.752908353688042 and parameters: {'learning_rate': 0.02245280213930128, 'max_depth': 7, 'min_child_weight': 1.1116809837648005, 'subsample': 0.8625774740174695, 'colsample_bytree': 0.60363027151635, 'reg_alpha': 1.9788952493289227, 'reg_lambda': 0.020019072907297764, 'gamma': 3.2729691876023814, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:39:39,257] Trial 43 finished with value: 8.749650571847202 and parameters: {'learning_rate': 0.027483062512133213, 'max_depth': 6, 'min_child_weight': 3.657476759180277, 'subsample': 0.819375406912457, 'colsample_bytree': 0.737207612537297, 'reg_alpha': 4.0220300528229105, 'reg_lambda': 0.003526141360802407, 'gamma': 4.949644316069636, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:42:15,362] Trial 44 finished with value: 8.756749244924626 and parameters: {'learning_rate': 0.011222347548685944, 'max_depth': 5, 'min_child_weight': 2.070113831732019, 'subsample': 0.8807127654832866, 'colsample_bytree': 0.7144452620791761, 'reg_alpha': 0.8489125427723033, 'reg_lambda': 0.008766044205121577, 'gamma': 2.553734826425384, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:44:51,037] Trial 45 finished with value: 8.76540026570019 and parameters: {'learning_rate': 0.008635029156735025, 'max_depth': 5, 'min_child_weight': 1.5166911779926846, 'subsample': 0.8556372512343481, 'colsample_bytree': 0.5702135176537777, 'reg_alpha': 0.001552009158483452, 'reg_lambda': 0.0015092582159957396, 'gamma': 3.459673766437828, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:47:57,633] Trial 46 finished with value: 8.750292510829246 and parameters: {'learning_rate': 0.01890722829889827, 'max_depth': 7, 'min_child_weight': 1.0005797713213291, 'subsample': 0.8816554622973747, 'colsample_bytree': 0.681534033927603, 'reg_alpha': 0.003705386747669752, 'reg_lambda': 0.0056257011161135895, 'gamma': 3.035958959323283, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:49:32,289] Trial 47 finished with value: 8.749737188477502 and parameters: {'learning_rate': 0.015269896051088912, 'max_depth': 6, 'min_child_weight': 1.308581463064318, 'subsample': 0.8010269623564773, 'colsample_bytree': 0.643492949214387, 'reg_alpha': 0.015678912166480596, 'reg_lambda': 0.003011122964502104, 'gamma': 4.162425435803614, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:52:09,176] Trial 48 finished with value: 8.752329340148732 and parameters: {'learning_rate': 0.012659098007864921, 'max_depth': 5, 'min_child_weight': 1.765691774242039, 'subsample': 0.8385547445320494, 'colsample_bytree': 0.8178566760393455, 'reg_alpha': 0.0010652387963246846, 'reg_lambda': 0.022040465394355117, 'gamma': 3.7605431681206714, 'grow_policy': 'lossguide'}. Best is trial 28 with value: 8.746314068714168.
# [I 2026-01-10 16:53:14,775] Trial 49 finished with value: 8.748387089482604 and parameters: {'learning_rate': 0.019371900087596667, 'max_depth': 7, 'min_child_weight': 2.4958794701520373, 'subsample': 0.8639667041704728, 'colsample_bytree': 0.7704792735899827, 'reg_alpha': 0.551350637885731, 'reg_lambda': 0.009050028502679367, 'gamma': 1.6150639952283088, 'grow_policy': 'depthwise'}. Best is trial 28 with value: 8.746314068714168.
#
# Best Trial:
#   RMSE: 8.74631
#   Params:  {'learning_rate': 0.013990215499161093, 'max_depth': 6, 'min_child_weight': 1.4425033535788745, 'subsample': 0.8894820282793995, 'colsample_bytree': 0.7473735194517545, 'reg_alpha': 0.0023956873156932845, 'reg_lambda': 0.001976726479539849, 'gamma': 2.5221307703428075, 'grow_policy': 'depthwise'}

# %%
## Model Training

# %%
xgb_tuned_params = {
    **xgb_best_params, # Unpack Optuna best params
    'n_estimators': 12000,
    'objective': 'reg:squarederror', # Standard for Regression
    'eval_metric': 'rmse',           # Metric to optimize
    'n_jobs': n_jobs,
    'random_state': seed,
    'early_stopping_rounds': 50,
    'tree_method': 'gpu_hist' if USE_GPU else 'hist',
    'enable_categorical': True,
}

print('Final XGBoost CV Training with OOF / Test predictions')
print('======================================================')
print('Parameters used for training:')
print(xgb_tuned_params)

# Ensure optimal_cols is a standard list
cols_to_keep = list(optimal_cols) if not isinstance(optimal_cols, list) else optimal_cols

# Initialize Standard K-Fold
n_folds = 5
kf = KFold(n_splits=n_folds, shuffle=True, random_state=seed)

# Storage for plotting later
eval_results = []
models = []

# Arrays to store results
oof_preds = np.zeros(len(y))
test_preds = np.zeros(len(test_df))

# Standard CV Loop
for fold, (train_idx, val_idx) in enumerate(kf.split(training_df, y)):

    print(f"Starting processing of fold {fold+1}")

    # Create Folds
    X_train_fold = training_df.iloc[train_idx]
    y_train_fold = y.iloc[train_idx]
    
    X_val_fold = training_df.iloc[val_idx]
    y_val_fold = y.iloc[val_idx]
    
    # Feature Engineering
    fe_fold = FeatureFactory(strategies=fe_strategies, target=TARGET, seed=seed)
    
    X_train_trans = fe_fold.fit_transform(X_train_fold)
    X_val_trans = fe_fold.transform(X_val_fold)
    X_test_trans = fe_fold.transform(test_df)
    
    # Restrict to optimal column set
    if cols_to_keep is not None:
        final_cols = [c for c in cols_to_keep if c in X_train_trans.columns]
        if not final_cols:
            raise RuntimeError("No overlap between optimal_cols and fold feature columns.")
        X_train_trans = X_train_trans[final_cols]
        X_val_trans   = X_val_trans[final_cols]
        X_test_trans  = X_test_trans[final_cols]

    # Handle Categoricals
    cat_cols = X_train_trans.select_dtypes(include=['object', 'category']).columns.tolist()

    if cat_cols:
        # Use OrdinalEncoder to turn "Female" -> 0, "Male" -> 1
        oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
        X_train_trans[cat_cols] = oe.fit_transform(X_train_trans[cat_cols])
        X_val_trans[cat_cols] = oe.transform(X_val_trans[cat_cols])
        X_test_trans[cat_cols] = oe.transform(X_test_trans[cat_cols])

        # Cast to 'category' so XGBoost handles them as discrete partitions
        for col in cat_cols:
            X_train_trans[col] = X_train_trans[col].astype('category')
            X_val_trans[col] = X_val_trans[col].astype('category')
            X_test_trans[col] = X_test_trans[col].astype('category')
        
    # Create model (Regressor)
    model = xgb.XGBRegressor(**xgb_tuned_params)
    
    # Train Model
    model.fit(
        X_train_trans, y_train_fold,
        # eval_set order: [validation, train] so we can track both
        eval_set=[(X_val_trans, y_val_fold), (X_train_trans, y_train_fold)],
        verbose=100
    )
    
    # Store history
    eval_results.append(model.evals_result())
    models.append(model)
    
    # Predict OOF (Regression returns values directly)
    val_preds = model.predict(X_val_trans)
    
    # CLIP predictions (Critical for RMSE optimization)
    val_preds = np.clip(val_preds, 0, 100)
    
    oof_preds[val_idx] = val_preds
    
    # Score this fold
    fold_rmse = np.sqrt(mean_squared_error(y_val_fold, val_preds))
    print(f"Fold {fold+1} RMSE: {fold_rmse:.5f} (best_iteration={model.best_iteration})")
    
    # Accumulate Test Preds
    batch_test_preds = model.predict(X_test_trans)
    batch_test_preds = np.clip(batch_test_preds, 0, 100)
    test_preds += batch_test_preds / n_folds

# Final Metric Calculation
overall_rmse = np.sqrt(mean_squared_error(y, oof_preds))
print(f"\nOverall CV RMSE: {overall_rmse:.5f}")
# Out:
# Final XGBoost CV Training with OOF / Test predictions
# ======================================================
# Parameters used for training:
# {'learning_rate': 0.013990215499161093, 'max_depth': 6, 'min_child_weight': 1.4425033535788745, 'subsample': 0.8894820282793995, 'colsample_bytree': 0.7473735194517545, 'reg_alpha': 0.0023956873156932845, 'reg_lambda': 0.001976726479539849, 'gamma': 2.5221307703428075, 'grow_policy': 'depthwise', 'n_estimators': 12000, 'objective': 'reg:squarederror', 'eval_metric': 'rmse', 'n_jobs': 1, 'random_state': 10301, 'early_stopping_rounds': 50, 'tree_method': 'gpu_hist', 'enable_categorical': True}
# Starting processing of fold 1
# [0]	validation_0-rmse:18.88305	validation_1-rmse:18.86410
# [100]	validation_0-rmse:10.98728	validation_1-rmse:10.97445
# [200]	validation_0-rmse:9.18265	validation_1-rmse:9.16206
# [300]	validation_0-rmse:8.87600	validation_1-rmse:8.84584
# [400]	validation_0-rmse:8.82293	validation_1-rmse:8.78428
# [500]	validation_0-rmse:8.80728	validation_1-rmse:8.76175
# [600]	validation_0-rmse:8.79980	validation_1-rmse:8.74744
# [700]	validation_0-rmse:8.79498	validation_1-rmse:8.73611
# [800]	validation_0-rmse:8.79083	validation_1-rmse:8.72545
# [900]	validation_0-rmse:8.78722	validation_1-rmse:8.71560
# [1000]	validation_0-rmse:8.78330	validation_1-rmse:8.70552
# [1100]	validation_0-rmse:8.77965	validation_1-rmse:8.69594
# [1200]	validation_0-rmse:8.77679	validation_1-rmse:8.68678
# [1300]	validation_0-rmse:8.77375	validation_1-rmse:8.67787
# [1400]	validation_0-rmse:8.77145	validation_1-rmse:8.66962
# [1500]	validation_0-rmse:8.76938	validation_1-rmse:8.66167
# [1600]	validation_0-rmse:8.76717	validation_1-rmse:8.65369
# [1700]	validation_0-rmse:8.76530	validation_1-rmse:8.64609
# [1800]	validation_0-rmse:8.76368	validation_1-rmse:8.63863
# [1900]	validation_0-rmse:8.76233	validation_1-rmse:8.63138
# [2000]	validation_0-rmse:8.76081	validation_1-rmse:8.62407
# [2100]	validation_0-rmse:8.75933	validation_1-rmse:8.61680
# [2200]	validation_0-rmse:8.75813	validation_1-rmse:8.61008
# [2300]	validation_0-rmse:8.75705	validation_1-rmse:8.60327
# [2400]	validation_0-rmse:8.75605	validation_1-rmse:8.59657
# [2500]	validation_0-rmse:8.75507	validation_1-rmse:8.59006
# [2600]	validation_0-rmse:8.75414	validation_1-rmse:8.58368
# [2700]	validation_0-rmse:8.75336	validation_1-rmse:8.57751
# [2800]	validation_0-rmse:8.75256	validation_1-rmse:8.57118
# [2900]	validation_0-rmse:8.75195	validation_1-rmse:8.56504
# [3000]	validation_0-rmse:8.75129	validation_1-rmse:8.55883
# [3100]	validation_0-rmse:8.75086	validation_1-rmse:8.55278
# [3200]	validation_0-rmse:8.75029	validation_1-rmse:8.54688
# [3300]	validation_0-rmse:8.74963	validation_1-rmse:8.54083
# [3400]	validation_0-rmse:8.74904	validation_1-rmse:8.53476
# [3500]	validation_0-rmse:8.74859	validation_1-rmse:8.52879
# [3600]	validation_0-rmse:8.74819	validation_1-rmse:8.52307
# [3700]	validation_0-rmse:8.74775	validation_1-rmse:8.51733
# [3800]	validation_0-rmse:8.74738	validation_1-rmse:8.51169
# [3900]	validation_0-rmse:8.74695	validation_1-rmse:8.50618
# [4000]	validation_0-rmse:8.74665	validation_1-rmse:8.50076
# [4100]	validation_0-rmse:8.74649	validation_1-rmse:8.49530
# [4200]	validation_0-rmse:8.74635	validation_1-rmse:8.48989
# [4300]	validation_0-rmse:8.74615	validation_1-rmse:8.48464
# [4400]	validation_0-rmse:8.74599	validation_1-rmse:8.47944
# [4500]	validation_0-rmse:8.74567	validation_1-rmse:8.47411
# [4600]	validation_0-rmse:8.74556	validation_1-rmse:8.46906
# [4700]	validation_0-rmse:8.74533	validation_1-rmse:8.46377
# [4800]	validation_0-rmse:8.74521	validation_1-rmse:8.45860
# [4900]	validation_0-rmse:8.74521	validation_1-rmse:8.45358
# [5000]	validation_0-rmse:8.74516	validation_1-rmse:8.44876
# [5100]	validation_0-rmse:8.74488	validation_1-rmse:8.44363
# [5200]	validation_0-rmse:8.74487	validation_1-rmse:8.43852
# [5300]	validation_0-rmse:8.74494	validation_1-rmse:8.43371
# [5400]	validation_0-rmse:8.74503	validation_1-rmse:8.42875
# [5500]	validation_0-rmse:8.74507	validation_1-rmse:8.42382
# [5600]	validation_0-rmse:8.74501	validation_1-rmse:8.41898
# [5700]	validation_0-rmse:8.74499	validation_1-rmse:8.41418
# [5800]	validation_0-rmse:8.74501	validation_1-rmse:8.40928
# [5900]	validation_0-rmse:8.74497	validation_1-rmse:8.40452
# [6000]	validation_0-rmse:8.74494	validation_1-rmse:8.39971
# [6100]	validation_0-rmse:8.74495	validation_1-rmse:8.39497
# [6200]	validation_0-rmse:8.74506	validation_1-rmse:8.39023
# [6300]	validation_0-rmse:8.74514	validation_1-rmse:8.38552
# [6400]	validation_0-rmse:8.74521	validation_1-rmse:8.38080
# [6500]	validation_0-rmse:8.74519	validation_1-rmse:8.37617
# [6600]	validation_0-rmse:8.74517	validation_1-rmse:8.37158
# [6700]	validation_0-rmse:8.74532	validation_1-rmse:8.36700
# [6800]	validation_0-rmse:8.74552	validation_1-rmse:8.36247
# [6900]	validation_0-rmse:8.74558	validation_1-rmse:8.35798
# [7000]	validation_0-rmse:8.74587	validation_1-rmse:8.35351
# [7100]	validation_0-rmse:8.74603	validation_1-rmse:8.34908
# [7200]	validation_0-rmse:8.74619	validation_1-rmse:8.34469
# [7300]	validation_0-rmse:8.74640	validation_1-rmse:8.34024
# [7400]	validation_0-rmse:8.74645	validation_1-rmse:8.33580
# [7500]	validation_0-rmse:8.74655	validation_1-rmse:8.33149
# [7600]	validation_0-rmse:8.74687	validation_1-rmse:8.32715
# [7700]	validation_0-rmse:8.74716	validation_1-rmse:8.32291
# [7800]	validation_0-rmse:8.74734	validation_1-rmse:8.31860
# [7900]	validation_0-rmse:8.74765	validation_1-rmse:8.31446
# [8000]	validation_0-rmse:8.74789	validation_1-rmse:8.31017
# [8100]	validation_0-rmse:8.74820	validation_1-rmse:8.30607
# [8200]	validation_0-rmse:8.74855	validation_1-rmse:8.30195
# [8300]	validation_0-rmse:8.74881	validation_1-rmse:8.29767
# [8400]	validation_0-rmse:8.74908	validation_1-rmse:8.29344
# [8500]	validation_0-rmse:8.74932	validation_1-rmse:8.28925
# [8600]	validation_0-rmse:8.74961	validation_1-rmse:8.28528
# [8700]	validation_0-rmse:8.74990	validation_1-rmse:8.28111
# [8800]	validation_0-rmse:8.75008	validation_1-rmse:8.27701
# [8900]	validation_0-rmse:8.75033	validation_1-rmse:8.27292
# [9000]	validation_0-rmse:8.75069	validation_1-rmse:8.26879
# [9100]	validation_0-rmse:8.75094	validation_1-rmse:8.26487
# [9200]	validation_0-rmse:8.75109	validation_1-rmse:8.26087
# [9300]	validation_0-rmse:8.75135	validation_1-rmse:8.25672
# [9400]	validation_0-rmse:8.75172	validation_1-rmse:8.25269
# [9500]	validation_0-rmse:8.75202	validation_1-rmse:8.24872
# [9600]	validation_0-rmse:8.75228	validation_1-rmse:8.24475
# [9700]	validation_0-rmse:8.75274	validation_1-rmse:8.24073
# [9800]	validation_0-rmse:8.75307	validation_1-rmse:8.23687
# [9900]	validation_0-rmse:8.75347	validation_1-rmse:8.23299
# [10000]	validation_0-rmse:8.75363	validation_1-rmse:8.22899
# [10100]	validation_0-rmse:8.75395	validation_1-rmse:8.22506
# [10200]	validation_0-rmse:8.75417	validation_1-rmse:8.22123
# [10300]	validation_0-rmse:8.75451	validation_1-rmse:8.21744
# [10400]	validation_0-rmse:8.75474	validation_1-rmse:8.21361
# [10500]	validation_0-rmse:8.75514	validation_1-rmse:8.20975
# [10600]	validation_0-rmse:8.75550	validation_1-rmse:8.20594
# [10700]	validation_0-rmse:8.75577	validation_1-rmse:8.20217
# [10800]	validation_0-rmse:8.75611	validation_1-rmse:8.19830
# [10900]	validation_0-rmse:8.75643	validation_1-rmse:8.19452
# [11000]	validation_0-rmse:8.75671	validation_1-rmse:8.19081
# [11100]	validation_0-rmse:8.75722	validation_1-rmse:8.18700
# [11200]	validation_0-rmse:8.75770	validation_1-rmse:8.18322
# [11300]	validation_0-rmse:8.75812	validation_1-rmse:8.17942
# [11400]	validation_0-rmse:8.75845	validation_1-rmse:8.17570
# [11500]	validation_0-rmse:8.75877	validation_1-rmse:8.17196
# [11600]	validation_0-rmse:8.75923	validation_1-rmse:8.16835
# [11700]	validation_0-rmse:8.75965	validation_1-rmse:8.16459
# [11800]	validation_0-rmse:8.76002	validation_1-rmse:8.16081
# [11900]	validation_0-rmse:8.76040	validation_1-rmse:8.15723
# [11999]	validation_0-rmse:8.76066	validation_1-rmse:8.15358
# Fold 1 RMSE: 8.76038 (best_iteration=11999)
# Starting processing of fold 2
# [0]	validation_0-rmse:18.84861	validation_1-rmse:18.87264
# [100]	validation_0-rmse:10.97434	validation_1-rmse:10.97462
# [200]	validation_0-rmse:9.17929	validation_1-rmse:9.16257
# [300]	validation_0-rmse:8.87094	validation_1-rmse:8.84674
# [400]	validation_0-rmse:8.81611	validation_1-rmse:8.78517
# [500]	validation_0-rmse:8.80005	validation_1-rmse:8.76275
# [600]	validation_0-rmse:8.79271	validation_1-rmse:8.74874
# [700]	validation_0-rmse:8.78789	validation_1-rmse:8.73741
# [800]	validation_0-rmse:8.78421	validation_1-rmse:8.72729
# [900]	validation_0-rmse:8.78049	validation_1-rmse:8.71733
# [1000]	validation_0-rmse:8.77692	validation_1-rmse:8.70769
# [1100]	validation_0-rmse:8.77358	validation_1-rmse:8.69819
# [1200]	validation_0-rmse:8.77063	validation_1-rmse:8.68921
# [1300]	validation_0-rmse:8.76774	validation_1-rmse:8.68040
# [1400]	validation_0-rmse:8.76518	validation_1-rmse:8.67182
# [1500]	validation_0-rmse:8.76278	validation_1-rmse:8.66357
# [1600]	validation_0-rmse:8.76084	validation_1-rmse:8.65572
# [1700]	validation_0-rmse:8.75896	validation_1-rmse:8.64786
# [1800]	validation_0-rmse:8.75713	validation_1-rmse:8.64016
# [1900]	validation_0-rmse:8.75573	validation_1-rmse:8.63298
# [2000]	validation_0-rmse:8.75438	validation_1-rmse:8.62558
# [2100]	validation_0-rmse:8.75324	validation_1-rmse:8.61859
# [2200]	validation_0-rmse:8.75229	validation_1-rmse:8.61190
# [2300]	validation_0-rmse:8.75125	validation_1-rmse:8.60519
# [2400]	validation_0-rmse:8.74998	validation_1-rmse:8.59840
# [2500]	validation_0-rmse:8.74917	validation_1-rmse:8.59193
# [2600]	validation_0-rmse:8.74833	validation_1-rmse:8.58545
# [2700]	validation_0-rmse:8.74769	validation_1-rmse:8.57938
# [2800]	validation_0-rmse:8.74696	validation_1-rmse:8.57319
# [2900]	validation_0-rmse:8.74637	validation_1-rmse:8.56700
# [3000]	validation_0-rmse:8.74561	validation_1-rmse:8.56092
# [3100]	validation_0-rmse:8.74503	validation_1-rmse:8.55485
# [3200]	validation_0-rmse:8.74467	validation_1-rmse:8.54878
# [3300]	validation_0-rmse:8.74423	validation_1-rmse:8.54270
# [3400]	validation_0-rmse:8.74372	validation_1-rmse:8.53673
# [3500]	validation_0-rmse:8.74346	validation_1-rmse:8.53074
# [3600]	validation_0-rmse:8.74305	validation_1-rmse:8.52501
# [3700]	validation_0-rmse:8.74275	validation_1-rmse:8.51933
# [3800]	validation_0-rmse:8.74248	validation_1-rmse:8.51371
# [3900]	validation_0-rmse:8.74221	validation_1-rmse:8.50809
# [4000]	validation_0-rmse:8.74182	validation_1-rmse:8.50257
# [4100]	validation_0-rmse:8.74157	validation_1-rmse:8.49704
# [4200]	validation_0-rmse:8.74157	validation_1-rmse:8.49159
# [4300]	validation_0-rmse:8.74156	validation_1-rmse:8.48631
# [4400]	validation_0-rmse:8.74141	validation_1-rmse:8.48097
# [4500]	validation_0-rmse:8.74114	validation_1-rmse:8.47556
# [4600]	validation_0-rmse:8.74114	validation_1-rmse:8.47051
# [4700]	validation_0-rmse:8.74101	validation_1-rmse:8.46531
# [4800]	validation_0-rmse:8.74068	validation_1-rmse:8.45992
# [4900]	validation_0-rmse:8.74069	validation_1-rmse:8.45496
# [5000]	validation_0-rmse:8.74077	validation_1-rmse:8.45002
# [5100]	validation_0-rmse:8.74086	validation_1-rmse:8.44498
# [5200]	validation_0-rmse:8.74088	validation_1-rmse:8.43993
# [5300]	validation_0-rmse:8.74100	validation_1-rmse:8.43512
# [5400]	validation_0-rmse:8.74106	validation_1-rmse:8.43014
# [5500]	validation_0-rmse:8.74101	validation_1-rmse:8.42518
# [5600]	validation_0-rmse:8.74115	validation_1-rmse:8.42047
# [5700]	validation_0-rmse:8.74123	validation_1-rmse:8.41570
# [5800]	validation_0-rmse:8.74124	validation_1-rmse:8.41082
# [5900]	validation_0-rmse:8.74133	validation_1-rmse:8.40600
# [6000]	validation_0-rmse:8.74133	validation_1-rmse:8.40129
# [6100]	validation_0-rmse:8.74156	validation_1-rmse:8.39664
# [6200]	validation_0-rmse:8.74160	validation_1-rmse:8.39193
# [6300]	validation_0-rmse:8.74183	validation_1-rmse:8.38733
# [6400]	validation_0-rmse:8.74186	validation_1-rmse:8.38273
# [6500]	validation_0-rmse:8.74199	validation_1-rmse:8.37802
# [6600]	validation_0-rmse:8.74229	validation_1-rmse:8.37340
# [6700]	validation_0-rmse:8.74242	validation_1-rmse:8.36879
# [6800]	validation_0-rmse:8.74253	validation_1-rmse:8.36435
# [6900]	validation_0-rmse:8.74269	validation_1-rmse:8.35982
# [7000]	validation_0-rmse:8.74292	validation_1-rmse:8.35544
# [7100]	validation_0-rmse:8.74320	validation_1-rmse:8.35094
# [7200]	validation_0-rmse:8.74342	validation_1-rmse:8.34646
# [7300]	validation_0-rmse:8.74355	validation_1-rmse:8.34214
# [7400]	validation_0-rmse:8.74363	validation_1-rmse:8.33766
# [7500]	validation_0-rmse:8.74388	validation_1-rmse:8.33330
# [7600]	validation_0-rmse:8.74416	validation_1-rmse:8.32888
# [7700]	validation_0-rmse:8.74426	validation_1-rmse:8.32451
# [7800]	validation_0-rmse:8.74444	validation_1-rmse:8.32008
# [7900]	validation_0-rmse:8.74481	validation_1-rmse:8.31589
# [8000]	validation_0-rmse:8.74509	validation_1-rmse:8.31159
# [8100]	validation_0-rmse:8.74535	validation_1-rmse:8.30737
# [8200]	validation_0-rmse:8.74566	validation_1-rmse:8.30318
# [8300]	validation_0-rmse:8.74598	validation_1-rmse:8.29891
# [8400]	validation_0-rmse:8.74632	validation_1-rmse:8.29470
# [8500]	validation_0-rmse:8.74647	validation_1-rmse:8.29053
# [8600]	validation_0-rmse:8.74665	validation_1-rmse:8.28652
# [8700]	validation_0-rmse:8.74695	validation_1-rmse:8.28236
# [8800]	validation_0-rmse:8.74716	validation_1-rmse:8.27821
# [8900]	validation_0-rmse:8.74741	validation_1-rmse:8.27408
# [9000]	validation_0-rmse:8.74793	validation_1-rmse:8.26993
# [9100]	validation_0-rmse:8.74827	validation_1-rmse:8.26595
# [9200]	validation_0-rmse:8.74863	validation_1-rmse:8.26201
# [9300]	validation_0-rmse:8.74883	validation_1-rmse:8.25787
# [9400]	validation_0-rmse:8.74909	validation_1-rmse:8.25384
# [9500]	validation_0-rmse:8.74921	validation_1-rmse:8.24988
# [9600]	validation_0-rmse:8.74961	validation_1-rmse:8.24590
# [9700]	validation_0-rmse:8.74992	validation_1-rmse:8.24190
# [9800]	validation_0-rmse:8.75032	validation_1-rmse:8.23807
# [9900]	validation_0-rmse:8.75056	validation_1-rmse:8.23420
# [10000]	validation_0-rmse:8.75087	validation_1-rmse:8.23019
# [10100]	validation_0-rmse:8.75119	validation_1-rmse:8.22625
# [10200]	validation_0-rmse:8.75161	validation_1-rmse:8.22236
# [10300]	validation_0-rmse:8.75198	validation_1-rmse:8.21848
# [10400]	validation_0-rmse:8.75239	validation_1-rmse:8.21467
# [10500]	validation_0-rmse:8.75285	validation_1-rmse:8.21078
# [10600]	validation_0-rmse:8.75311	validation_1-rmse:8.20688
# [10700]	validation_0-rmse:8.75333	validation_1-rmse:8.20305
# [10800]	validation_0-rmse:8.75364	validation_1-rmse:8.19922
# [10900]	validation_0-rmse:8.75410	validation_1-rmse:8.19541
# [11000]	validation_0-rmse:8.75461	validation_1-rmse:8.19170
# [11100]	validation_0-rmse:8.75496	validation_1-rmse:8.18784
# [11200]	validation_0-rmse:8.75523	validation_1-rmse:8.18407
# [11300]	validation_0-rmse:8.75562	validation_1-rmse:8.18030
# [11400]	validation_0-rmse:8.75610	validation_1-rmse:8.17647
# [11500]	validation_0-rmse:8.75646	validation_1-rmse:8.17276
# [11600]	validation_0-rmse:8.75688	validation_1-rmse:8.16916
# [11700]	validation_0-rmse:8.75731	validation_1-rmse:8.16535
# [11800]	validation_0-rmse:8.75771	validation_1-rmse:8.16164
# [11900]	validation_0-rmse:8.75796	validation_1-rmse:8.15794
# [11999]	validation_0-rmse:8.75844	validation_1-rmse:8.15431
# Fold 2 RMSE: 8.75819 (best_iteration=11999)
# Starting processing of fold 3
# [0]	validation_0-rmse:18.85528	validation_1-rmse:18.87120
# [100]	validation_0-rmse:10.99018	validation_1-rmse:10.97238
# [200]	validation_0-rmse:9.19334	validation_1-rmse:9.15827
# [300]	validation_0-rmse:8.88711	validation_1-rmse:8.84211
# [400]	validation_0-rmse:8.83292	validation_1-rmse:8.78062
# [500]	validation_0-rmse:8.81773	validation_1-rmse:8.75837
# [600]	validation_0-rmse:8.81031	validation_1-rmse:8.74433
# [700]	validation_0-rmse:8.80560	validation_1-rmse:8.73313
# [800]	validation_0-rmse:8.80165	validation_1-rmse:8.72274
# [900]	validation_0-rmse:8.79747	validation_1-rmse:8.71236
# [1000]	validation_0-rmse:8.79421	validation_1-rmse:8.70284
# [1100]	validation_0-rmse:8.79146	validation_1-rmse:8.69367
# [1200]	validation_0-rmse:8.78862	validation_1-rmse:8.68453
# [1300]	validation_0-rmse:8.78623	validation_1-rmse:8.67573
# [1400]	validation_0-rmse:8.78401	validation_1-rmse:8.66721
# [1500]	validation_0-rmse:8.78196	validation_1-rmse:8.65891
# [1600]	validation_0-rmse:8.78019	validation_1-rmse:8.65104
# [1700]	validation_0-rmse:8.77833	validation_1-rmse:8.64330
# [1800]	validation_0-rmse:8.77652	validation_1-rmse:8.63548
# [1900]	validation_0-rmse:8.77522	validation_1-rmse:8.62825
# [2000]	validation_0-rmse:8.77383	validation_1-rmse:8.62104
# [2100]	validation_0-rmse:8.77255	validation_1-rmse:8.61394
# [2200]	validation_0-rmse:8.77153	validation_1-rmse:8.60707
# [2300]	validation_0-rmse:8.77042	validation_1-rmse:8.60014
# [2400]	validation_0-rmse:8.76935	validation_1-rmse:8.59321
# [2500]	validation_0-rmse:8.76868	validation_1-rmse:8.58670
# [2600]	validation_0-rmse:8.76802	validation_1-rmse:8.58040
# [2700]	validation_0-rmse:8.76732	validation_1-rmse:8.57423
# [2800]	validation_0-rmse:8.76664	validation_1-rmse:8.56778
# [2900]	validation_0-rmse:8.76631	validation_1-rmse:8.56174
# [3000]	validation_0-rmse:8.76579	validation_1-rmse:8.55567
# [3100]	validation_0-rmse:8.76534	validation_1-rmse:8.54961
# [3200]	validation_0-rmse:8.76493	validation_1-rmse:8.54370
# [3300]	validation_0-rmse:8.76445	validation_1-rmse:8.53775
# [3400]	validation_0-rmse:8.76408	validation_1-rmse:8.53188
# [3500]	validation_0-rmse:8.76366	validation_1-rmse:8.52606
# [3600]	validation_0-rmse:8.76340	validation_1-rmse:8.52041
# [3700]	validation_0-rmse:8.76313	validation_1-rmse:8.51465
# [3800]	validation_0-rmse:8.76296	validation_1-rmse:8.50906
# [3900]	validation_0-rmse:8.76281	validation_1-rmse:8.50358
# [4000]	validation_0-rmse:8.76262	validation_1-rmse:8.49806
# [4100]	validation_0-rmse:8.76245	validation_1-rmse:8.49250
# [4200]	validation_0-rmse:8.76216	validation_1-rmse:8.48692
# [4300]	validation_0-rmse:8.76215	validation_1-rmse:8.48165
# [4400]	validation_0-rmse:8.76190	validation_1-rmse:8.47636
# [4500]	validation_0-rmse:8.76190	validation_1-rmse:8.47108
# [4600]	validation_0-rmse:8.76191	validation_1-rmse:8.46595
# [4700]	validation_0-rmse:8.76166	validation_1-rmse:8.46053
# [4800]	validation_0-rmse:8.76150	validation_1-rmse:8.45526
# [4900]	validation_0-rmse:8.76162	validation_1-rmse:8.45024
# [5000]	validation_0-rmse:8.76149	validation_1-rmse:8.44531
# [5100]	validation_0-rmse:8.76152	validation_1-rmse:8.44020
# [5200]	validation_0-rmse:8.76160	validation_1-rmse:8.43517
# [5300]	validation_0-rmse:8.76168	validation_1-rmse:8.43027
# [5400]	validation_0-rmse:8.76167	validation_1-rmse:8.42517
# [5500]	validation_0-rmse:8.76188	validation_1-rmse:8.42027
# [5600]	validation_0-rmse:8.76178	validation_1-rmse:8.41552
# [5700]	validation_0-rmse:8.76184	validation_1-rmse:8.41080
# [5800]	validation_0-rmse:8.76195	validation_1-rmse:8.40593
# [5900]	validation_0-rmse:8.76206	validation_1-rmse:8.40125
# [6000]	validation_0-rmse:8.76209	validation_1-rmse:8.39647
# [6100]	validation_0-rmse:8.76238	validation_1-rmse:8.39186
# [6200]	validation_0-rmse:8.76252	validation_1-rmse:8.38713
# [6300]	validation_0-rmse:8.76288	validation_1-rmse:8.38257
# [6400]	validation_0-rmse:8.76309	validation_1-rmse:8.37796
# [6500]	validation_0-rmse:8.76335	validation_1-rmse:8.37332
# [6600]	validation_0-rmse:8.76340	validation_1-rmse:8.36876
# [6700]	validation_0-rmse:8.76361	validation_1-rmse:8.36431
# [6800]	validation_0-rmse:8.76383	validation_1-rmse:8.35974
# [6900]	validation_0-rmse:8.76394	validation_1-rmse:8.35530
# [7000]	validation_0-rmse:8.76401	validation_1-rmse:8.35091
# [7100]	validation_0-rmse:8.76435	validation_1-rmse:8.34636
# [7200]	validation_0-rmse:8.76448	validation_1-rmse:8.34192
# [7300]	validation_0-rmse:8.76472	validation_1-rmse:8.33742
# [7400]	validation_0-rmse:8.76489	validation_1-rmse:8.33303
# [7500]	validation_0-rmse:8.76522	validation_1-rmse:8.32863
# [7600]	validation_0-rmse:8.76544	validation_1-rmse:8.32436
# [7700]	validation_0-rmse:8.76578	validation_1-rmse:8.32008
# [7800]	validation_0-rmse:8.76603	validation_1-rmse:8.31566
# [7900]	validation_0-rmse:8.76640	validation_1-rmse:8.31139
# [8000]	validation_0-rmse:8.76672	validation_1-rmse:8.30703
# [8100]	validation_0-rmse:8.76704	validation_1-rmse:8.30284
# [8200]	validation_0-rmse:8.76722	validation_1-rmse:8.29868
# [8300]	validation_0-rmse:8.76758	validation_1-rmse:8.29443
# [8400]	validation_0-rmse:8.76790	validation_1-rmse:8.29023
# [8500]	validation_0-rmse:8.76826	validation_1-rmse:8.28605
# [8600]	validation_0-rmse:8.76861	validation_1-rmse:8.28193
# [8700]	validation_0-rmse:8.76880	validation_1-rmse:8.27775
# [8800]	validation_0-rmse:8.76919	validation_1-rmse:8.27369
# [8900]	validation_0-rmse:8.76953	validation_1-rmse:8.26965
# [9000]	validation_0-rmse:8.76975	validation_1-rmse:8.26561
# [9100]	validation_0-rmse:8.76995	validation_1-rmse:8.26167
# [9200]	validation_0-rmse:8.77018	validation_1-rmse:8.25762
# [9300]	validation_0-rmse:8.77058	validation_1-rmse:8.25355
# [9400]	validation_0-rmse:8.77072	validation_1-rmse:8.24947
# [9500]	validation_0-rmse:8.77096	validation_1-rmse:8.24553
# [9600]	validation_0-rmse:8.77126	validation_1-rmse:8.24158
# [9700]	validation_0-rmse:8.77162	validation_1-rmse:8.23756
# [9800]	validation_0-rmse:8.77196	validation_1-rmse:8.23360
# [9900]	validation_0-rmse:8.77243	validation_1-rmse:8.22968
# [10000]	validation_0-rmse:8.77277	validation_1-rmse:8.22583
# [10100]	validation_0-rmse:8.77311	validation_1-rmse:8.22192
# [10200]	validation_0-rmse:8.77339	validation_1-rmse:8.21800
# [10300]	validation_0-rmse:8.77373	validation_1-rmse:8.21421
# [10400]	validation_0-rmse:8.77398	validation_1-rmse:8.21035
# [10500]	validation_0-rmse:8.77435	validation_1-rmse:8.20644
# [10600]	validation_0-rmse:8.77465	validation_1-rmse:8.20269
# [10700]	validation_0-rmse:8.77495	validation_1-rmse:8.19888
# [10800]	validation_0-rmse:8.77521	validation_1-rmse:8.19505
# [10900]	validation_0-rmse:8.77549	validation_1-rmse:8.19125
# [11000]	validation_0-rmse:8.77578	validation_1-rmse:8.18753
# [11100]	validation_0-rmse:8.77620	validation_1-rmse:8.18374
# [11200]	validation_0-rmse:8.77654	validation_1-rmse:8.17998
# [11300]	validation_0-rmse:8.77693	validation_1-rmse:8.17623
# [11400]	validation_0-rmse:8.77717	validation_1-rmse:8.17247
# [11500]	validation_0-rmse:8.77758	validation_1-rmse:8.16878
# [11600]	validation_0-rmse:8.77790	validation_1-rmse:8.16512
# [11700]	validation_0-rmse:8.77834	validation_1-rmse:8.16144
# [11800]	validation_0-rmse:8.77868	validation_1-rmse:8.15764
# [11900]	validation_0-rmse:8.77898	validation_1-rmse:8.15394
# [11999]	validation_0-rmse:8.77940	validation_1-rmse:8.15032
# Fold 3 RMSE: 8.77892 (best_iteration=11999)
# Starting processing of fold 4
# [0]	validation_0-rmse:18.87528	validation_1-rmse:18.86611
# [100]	validation_0-rmse:10.98322	validation_1-rmse:10.97867
# [200]	validation_0-rmse:9.16927	validation_1-rmse:9.16880
# [300]	validation_0-rmse:8.85414	validation_1-rmse:8.85329
# [400]	validation_0-rmse:8.79684	validation_1-rmse:8.79175
# [500]	validation_0-rmse:8.78002	validation_1-rmse:8.76890
# [600]	validation_0-rmse:8.77186	validation_1-rmse:8.75440
# [700]	validation_0-rmse:8.76691	validation_1-rmse:8.74337
# [800]	validation_0-rmse:8.76306	validation_1-rmse:8.73324
# [900]	validation_0-rmse:8.75892	validation_1-rmse:8.72303
# [1000]	validation_0-rmse:8.75528	validation_1-rmse:8.71340
# [1100]	validation_0-rmse:8.75218	validation_1-rmse:8.70420
# [1200]	validation_0-rmse:8.74947	validation_1-rmse:8.69530
# [1300]	validation_0-rmse:8.74670	validation_1-rmse:8.68649
# [1400]	validation_0-rmse:8.74433	validation_1-rmse:8.67826
# [1500]	validation_0-rmse:8.74232	validation_1-rmse:8.67024
# [1600]	validation_0-rmse:8.74025	validation_1-rmse:8.66215
# [1700]	validation_0-rmse:8.73840	validation_1-rmse:8.65435
# [1800]	validation_0-rmse:8.73686	validation_1-rmse:8.64671
# [1900]	validation_0-rmse:8.73533	validation_1-rmse:8.63946
# [2000]	validation_0-rmse:8.73401	validation_1-rmse:8.63229
# [2100]	validation_0-rmse:8.73268	validation_1-rmse:8.62525
# [2200]	validation_0-rmse:8.73150	validation_1-rmse:8.61862
# [2300]	validation_0-rmse:8.73059	validation_1-rmse:8.61179
# [2400]	validation_0-rmse:8.72951	validation_1-rmse:8.60496
# [2500]	validation_0-rmse:8.72861	validation_1-rmse:8.59831
# [2600]	validation_0-rmse:8.72796	validation_1-rmse:8.59205
# [2700]	validation_0-rmse:8.72731	validation_1-rmse:8.58587
# [2800]	validation_0-rmse:8.72635	validation_1-rmse:8.57951
# [2900]	validation_0-rmse:8.72577	validation_1-rmse:8.57333
# [3000]	validation_0-rmse:8.72487	validation_1-rmse:8.56713
# [3100]	validation_0-rmse:8.72422	validation_1-rmse:8.56121
# [3200]	validation_0-rmse:8.72369	validation_1-rmse:8.55513
# [3300]	validation_0-rmse:8.72316	validation_1-rmse:8.54924
# [3400]	validation_0-rmse:8.72274	validation_1-rmse:8.54329
# [3500]	validation_0-rmse:8.72237	validation_1-rmse:8.53739
# [3600]	validation_0-rmse:8.72209	validation_1-rmse:8.53177
# [3700]	validation_0-rmse:8.72147	validation_1-rmse:8.52609
# [3800]	validation_0-rmse:8.72105	validation_1-rmse:8.52040
# [3900]	validation_0-rmse:8.72076	validation_1-rmse:8.51477
# [4000]	validation_0-rmse:8.72060	validation_1-rmse:8.50943
# [4100]	validation_0-rmse:8.72046	validation_1-rmse:8.50394
# [4200]	validation_0-rmse:8.72017	validation_1-rmse:8.49845
# [4300]	validation_0-rmse:8.72000	validation_1-rmse:8.49315
# [4400]	validation_0-rmse:8.71978	validation_1-rmse:8.48784
# [4500]	validation_0-rmse:8.71966	validation_1-rmse:8.48239
# [4600]	validation_0-rmse:8.71970	validation_1-rmse:8.47736
# [4700]	validation_0-rmse:8.71944	validation_1-rmse:8.47218
# [4800]	validation_0-rmse:8.71931	validation_1-rmse:8.46700
# [4900]	validation_0-rmse:8.71924	validation_1-rmse:8.46205
# [5000]	validation_0-rmse:8.71925	validation_1-rmse:8.45712
# [5100]	validation_0-rmse:8.71924	validation_1-rmse:8.45197
# [5200]	validation_0-rmse:8.71931	validation_1-rmse:8.44689
# [5300]	validation_0-rmse:8.71923	validation_1-rmse:8.44200
# [5400]	validation_0-rmse:8.71923	validation_1-rmse:8.43707
# [5500]	validation_0-rmse:8.71908	validation_1-rmse:8.43217
# [5600]	validation_0-rmse:8.71917	validation_1-rmse:8.42745
# [5700]	validation_0-rmse:8.71915	validation_1-rmse:8.42273
# [5800]	validation_0-rmse:8.71915	validation_1-rmse:8.41786
# [5900]	validation_0-rmse:8.71930	validation_1-rmse:8.41328
# [6000]	validation_0-rmse:8.71933	validation_1-rmse:8.40841
# [6100]	validation_0-rmse:8.71953	validation_1-rmse:8.40373
# [6200]	validation_0-rmse:8.71964	validation_1-rmse:8.39905
# [6300]	validation_0-rmse:8.71979	validation_1-rmse:8.39440
# [6400]	validation_0-rmse:8.71977	validation_1-rmse:8.38976
# [6500]	validation_0-rmse:8.71987	validation_1-rmse:8.38521
# [6600]	validation_0-rmse:8.72005	validation_1-rmse:8.38062
# [6700]	validation_0-rmse:8.72018	validation_1-rmse:8.37614
# [6800]	validation_0-rmse:8.72045	validation_1-rmse:8.37169
# [6900]	validation_0-rmse:8.72072	validation_1-rmse:8.36731
# [7000]	validation_0-rmse:8.72099	validation_1-rmse:8.36293
# [7100]	validation_0-rmse:8.72119	validation_1-rmse:8.35846
# [7200]	validation_0-rmse:8.72143	validation_1-rmse:8.35406
# [7300]	validation_0-rmse:8.72155	validation_1-rmse:8.34968
# [7400]	validation_0-rmse:8.72170	validation_1-rmse:8.34526
# [7500]	validation_0-rmse:8.72184	validation_1-rmse:8.34089
# [7600]	validation_0-rmse:8.72208	validation_1-rmse:8.33649
# [7700]	validation_0-rmse:8.72232	validation_1-rmse:8.33216
# [7800]	validation_0-rmse:8.72261	validation_1-rmse:8.32791
# [7900]	validation_0-rmse:8.72280	validation_1-rmse:8.32369
# [8000]	validation_0-rmse:8.72284	validation_1-rmse:8.31940
# [8100]	validation_0-rmse:8.72309	validation_1-rmse:8.31512
# [8200]	validation_0-rmse:8.72339	validation_1-rmse:8.31102
# [8300]	validation_0-rmse:8.72352	validation_1-rmse:8.30674
# [8400]	validation_0-rmse:8.72371	validation_1-rmse:8.30261
# [8500]	validation_0-rmse:8.72392	validation_1-rmse:8.29837
# [8600]	validation_0-rmse:8.72418	validation_1-rmse:8.29430
# [8700]	validation_0-rmse:8.72454	validation_1-rmse:8.29018
# [8800]	validation_0-rmse:8.72492	validation_1-rmse:8.28605
# [8900]	validation_0-rmse:8.72516	validation_1-rmse:8.28192
# [9000]	validation_0-rmse:8.72535	validation_1-rmse:8.27775
# [9100]	validation_0-rmse:8.72563	validation_1-rmse:8.27376
# [9200]	validation_0-rmse:8.72599	validation_1-rmse:8.26977
# [9300]	validation_0-rmse:8.72614	validation_1-rmse:8.26570
# [9400]	validation_0-rmse:8.72648	validation_1-rmse:8.26181
# [9500]	validation_0-rmse:8.72682	validation_1-rmse:8.25788
# [9600]	validation_0-rmse:8.72710	validation_1-rmse:8.25394
# [9700]	validation_0-rmse:8.72735	validation_1-rmse:8.25004
# [9800]	validation_0-rmse:8.72763	validation_1-rmse:8.24615
# [9900]	validation_0-rmse:8.72803	validation_1-rmse:8.24226
# [10000]	validation_0-rmse:8.72838	validation_1-rmse:8.23833
# [10100]	validation_0-rmse:8.72874	validation_1-rmse:8.23445
# [10200]	validation_0-rmse:8.72893	validation_1-rmse:8.23061
# [10300]	validation_0-rmse:8.72913	validation_1-rmse:8.22666
# [10400]	validation_0-rmse:8.72947	validation_1-rmse:8.22291
# [10500]	validation_0-rmse:8.72980	validation_1-rmse:8.21900
# [10600]	validation_0-rmse:8.73019	validation_1-rmse:8.21522
# [10700]	validation_0-rmse:8.73052	validation_1-rmse:8.21140
# [10800]	validation_0-rmse:8.73087	validation_1-rmse:8.20749
# [10900]	validation_0-rmse:8.73114	validation_1-rmse:8.20366
# [11000]	validation_0-rmse:8.73156	validation_1-rmse:8.19997
# [11100]	validation_0-rmse:8.73191	validation_1-rmse:8.19630
# [11200]	validation_0-rmse:8.73216	validation_1-rmse:8.19257
# [11300]	validation_0-rmse:8.73245	validation_1-rmse:8.18885
# [11400]	validation_0-rmse:8.73276	validation_1-rmse:8.18513
# [11500]	validation_0-rmse:8.73325	validation_1-rmse:8.18138
# [11600]	validation_0-rmse:8.73364	validation_1-rmse:8.17773
# [11700]	validation_0-rmse:8.73402	validation_1-rmse:8.17405
# [11800]	validation_0-rmse:8.73428	validation_1-rmse:8.17033
# [11900]	validation_0-rmse:8.73466	validation_1-rmse:8.16674
# [11999]	validation_0-rmse:8.73503	validation_1-rmse:8.16315
# Fold 4 RMSE: 8.73474 (best_iteration=11999)
# Starting processing of fold 5
# [0]	validation_0-rmse:18.87808	validation_1-rmse:18.86536
# [100]	validation_0-rmse:10.99971	validation_1-rmse:10.97129
# [200]	validation_0-rmse:9.19941	validation_1-rmse:9.15836
# [300]	validation_0-rmse:8.89057	validation_1-rmse:8.84205
# [400]	validation_0-rmse:8.83578	validation_1-rmse:8.78068
# [500]	validation_0-rmse:8.82028	validation_1-rmse:8.75856
# [600]	validation_0-rmse:8.81274	validation_1-rmse:8.74436
# [700]	validation_0-rmse:8.80811	validation_1-rmse:8.73329
# [800]	validation_0-rmse:8.80443	validation_1-rmse:8.72327
# [900]	validation_0-rmse:8.80086	validation_1-rmse:8.71318
# [1000]	validation_0-rmse:8.79770	validation_1-rmse:8.70363
# [1100]	validation_0-rmse:8.79446	validation_1-rmse:8.69419
# [1200]	validation_0-rmse:8.79148	validation_1-rmse:8.68511
# [1300]	validation_0-rmse:8.78885	validation_1-rmse:8.67651
# [1400]	validation_0-rmse:8.78668	validation_1-rmse:8.66828
# [1500]	validation_0-rmse:8.78473	validation_1-rmse:8.66050
# [1600]	validation_0-rmse:8.78270	validation_1-rmse:8.65252
# [1700]	validation_0-rmse:8.78099	validation_1-rmse:8.64481
# [1800]	validation_0-rmse:8.77916	validation_1-rmse:8.63728
# [1900]	validation_0-rmse:8.77776	validation_1-rmse:8.63001
# [2000]	validation_0-rmse:8.77615	validation_1-rmse:8.62253
# [2100]	validation_0-rmse:8.77486	validation_1-rmse:8.61562
# [2200]	validation_0-rmse:8.77388	validation_1-rmse:8.60900
# [2300]	validation_0-rmse:8.77273	validation_1-rmse:8.60208
# [2400]	validation_0-rmse:8.77187	validation_1-rmse:8.59537
# [2500]	validation_0-rmse:8.77116	validation_1-rmse:8.58888
# [2600]	validation_0-rmse:8.77035	validation_1-rmse:8.58259
# [2700]	validation_0-rmse:8.76951	validation_1-rmse:8.57645
# [2800]	validation_0-rmse:8.76898	validation_1-rmse:8.57010
# [2900]	validation_0-rmse:8.76837	validation_1-rmse:8.56404
# [3000]	validation_0-rmse:8.76779	validation_1-rmse:8.55786
# [3100]	validation_0-rmse:8.76725	validation_1-rmse:8.55190
# [3200]	validation_0-rmse:8.76684	validation_1-rmse:8.54585
# [3300]	validation_0-rmse:8.76646	validation_1-rmse:8.53999
# [3400]	validation_0-rmse:8.76561	validation_1-rmse:8.53390
# [3500]	validation_0-rmse:8.76510	validation_1-rmse:8.52798
# [3600]	validation_0-rmse:8.76486	validation_1-rmse:8.52232
# [3700]	validation_0-rmse:8.76447	validation_1-rmse:8.51668
# [3800]	validation_0-rmse:8.76402	validation_1-rmse:8.51084
# [3900]	validation_0-rmse:8.76385	validation_1-rmse:8.50527
# [4000]	validation_0-rmse:8.76376	validation_1-rmse:8.49983
# [4100]	validation_0-rmse:8.76351	validation_1-rmse:8.49432
# [4200]	validation_0-rmse:8.76327	validation_1-rmse:8.48883
# [4300]	validation_0-rmse:8.76314	validation_1-rmse:8.48359
# [4400]	validation_0-rmse:8.76306	validation_1-rmse:8.47825
# [4500]	validation_0-rmse:8.76305	validation_1-rmse:8.47288
# [4600]	validation_0-rmse:8.76309	validation_1-rmse:8.46775
# [4700]	validation_0-rmse:8.76300	validation_1-rmse:8.46256
# [4800]	validation_0-rmse:8.76279	validation_1-rmse:8.45722
# [4900]	validation_0-rmse:8.76273	validation_1-rmse:8.45217
# [5000]	validation_0-rmse:8.76292	validation_1-rmse:8.44723
# [5100]	validation_0-rmse:8.76286	validation_1-rmse:8.44218
# [5200]	validation_0-rmse:8.76290	validation_1-rmse:8.43700
# [5300]	validation_0-rmse:8.76283	validation_1-rmse:8.43215
# [5400]	validation_0-rmse:8.76284	validation_1-rmse:8.42716
# [5500]	validation_0-rmse:8.76277	validation_1-rmse:8.42215
# [5600]	validation_0-rmse:8.76280	validation_1-rmse:8.41734
# [5700]	validation_0-rmse:8.76293	validation_1-rmse:8.41254
# [5800]	validation_0-rmse:8.76315	validation_1-rmse:8.40763
# [5900]	validation_0-rmse:8.76331	validation_1-rmse:8.40288
# [6000]	validation_0-rmse:8.76344	validation_1-rmse:8.39814
# [6100]	validation_0-rmse:8.76355	validation_1-rmse:8.39339
# [6200]	validation_0-rmse:8.76366	validation_1-rmse:8.38876
# [6300]	validation_0-rmse:8.76379	validation_1-rmse:8.38414
# [6400]	validation_0-rmse:8.76407	validation_1-rmse:8.37957
# [6500]	validation_0-rmse:8.76409	validation_1-rmse:8.37492
# [6600]	validation_0-rmse:8.76422	validation_1-rmse:8.37033
# [6700]	validation_0-rmse:8.76440	validation_1-rmse:8.36581
# [6800]	validation_0-rmse:8.76464	validation_1-rmse:8.36121
# [6900]	validation_0-rmse:8.76482	validation_1-rmse:8.35677
# [7000]	validation_0-rmse:8.76489	validation_1-rmse:8.35233
# [7100]	validation_0-rmse:8.76507	validation_1-rmse:8.34779
# [7200]	validation_0-rmse:8.76533	validation_1-rmse:8.34335
# [7300]	validation_0-rmse:8.76561	validation_1-rmse:8.33899
# [7400]	validation_0-rmse:8.76592	validation_1-rmse:8.33447
# [7500]	validation_0-rmse:8.76610	validation_1-rmse:8.33009
# [7600]	validation_0-rmse:8.76649	validation_1-rmse:8.32570
# [7700]	validation_0-rmse:8.76678	validation_1-rmse:8.32125
# [7800]	validation_0-rmse:8.76687	validation_1-rmse:8.31692
# [7900]	validation_0-rmse:8.76709	validation_1-rmse:8.31272
# [8000]	validation_0-rmse:8.76735	validation_1-rmse:8.30837
# [8100]	validation_0-rmse:8.76770	validation_1-rmse:8.30417
# [8200]	validation_0-rmse:8.76796	validation_1-rmse:8.29995
# [8300]	validation_0-rmse:8.76835	validation_1-rmse:8.29574
# [8400]	validation_0-rmse:8.76855	validation_1-rmse:8.29153
# [8500]	validation_0-rmse:8.76876	validation_1-rmse:8.28729
# [8600]	validation_0-rmse:8.76900	validation_1-rmse:8.28322
# [8700]	validation_0-rmse:8.76926	validation_1-rmse:8.27910
# [8800]	validation_0-rmse:8.76953	validation_1-rmse:8.27493
# [8900]	validation_0-rmse:8.76993	validation_1-rmse:8.27084
# [9000]	validation_0-rmse:8.77037	validation_1-rmse:8.26677
# [9100]	validation_0-rmse:8.77066	validation_1-rmse:8.26279
# [9200]	validation_0-rmse:8.77093	validation_1-rmse:8.25881
# [9300]	validation_0-rmse:8.77130	validation_1-rmse:8.25476
# [9400]	validation_0-rmse:8.77160	validation_1-rmse:8.25064
# [9500]	validation_0-rmse:8.77195	validation_1-rmse:8.24668
# [9600]	validation_0-rmse:8.77223	validation_1-rmse:8.24273
# [9700]	validation_0-rmse:8.77268	validation_1-rmse:8.23876
# [9800]	validation_0-rmse:8.77305	validation_1-rmse:8.23479
# [9900]	validation_0-rmse:8.77338	validation_1-rmse:8.23090
# [10000]	validation_0-rmse:8.77366	validation_1-rmse:8.22697
# [10100]	validation_0-rmse:8.77400	validation_1-rmse:8.22305
# [10200]	validation_0-rmse:8.77439	validation_1-rmse:8.21908
# [10300]	validation_0-rmse:8.77473	validation_1-rmse:8.21521
# [10400]	validation_0-rmse:8.77517	validation_1-rmse:8.21141
# [10500]	validation_0-rmse:8.77539	validation_1-rmse:8.20746
# [10600]	validation_0-rmse:8.77570	validation_1-rmse:8.20353
# [10700]	validation_0-rmse:8.77603	validation_1-rmse:8.19970
# [10800]	validation_0-rmse:8.77637	validation_1-rmse:8.19582
# [10900]	validation_0-rmse:8.77666	validation_1-rmse:8.19193
# [11000]	validation_0-rmse:8.77694	validation_1-rmse:8.18820
# [11100]	validation_0-rmse:8.77718	validation_1-rmse:8.18439
# [11200]	validation_0-rmse:8.77758	validation_1-rmse:8.18056
# [11300]	validation_0-rmse:8.77788	validation_1-rmse:8.17681
# [11400]	validation_0-rmse:8.77821	validation_1-rmse:8.17305
# [11500]	validation_0-rmse:8.77852	validation_1-rmse:8.16931
# [11600]	validation_0-rmse:8.77894	validation_1-rmse:8.16557
# [11700]	validation_0-rmse:8.77943	validation_1-rmse:8.16181
# [11800]	validation_0-rmse:8.77981	validation_1-rmse:8.15803
# [11900]	validation_0-rmse:8.78026	validation_1-rmse:8.15441
# [11999]	validation_0-rmse:8.78062	validation_1-rmse:8.15068
# Fold 5 RMSE: 8.78024 (best_iteration=11999)
#
# Overall CV RMSE: 8.76251

# %% [markdown]
# ## Visualizing Model Performance
# We use four key plots to diagnose the health of our regression model

# %% [markdown]
# ### Learning Curves (Train vs. Validation RMSE)
# This plot tracks the Root Mean Squared Error (RMSE) for both the training set (Blue) and validation set (Red) over each boosting iteration.
#
# * **What to look for:** You want the Validation (Red) curve to go down and flatten out.
# * **Overfitting:** If the Blue line keeps dropping rapidly but the Red line starts rising, the model is memorizing the training data.
# * **Underfitting:** If both lines are high and flat, the model isn't learning enough complexity.
# * **Ideal:** The Red line reaches a minimum low value and stays there. The gap between Blue and Red should not be massive.

# %%
mviz = ModelVisualizer(model_name='XGBoost')

mviz.plot_learning_curves(eval_results)

# %% [markdown]
# ### Feature Importance
# This bar chart ranks which columns had the biggest impact on the model's predictions.
# * **Validation Check:** Ensure the top features make sense (e.g., `study_hours` or `class_attendance` should likely be high).
# * **Sanity Check:** If `id` or a random noise column appears in the top 5, there is a data leakage problem.
# * **Engineering Check:** Look for the engineered features (e.g., `restoration_index`, `interaction_score`). If they appear near the top, the feature engineering added real value.

# %%
mviz.plot_feature_importance(models, show_values=True)

# %% [markdown]
# ### Prediction Error Plot (True vs. Predicted)
# This scatter plot compares the **Actual Exam Scores** (X-axis) against what the model **Predicted** (Y-axis).
# * **The Red Line:** This represents "Perfect Prediction."
# * **Tight Cloud:** The closer the blue dots are to the red dashed line, the better the model.
# * **Bias Detection:**
#     * If dots at the bottom left (low scores) are consistently above the line, the model is over-predicting struggling students.
#     * If dots at the top right (high scores) are below the line, the model is under-predicting top performers.

# %%
mviz.plot_prediction_error(y, oof_preds)

# %% [markdown]
# ### Residual Plot
# This plot shows the **Error** (True - Predicted) on the Y-axis against the **Predicted Score** on the X-axis.
# * **The Goal:** You want a random cloud of points centered around the red line (0 error).
# * **Bad Patterns:**
#     * **Funnel Shape:** If the cloud gets wider as the score increases, the model is less certain about high-scoring students.
#     * **U-Shape: If the points dip in the middle, the model is missing a non-linear relationship (e.g., it's fitting a straight line to a curved trend).
# * **Outliers:** Dots that are very far from the center line represent students the model completely misjudged. Investigating these specific rows often reveals data quality issues.

# %%
mviz.plot_residuals(y, oof_preds)

# %% [markdown]
# ## Prepare Submission

# %%
submission_df = helper.read_sample_submission_dataset()
submission_df[TARGET] = test_preds

print('SAMPLE SUBMISSION')
print('=================')

print(submission_df.head(10))
# Out:
# SAMPLE SUBMISSION
# =================
#        id  exam_score
# 0  630000      71.989
# 1  630001      70.720
# 2  630002      87.896
# 3  630003      57.456
# 4  630004      48.328
# 5  630005      71.306
# 6  630006      73.118
# 7  630007      59.509
# 8  630008      77.691
# 9  630009      90.683

# %%
submission_df.to_csv('submission.csv', index=False)
print('Saved: submission.csv')
# Out:
# Saved: submission.csv

# %% [markdown]
# ## Save OOF and Test Predictions
#
# The OOF and test predictions are saved so that they may be used for comparison of performance differences between the various models, or by a notebook exploring blending the predictions of the models using some of the tools and techniques outline by Tilii in his excellent [For the (recovering) blind blending addicts](https://www.kaggle.com/competitions/playground-series-s5e12/discussion/651787).

# %%
# Ensure directory exists
output_dir = 'predictions'
os.makedirs(output_dir, exist_ok=True) 

# Save OOF predictions and raw Test predictions.
# We will load these files in a separate "Blending Notebook".
oof_df = pd.DataFrame({'id': training_df.index, 'pred_xgb': oof_preds, 'target': y})
oof_df.to_csv(f'{output_dir}/xgb_oof_preds.csv', index=False)

test_pred_df = pd.DataFrame({'id': test_df.index, 'pred_xgb': test_preds})
test_pred_df.to_csv(f'{output_dir}/xgb_test_preds.csv', index=False)

print(f'Saved for Blending: {output_dir}/xgb_oof_preds.csv, {output_dir}/xgb_test_preds.csv')
# Out:
# Saved for Blending: predictions/xgb_oof_preds.csv, predictions/xgb_test_preds.csv
